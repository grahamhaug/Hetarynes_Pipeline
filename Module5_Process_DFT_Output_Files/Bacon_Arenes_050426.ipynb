# %%
#General Dependencies
from pathlib import Path
import shutil, os, glob, re
import pandas as pd
import numpy as np
from natsort import natsorted
from file_read_backwards import FileReadBackwards
import filecmp

# %% [markdown]
# """
#
#           __      _.._       ___        _.._               _
#        .-'__`-._.'.--.'.__.-'.--.`-._.''.--. '._.,        | |
#       /--'  '-._.'    '-._.'' __ '-._.' ._.  '._./        | |__   __ _  ___ ___  _ __
#      /__.--._.--._.'``-.__.''`  '`-.__.'   '--._/         | '_ \ / _` |/ __/ _ \| '_ \
#      '._.-'-._.-._.-''-..'._.-''-..''-..''-.__.'          | |_) | (_| | (_| (_) | | | |
#              @GCH v1.0 - last updt. 05/04/2026            |_.__/ \__,_|\___\___/|_| |_|
#
# ### Notebook Overview:
# This notebook contains code to process ORCA 5.0.3 output (.out) files. 'Successful' jobs correspond to converged optimized geometries
# with zero imaginary frequencies. 'Failed Jobs' are triaged based on common calculation outcomes, ex: failed convergence, failed to
# terminate, presence of imaginary frequences.
#
# ### Planned Features:
# 1. Implement a better/more intelligent means of resetting jobs that failed to converge (analysis of failure cause)
# 2. Update to parse Orca 6.x file format
#
# ### Motivation:
# A lightweight and modular local Orca.out parser without any external comp chem dependencies (ex: no cclib)
#
# ### How to Use this Notebook:
# 1. Define relevant Paths to output files in the PATH cell below
# 2. Download all .out files from an HPC to the relevant output paths (see example, below)
# 3. Run the notebook from the top-level project directory to process/sort .out files
# 4. There are also cells below to regenerate new .inp files from failed/non-converged first-run calculations - an area for improvement
#
# #### Example:
# I have 1 dir for aryne .outs (/project_dir/aryne_ORCA_ DFT_Outputs/) and 1 dir for Aryne .outs (/project_dir/aryne_ORCA_ DFT_Outputs/). I define paths in the ### PATHS ### cell below to indicate that these two dirs contain my .out files that I want to process. I run the cells below on each of my two target directories. After, each dir (arynes/arynes) will contain validate '.outs' and a subdir called /failed_calculations. Within /failed_calculations, there are subdirs for jobs that failed due to different reasons.
#
# ### How Bacon processes .out files:
# 1. First pass, the 'sort_complete_fail_jobs_orca5()' method sorts jobs according to the ending text in the .out file:
#     - 'Normal Termination' - either completed calcs or those that ended in failed convergence
#         - Normal termination/no errors - stay in top level dir/don't move file
#         - Normal termination/failed convergence - move .outs to /project_dir/Aryne_ORCA_ DFT_Outputs/convergence_failure/
#     - Failed/No 'Normal Termination' => sent to /project_dir/Aryne_ORCA_ DFT_Outputs/failed_calculations" for manual
#         triage - usually these are just genuinely bad calculations.
#
# 2. There is next an explicit check for optimization convergence with the 'did_optimization_converge()' method. This is a True/False check.
#
# 3. Third pass evaluates the putatively "good" calculations and performs an imaginary frequency check.
#     - does_out_contain_freq_data() method checks the 'normal termination' jobs for text flags indicating a frequency calc. was
#         performed
#     - get_orca5_freqs() method extracts the last freq block from the .out file
#     - has_imaginary_freqs_check() method analyzes extracted freqs for imaginary values
#
# End result should be a top-level dir containing validated .out files and subdirs containing calcs that failed due to various
# reasons. Can resubmit these jobs as-needed and re-process.
#
# """

# %%
### Define PATHS/relevant directories ### 
# project_dir = Path.cwd() #top level project dir
project_dir = Path.cwd().resolve().parent

### ARENES Top Level Job Directory and triage subdirs ### 
arene_dft_output_path = project_dir/"DFT_Arene_Data"/"Arene_Orca_DFT_Outputs" #arene_outs

#dir containing .inp files for referencing expected .out files 
arene_dft_input_path = project_dir/"DFT_Arene_Data"/"Arene_Orca_DFT_Inputs"

#dir for writing new .inp files to for resubmission
arene_dft_resub_input = arene_dft_input_path/"Arene_Resubs"
arene_dft_resub_input.mkdir(exist_ok=True)

#dir for jobs that failed due to bad failures/didn't terminate
arene_failed_to_terminate = arene_dft_output_path/"Failed_Calculations"
arene_failed_to_terminate.mkdir(exist_ok=True)

#dir for jobs that failed due to convergence failure
arene_no_convergence_dir = arene_failed_to_terminate /"Convergence_Failure"
arene_no_convergence_dir.mkdir(exist_ok=True)

#dir for jobs that failed due to having an extra (or more) imaginary frequency
arene_im_freq_dir= arene_failed_to_terminate/"Extra_Imaginary_Frequency"
# arene_im_freq_dir.mkdir(exist_ok=True)

# %%
def get_filepaths_in_target_dir(target_directory: Path, extension: str, printing=True):
    """
    Function: returns a list of Path objects pertaining to files in a specified directory. Searches for specific .ext
    
    Input:
        - target_directory; Path containing files with the '.extension'
        - extension; str: a string specifying an extension to use, ex: ".out", ".inp", ".sdf" etc.
        - printing; bool; Default value = True; controls printing back to user
        
    Returns: 
        - filepaths - a list of filepaths for each file wit .extension' in 'target_directory'
    """
    
    #grab user extension with a search wildcard
    file_extension = f"*{extension}"
    
    #gather and sort .ext files in /target_directory/
    filepaths = target_directory.glob(file_extension)
    filepaths = natsorted(filepaths, key=str)

    #return some user info
    if printing:
        print(f"\033[1mFound {len(filepaths)} {extension} files in '/{target_directory.stem}/\033[0m'")

    #return the list of located filepaths
    return filepaths

# %%
def get_filepaths_in_target_dir_recursive(target_directory: Path, extension: str, printing=True):
    """
    Function: returns a list of Path objects pertaining to files in a specified directory. Searches recursively
        for files matching the specified extension.
    
    Input:
        - target_directory; Path containing files with the '.extension'
        - extension; str: a string specifying an extension to use, ex: ".out", ".inp", ".sdf" etc.
        - printing; bool; Default value = True; controls printing back to user
        
    Returns: 
        - filepaths - a list of filepaths (recursive) for each file wit .extension' in 'target_directory' 
    """
    
    #grab user extension with a search wildcard
    file_extension = f"*{extension}"
    
    #gather and sort .ext files in /target_directory/
    filepaths = target_directory.rglob(file_extension)
    filepaths = natsorted(filepaths, key=str)

    #return some user info
    if printing:
        print(f"\033[1mFound {len(filepaths)} {extension} files in '/{target_directory.stem}/' (recursive)\033[0m")

    #return the list of located filepaths
    return filepaths

# %%
def sort_complete_fail_jobs_orca5(path_to_out_file: Path):
    """
    Function: Given an .out file, determine if it completed successfully or terminated with an error.
        Triages DFT .out files based on their success/failure type. 
    
    Input:
        - path_to_out_file: Path; a Path specifying a DFT .out file
        
    Returns: 
        - filepaths - a list of filepaths for each file wit .extension' in 'target_directory'
    """

    #local capture of some vars/name vars
    file_path = path_to_out_file
    parent_dir = path_to_out_file.parent

    #Strings that indicate specific job fate; used for triaging DFT .outs according to common failure modes
    normal_termination_str = "****ORCA TERMINATED NORMALLY****" #these are potentially good calculations
    failed_convergence_str = "The optimization did not converge but reached the maximum" #these failed convergence during opt
    #Store all of the flags as a list to check against
    ending_flags = [normal_termination_str, failed_convergence_str]

    #read each .out file starting from the end and working up line-by-line
    try:
        with FileReadBackwards(file_path, encoding="utf-8") as file: #read backwards from end for speed/mem
            #boolean for whether or not a known termination flag is in a line
            flag_found = False

            #read just the last 20 or so lines of an .out file for speed/mem - searching for ending flags only
            for i in range(19):
                line = file.readline()

                #out file should have at least 20 lines to be even sort of feasibly OK
                if not line:
                    print(f"'{file_path.name}': Calculation failed catastrophically; check by hand")
                    break

                #If the first 20 or so lines contain one of the known ending flags, job terminated somehow (known outcome)
                if any(ending_flag in line for ending_flag in ending_flags):
                    flag_found = True #one of the known ending flags was found; triage the type of termination

                    #most common in an ideal world; should be first condition checked
                    #these jobs terminated and should be evaluated for quality after this first pass
                    #need to check them for imfreqs and for convergence criteria
                    if normal_termination_str in line:
                        print(f"\t'{file_path.name}': Potentially Valid")
                        break

                    #jobs that finished but didn't converge to opt'd geometry
                    elif failed_convergence_str in line: 
                        #move the file to /no_convergence_dir/
                        file.close()
                        destination_file_path = parent_dir/"failed_calculations"/"convergence_failure"/file_path.name
                        try:
                            shutil.move(file_path, destination_file_path)
                            print(f"'{file_path.name}': \tFailed Convergence. Moved to /convergence_failure/ for resub")
                        except FileNotFoundError:
                            print(f"Failed Conv Error - Error: Source file not found at {file_path}")
                        except shutil.SameFileError:
                            print(f"Skipped '{file_path.name}', already exists in destination.")
                        except Exception as e:
                            print(f"Error copying {file_path.name}: {e}")
                        break
                    break

            #if none of the known termination flags are found in the last 20 or so lines, job did not finish
            if not flag_found:
                file.close()
                destination_file_path = parent_dir/"failed_calculations"/file_path.name
                try:
                    shutil.move(file_path, destination_file_path)
                    print(f"'{file_path.name}': \tDid not terminate. Moved to /failed_calculations/ for further triage.")
                except FileNotFoundError:
                    print(f"Error: Source file not found at {file_path}")
                except shutil.SameFileError:
                    print(f"Skipped '{file_path.name}', already exists in destination.")
                except Exception as e:
                    print(f"Error copying {file_path.name}: {e}")
                #move them to a new dir or make a new resub input
                #kind of depends on what happened with them; can maybe trirage more
                    
    except FileNotFoundError:
        print(f"'{file_path}' does not exist.")
        
    except PermissionError:
        print(f"Permission denied for '{file_path}'.")

# %%
def check_opt_convergence(path_to_out_file: Path):
    """
    Function: Explicitly check that an Orca 5.0.3 .out file terminatated with optimization convergence. 
        Returns True if converged, False if not found. 

    Input:
        - path_to_out_file: Path; a path to a putatively valid (normal termination) Orca 5.0.3 Output file.
        - path_to_fail_dir: Path; a path to a directory for outs that failed to converge

    Returns:
        convergence_check: Bool; a Pass/Fail True/False on convergence    
    """

    #string to look for in the output file
    convergence_line = "THE OPTIMIZATION HAS CONVERGED"

    #Prep a flag to indicate whether the desired line was found or not
    convergence_line_found = False

    #read through the file backwards for our desired text line
    try:
        with FileReadBackwards(path_to_out_file, encoding="utf-8") as file:
            for line in file: #remember we are going backwards from end of file

                #if the line indicating Freq calc was performed is found, 
                if convergence_line in line:
                    convergence_found = True #set the flag to "True"
                    return True #return True (optimization converged)
                    break #exit as soon as a match is confirmed

        #If all lines were read and flag not found, 
        if not convergence_line_found: #the optimization terminated but did not converge
            print(f"{path_to_out_file.name} finished with 'Normal Termination' but did NOT converge.")
            return False #return False - optimization didn't converge
            file.close() #make sure to close the file first before moving

    #throw an error if file not located
    except FileNotFoundError:
        print(f"'{path_to_out_file.name}' does not exist in '/{path_to_out_file.parent}/'.")

    #throw an error if it's been locked up in a temp proc. 
    except PermissionError:
        print(f"Permission denied for '{path_to_out_file.name}'.")

# %%
def check_outs_for_convergence(path_to_outs_dir: Path, path_to_fail_dir: Path, printing=False):
    """
    Function: 

    Input:
        - path_to_outs_dir: Path; a path containing potentially valid DFT .outs (Orca 5.0.3)
        - path_to_fail_dir: Path; a path to move/send .outs that failed to converge
        - printing: Bool; Turns on/off debug printing; a default value of False

    Returns:
        convergence_check: Bool; a Pass/Fail True/False on convergence    
    """

    #get the .outs in the path_to_outs_dir as a list
    pre_sort_outs = get_filepaths_in_target_dir(path_to_outs_dir, ".out", printing=False)

    #counter to keep track of successful .outs
    success_convergence_count = 0
    
    #counter to keep track of failed convergence
    failed_convergence_count = 0

    #loop through each of the output files in the path_to_outs_dir
    for out_file in pre_sort_outs:
        #Explicitly check for optimization convergence in the .out file
        convergence_check = check_opt_convergence(out_file)

        #check_opt_convergence() returns True/False
        if convergence_check: 
            #Print some debug info to console
            print(f"\t{out_file.name}: Optimization Converged")

            #Increment the success counter
            success_convergence_count += 1

        #if this the opt failed to converge, we want to move it to /failed_calcs dir
        elif not convergence_check:

            #print debug to user
            print(f"{out_file.name}: Failed Convergence!")

            #craft a path for the place to move the bad .out to
            destination_dir = path_to_fail_dir / out_file.name

            #[Try to] move the file to our spec. destination
            try:
                shutil.move(out_file, destination_dir)
                print(f"'{out_file.name}': \tDid not converge. Moved to '/Failed_Calculations/Failed_Convergence/' for further triage.")
            except FileNotFoundError:
                print(f"Error: Source file not found at {out_file}")
            except shutil.SameFileError:
                print(f"Skipped '{out_file.name}', already exists in destination.")
            except Exception as e:
                print(f"Error copying {out_file.name}: {e}")

            #increment the fail counter
            failed_convergence_count += 1

    #optionally pass printing=True to print the following info: 
    if printing:
        print(f"\nFinished processing {len(pre_sort_outs)} .out files in '/{path_to_outs_dir.name}/'")
        print(f"Successfully Converged .outs: {success_convergence_count}")
        print(f"Non-Converged .outs: {failed_convergence_count}\n")

    return success_convergence_count, failed_convergence_count

# %%
def does_out_contain_freq_data(path_to_out_file: Path):
    """
    Purpose: Check an Orca 5.x.x (tested Orca 5.0.3) .out file for evidence that a 'freq' calc occurred
    
    Input:
        - A path to an Orca 5.x.x .out file
        
    Returns:
        - True: if .out file contains at least one block of frequency data
            #Note: it is hard coded to look for a full start-end sequence;
            #partial "freq" blocks will fail the check
        - False: if .out file does not contain any complete frequency block
    """

    #some path things
    file_path = path_to_out_file
    parent_dir = file_path.parent
    no_freq_dir = parent_dir/"failed_calculations"/"no_freq_data"
    no_freq_dir.mkdir(exist_ok=True) #make dirs if they dont exist

    #Set this to whatever text signifier you want; 
    #since we are reading from the back to the front, the first thing we should hit
    #in an Orca5 output is "NORMAL MODES" that terminates the freq block in an .out
    orca_freq_line = "NORMAL MODES"

    #read through the file backwards for our desired text line
    try:
        with FileReadBackwards(file_path, encoding="utf-8") as file:
            for line in file: #remember we are going backwards

                #if the line indicating Freq calc was performed is found, 
                if orca_freq_line in line:
                    #print(f'{file_path.name} contains freq data!')
                    return True 
                    break #exit as soon as a match is 
                    
            else:  #no frequency data was found
                print(f'{file_path.name} does not contain frequency data.')
                
                #move the file to an error dir /no_freq_data/
                file.close() #make sure to close the file first
                destination_file_path = no_freq_dir / file_path.name

                try:
                    shutil.move(file_path, destination_file_path)
                    print(f"'{file_path.name}': \tDid not terminate. Moved to /failed_calculations/ for further triage.")
                except FileNotFoundError:
                    print(f"Error: Source file not found at {file_path}")
                except shutil.SameFileError:
                    print(f"Skipped '{file_path.name}', already exists in destination.")
                except Exception as e:
                    print(f"Error copying {file_path.name}: {e}")
                return False
                
    except FileNotFoundError:
        print(f"'{file_path.name}' does not exist.")
        
    except PermissionError:
        print(f"Permission denied for '{file_path.name}'.")

# %%
def get_orca5_freqs(path_to_out_file: Path):
    """
    Function: Manually captures the vibrational frequencies from an ORCA 5.0.3 output file using string matching
        and regex.

    Input:
        - path_to_out_file: Path; Path to an ORCA .out file

    Returns:
        - frequencies: List; A list of extracted frequencies in cm^-1
    """

    #local capture
    file_path = path_to_out_file

    frequencies = [] #list to store captured frequency data
    freq_flag = False #This flag is True when lines are within the "Frequency" block of the .log file

    #read the file from back to front to find the freq data block in .out (faster back to front, generally)
    try:
        with FileReadBackwards(file_path, encoding="utf-8") as file:
            freq_found_in_file = False #we want to see if the file contains ANY freq data first
            for line in file: #remember we are going backwards
            
                if "NORMAL MODES" in line: #this is the BOTTOM of the freq 
                    freq_found_in_file = True #Set flag to True indicating that ANY freq data was found
                    freq_flag = True #fly it
                    #print(f"Found the bottom of the freq section in: {line.strip()}") #debug
                    continue

                if freq_flag: #if the freq line has been found, we need to capture lines of text
                    stripped_line = line.strip() #strip the line of text of weird whitespace
                        
                    if re.match(r"^\s*\d", stripped_line): #looking for lines that start with no whitespace and a digit
                        split_elements = stripped_line.split() #split the matched line
                        frequencies.append(float(split_elements[1])) #store the freq data as type: float
                        
                    elif "Scaling factor for frequencies" in line: #this is the TOP of the freq block
                        break #we want to stop capturing lines if the top of the block is hit

        #check if the file has freq data
        if freq_found_in_file: 
            return frequencies[::-1] #if there is, give the reverse of the captured list (we read back to front)
        else:
            return("No Frequency data was found in your file") #throw an error if there's no freq data

    except FileNotFoundError:
        print(f"'{file_path}' does not exist.")
        
    except PermissionError:
        print(f"Permission denied for '{file_path}'.")

# %%
def has_imaginary_freqs_check(list_of_freqs: list): 
    """
    Function: Checks a list of normal vibrational modes for any imaginary (in this case <0) frequencies
    
    Input: 
        - A list of frequencies extracted with the 'get_orca5_freqs()' method
        
    Returns: 
        'True' if 1 or more imaginary frequencies were found (fails the check)
        'False' if all normal modes are positive
    """
    
    return any(x < 0 for x in list_of_freqs)

# %%
def how_many_jobs_where(path_to_target_directory: Path):
    """
    Function: Checks a list of normal vibrational modes for any imaginary (in this case <0) frequencies
    
    Input: 
        - A list of frequencies extracted with the 'get_orca5_freqs()' method
        
    Returns: 
        'True' if 1 or more imaginary frequencies were found (fails the check)
        'False' if all normal modes are positive
    """
    target_dir = path_to_target_directory
    print(f'\nChecking {target_dir} for Orca.out files after processesing...')

    #if the code above was used to sort the jobs, these dirs should exist (if there were failed calcs)
    failed_to_terminate_dir = target_dir/"Failed_Calculations"
    no_convergence_dir = failed_to_terminate_dir/"Convergence_Failure"
    extra_imag_freq_dir = failed_to_terminate_dir/"Extra_Imaginary_Frequency"
    no_freq_data = failed_to_terminate_dir/"no_freq_data"

    #how many successful jobs in the target dir (no subdirs)
    successful_outs = get_filepaths_in_target_dir(target_dir, ".out", printing=False)
    print(f'\n\033[1mNumber of VALIDATED ORCA.out files in {target_dir.name}: {len(successful_outs)}\033[0m')

    #if failed dirs exist, check other dirs for jobs/count the failed jobs in each
    if failed_to_terminate_dir.is_dir():
        all_failed_jobs = get_filepaths_in_target_dir_recursive(failed_to_terminate_dir, ".out", printing=False)
        print(f'\n\033[1mNumber of FAILED ORCA.outs in /{failed_to_terminate_dir.name}/: {len(all_failed_jobs):>12}\033[0m')
        
        jobs_with_ifs = get_filepaths_in_target_dir(extra_imag_freq_dir, ".out", printing=False)
        num_with_ifs = len(jobs_with_ifs)
        print(f'\t- Failed due to extraneous Imaginary Freqs: {num_with_ifs:>13}')

        no_conv_jobs = get_filepaths_in_target_dir(no_convergence_dir, ".out", printing=False)
        num_no_conv = len(no_conv_jobs)
        print(f'\t- Failed due to lack of convergence: {num_no_conv:>20}')

        failed_disasters = get_filepaths_in_target_dir(failed_to_terminate_dir, ".out", printing=False)
        num_total_fails = len(failed_disasters)
        print(f'\t- Complete and Utter Hopeless Failures: {num_total_fails:>17}')

        no_freq_jobs = get_filepaths_in_target_dir(no_freq_data, ".out", printing=False)
        num_no_freq = len(no_freq_jobs)
        print(f'\t- Failed due to missing freq data: {num_no_freq:>22}')
        
    if [len(successful_outs) >= 1] and [len(all_failed_jobs) >= 1]:
        total_outs = int(len(successful_outs) + int(len(all_failed_jobs)))
        print(f'\n\033[1mTotal number of ORCA.out files in /{target_dir.name}/ accounted for: {total_outs}\033[0m')

# %%
def get_input_filepaths_in_target_dir_recursive(target_directory: Path):
    """
    Input: Path 'target_directory' containing files with the '.out' extension (DFT output files)
    Returns: a list of filepaths for each file with '.out' extension in 'target_directory'

    could also modify this for any file extension
    """

    #gather and sort output files in target_directory by #
    #note "rglob"
    dft_input_filepaths = target_directory.rglob('*.inp')
    dft_input_filepaths = natsorted(dft_input_filepaths)

    return list(dft_input_filepaths)

# %%
def get_mol_ids_from_filepaths(filepaths: Path):
    """
    This chops each filename down into just its integer number
    #ex: aryne_4_rdkit_conf_1.out ==> 4 as type int
    """

    mol_ids = []
    
    for filepath in filepaths:
        file_name = filepath.stem
        file_name_parts = str(file_name).split('_')
        mol_num = f"{file_name_parts[1]}"
        mol_ids.append(int(mol_num))

    return mol_ids

# %%
def find_missing(list: list):
    ### fix this nonsense and add documentation
    max = int(list[0])
    for i in list:
        if i > max:
            max = i

    min = int(list[0])
    for i in list:
        if i < min:
            min = i

    list1 = []

    for num in range(min + 1, max):
        if num not in list:
            list1.append(num)

    return list1

# %%
def search_and_copy_files(source_dir: Path, dest_dir: Path, filenames_list: list):
    """
    Recursively searches for specified filenames in source_dir and copies them to dest_dir.

    :param source_dir: The root directory to start the search (pathlib.Path object or string).
    :param dest_dir: The destination directory for copied files (pathlib.Path object or string).
    :param filenames_list: A list of filenames (strings) to search for.
    """
    source_path = Path(source_dir)
    dest_path = Path(dest_dir)

    # Create the destination directory if it does not exist
    dest_path.mkdir(parents=True, exist_ok=True)

    # Use rglob to find all files recursively
    # The pattern "*" will match every file, which we then filter by name
    for file_path in source_path.rglob("*"):
        if file_path.is_file() and file_path.name in filenames_list:
            destination_file_path = dest_path / file_path.name
            try:
                # Copy the file to the destination directory
                shutil.copy(file_path, destination_file_path)
                print(f"Copied '{file_path.relative_to(source_path).as_posix()}' to '{destination_file_path.relative_to(source_path).as_posix()}'")
            except shutil.SameFileError:
                print(f"Skipped '{file_path.name}', already exists in destination.")
            except Exception as e:
                print(f"Error copying {file_path.name}: {e}")

# %%
def split_dir_into_subdirs(parent_directory_path: Path, num_jobs_in_each_subdir: int):
    """
    Input:
        1. parent_directory_path: path to the directory containing unsorted DFT input files
        2. num_jobs_in_each_subdir: int value for the number of jobs desired in each subdir
    Function:
        1. Creates 'n' subdirs in parent directory dep. on the # of files in parent directory/'num_jobs_in_each_subdir'
        2. moves 'num_jobs_in_each_subdir'-defined number of DFT inputs to each created subdir
    """
    
    #find and sort input files 
    inp_files = parent_directory_path.glob('*.inp')
    inp_files = natsorted(inp_files, key=str)
    print(f'\033[1mFound {len(inp_files)} DFT Orca.inp files in {parent_directory_path}\033[0m')

    ##debug
    # for inp_file in inp_files:
    #     inp_name = inp_file.name
    #     print(inp_name)

    #Assigns 'increment' number of DFT jobs to each subdir
    increment = num_jobs_in_each_subdir
    #keeps track of how many subdirs are created
    subdir_count = 0

    for i in range(0, len(inp_files), increment):

        #grab the filename's header to name a subdir with
        file_path = inp_files[i].stem
        #grab the first word of the filename, in this case either "aryne" or "aryne"
        mol_header = str(file_path).split('_', 1)[0]
        
        #formatting the names of the subdirs to be 'aryne/aryne_inputs_X-Y' 
        #where X and Y are i and i+increment chunks
        subdir = "{}_{}_{}".format(mol_header+"_inputs", i + 1, i + increment)
    
        #make a subdir named 'job_name_i_(i+increment)' to hold 'increment' # of .inps
        target_subdir = parent_directory_path/subdir
        target_subdir.mkdir(parents=True, exist_ok=True)

        for file in inp_files[i:i+increment]:
            ##move the files to target_subdir
            file.rename(target_subdir/file.name)

# %%
def write_resub_inp_for_failed_conv(path_to_out_file: Path, path_to_resub_dir: Path):
    """
    Function:
    Inputs:
        -path_to_out_file
        -path_to_resub_dir
    Returns: 
        - 
    """
    
    #capture file name for writing an out file
    file_name = path_to_out_file.stem
    
    #get the job input using get_orca5_inp_from_out()
    inp_from_out = get_orca5_inp_from_out(path_to_out_file)

    #Rip out the current xyz coordinates from captured input:
    stripped_block = strip_geometry_from_inp_orca5(inp_from_out)

    # get the "best" (last - can refine this a bit at some point) geometry from the .out file
    extracted_g =  get_last_geom(path_to_out_file)
    df_str = extracted_g.astype(str)
    extracted_xyz = [' '.join(row) for row in df_str.values]

    #insert the new geometry into the input template
    new_inp = splice_new_geom_into_inp(stripped_block, extracted_xyz)
    #have to flatten the list into a \n-sep string for writing - annoying
    new_inp_as_str = '\n'.join(new_inp)
    new_inp_as_str += '\n'

    out_file_name = file_name+".inp"
    write_path = path_to_resub_dir / out_file_name
    write_path.parent.mkdir(parents=True, exist_ok=True) #make sure the dir exists
    write_path.write_text(new_inp_as_str, encoding='utf-8') #write the new .inp file
    print(f'New inp for resubmission of {file_name} written to /{path_to_resub_dir.stem}/')

# %%
def get_orca5_inp_from_out(path_to_out_file: Path):
    """
    Manually captures the input parameters from an ORCA 5.0.3 output file
    using string matching and regex.

    Input:
        - path_to_out_file: Path to an ORCA .out file

    Returns:
        - captured_input: a list containing lines of text corresponding to the input block of an orca calc.
        (used as a template to remake new .inp files from .out triage)
    """

    file_path = path_to_out_file

    captured_input = []
    inp_flag = False #This flag is True when lines are within the "Frequency" block of the .log file

    try:
        with open(file_path, 'r') as file:
            for line in file:
            
                if "INPUT FILE" in line: #this is the top of the input block 
                    inp_flag = True #input data has been found/turn on text capture
                    continue

                if inp_flag: # text capture has been turned on
                    stripped_line = line.strip()
                    #add the captured line to our captured input 
                    captured_input.append(stripped_line)
                        
                    if "END OF INPUT" in line: #this is the BOTTOM of the inp block
                        break

        if captured_input: 
            raw_inp_block = captured_input[3:-1]

            formatted_inp = []
            for line in raw_inp_block:
                stripped_line = line.strip()
                split_line = stripped_line.split('>', 1)
                inp_line = split_line[1]
                formatted_inp.append(inp_line)
            return formatted_inp
        else:
            return("No input data was found in your file")

    except FileNotFoundError:
        print(f"'{file_path}' does not exist.")
        
    except PermissionError:
        print(f"Permission denied for '{file_path}'.")

# %%
def get_last_geom(dft_output_file_path: Path):
    """
    Input: A filepath to a DFT output file (orca)
    """

    file_name = dft_output_file_path

    captured_geom_blocks = []

    #empty string to store captured geom lines
    geom_block = []
    geom_block_list = []
    
    #regex match pattern
    END_PATTERN = '^-'
    
    #turn off printing as default
    printing = False
    found_start = False

    #read through a file line-by-line
    with open(file_name, "r") as file:
        for line in file:
            #Read through lines until hitting the Final Geometry Block indicator in text
            if line.strip().startswith("CARTESIAN COORDINATES (ANGSTROEM)"):
                #once the line has been found, indicate that it's time to start printing lines
                found_start = True
                #stops the current loop iteration and goes to the next line
                continue
    
            #once a loop iter hits the end pattern, do one of two things:	
            elif re.match(END_PATTERN, line):
    
                #if a second end (the last '---' is hit, stop printing. 
                if printing:
                    found_start = False
                    printing = False
                    #get the current geom block and save it to a list
                    geom_block_list.append(geom_block)
                    #empty the geom block so the next can be captured
                    geom_block = []
                    continue
    
                #if a start has been found, capture lines
                #this skips the first --- right under the start line
                if found_start:
                    printing = True
                continue
    
            #if match is found, printing is "on"
            #print/capture the line
            if printing:
                geom_block.append(line.strip())
    
    #the last geometry in this list should be the optimized one
    #can confirm looking for "*** FINAL ENERGY EVALUATION AT THE STATIONARY POINT ***" line
    optimized_geom_raw = geom_block_list[-1]
    final_geom = []
    for line in optimized_geom_raw[:-1]:
        stripped = line.strip()
        geom_line = stripped.split()
        final_geom.append(geom_line)
        
    #convert the geometry to a pd DF
    geom_df = pd.DataFrame(final_geom, columns=["AtomID", "x", "y", "z"])
    #set the index to be from 1 rather than 0 - we will work from atom index indices
    #geom_df.index = pd.RangeIndex(1, len(geom_df.index) + 1)
    
    #note the atom indices are 0, not 1
    return geom_df

# %%
def strip_geometry_from_inp_orca5(input_file_as_list: list):
    """
    Function: Remove the .xyz coordinates in the * xyz i j * block of an orca iput file
    Input:
        - a list of lines corresponding to an input file
    Returns:
        - a list of the inp with the xyz coordinates removed
    """

    #Get the list index where the geom block starts explicitly (by line index) - avoid incorrectly
    #grabbing other *input* blocks this way, ex: solvent blocks/nbo blocks etc.
    geom_start_indx = [i for i, inp_line in enumerate(input_file_as_list) if r"* xyz" in inp_line][0]

    #error catch flag - if this is still -1 after looping, no second * was found (unlikely but robust)
    geom_end_indx = -1

    #starting at the geom start index, find the index of the next * in the input lines
    for i in range(geom_start_indx +1, len(input_file_as_list)):
        if input_file_as_list[i].strip().startswith('*'):
            geom_end_indx = int(i)

    start_del = geom_start_indx + 1
    end_del = geom_end_indx 
    # #confirm we've found the correct numbers
    # print(f"Target for deletion: {start_del}-{end_del}")

    #Remove lines between the two captured indices (should be just the geometry in .xyz's 
    chopped_input = input_file_as_list[:start_del] + input_file_as_list[end_del:]

    return chopped_input

# %%
def splice_new_geom_into_inp(list_of_lines_for_input: list, new_xyz_coords: list):
    """
    Function: 
    Input: 
        - list_of_lines_for_input: list - 
        - new_xyz_coords: list - 
    Returns:
        -
    """
    
    input_lines = list_of_lines_for_input
    xyz_to_insert = new_xyz_coords

    #find the list index of the input lines
    geom_start_indx = [i for i, inp_line in enumerate(input_lines) if r"* xyz" in inp_line][0]
    #we will start inserting our geom lines
    insert_indx = geom_start_indx + 1

    list_of_lines_for_input[insert_indx:insert_indx] = xyz_to_insert

    return list_of_lines_for_input

# %%
def extract_displacement_vectors_as_df(output_file_path: Path):
    """
    Extracts normal mode displacement vectors from an ORCA output file.
    """
    #capture the block of text between 'NORMAL MODES' and 'IR SPECTRUM'
    #this block contains the Normalized displacement vectors corresponding to 
    #individual normal vibrational modes - used to displace geometries along
    #specific modes

    displacement_vectors_raw = [] #capture the raw text for subsequent parsing
    collecting_displacements = False #start with capture "off" until start marker

    try:
        with FileReadBackwards(output_file_path, encoding="utf-8") as file:
        #with open(output_file_path, 'r') as f:
            for line in file:
                # Check for the main normal mode header
                if r"IR SPECTRUM" in line:
                    collecting_displacements = True
                    continue

                if collecting_displacements:
                    stripped_line = line.strip()

                    #just capture stripped lines that start with a #
                    if re.match(r"^\s*\d", stripped_line): 
                        displacement_vectors_raw.append(stripped_line) #capture the raw text

                    elif "NORMAL MODES" in line: #this is the TOP of the displacements block
                        break

    except FileNotFoundError:
        print(f"Error: The file {output_file_path} was not found.")
        return None
        
    except Exception as e:
        print(f"An error occurred during parsing: {e}")
        return None

    #reverse the order of the captured raw text
    displacement_vectors_raw.reverse()

    sections = []
    current_section = []
    
    #break the raw output block into sections of 6 displacements:
    for line in displacement_vectors_raw:
        split_line = line.split()
        if not split_line:
            continue
            
        num_elem_in_line = len(split_line)
    
        #header lines = 6 split values (6 displacement vectors per 'block')
        if num_elem_in_line == 6:
            #print(f'Separated Displacement Vectors: {line}')
            
            if current_section:
                sections.append(current_section)
    
            #start a new section beginning with this line
            current_section = [line]
            
        #displacement lines = 7 split values (an index int. followed by 6 floats
        elif num_elem_in_line == 7:
            if current_section:
                current_section.append(split_line[1:])
        #     else:
        #         # Handle case where a 7-element line appears before a 6-element start
        #         print(f"Warning: 7-element line found before a 6-element section start: {line}")
    
        # else: # Handle case where a 7-element line appears before a 6-element start
        #     print(f"Warning: 7-element line found before a 6-element section start: {line}")         
    
    if current_section:
        sections.append(current_section)
        
    # print(f"{output_file_path.name} contains {len(sections)} blocks of displacement vectors.")
    # print("")
    
    #make an empty df to store extracted displacement vectors
    displacement_df = pd.DataFrame()
    
    #
    for displacement_block in sections:
        #the first line of each extracted block contains the ID of the displacement vector
        #ex: the first line of the first block is '0 1 2 3 4 5' and corresponds to the 0, 1, 2nd 
        #displacement vectors
        block_first_line = displacement_block[0]
        #split the captured first line and store as column headers
        block_col_headers = list(map(int, block_first_line.split()))
    
        #make a block df using the extracted column headers and the add corresp. vector data beneath each
        block_df = pd.DataFrame(displacement_block[1:], columns=block_col_headers)
    
        #add the block's DF to the big DF containing all the displacement vectors
        displacement_df = pd.concat([displacement_df, block_df], axis=1)
    
    #this is the final displacement vector section as a pd dataframe
    return displacement_df

# %%
def write_resub_inp_for_failed_imag_freq(path_to_out_file: Path, path_to_resub_dir: Path):
    """
    Function:
    Inputs:
        -path_to_out_file
        -path_to_resub_dir
    Returns: 
        - 
    """
    #Specify a scaling factor (default is 0.1 right now)
    scaling_factor = 0.1

    file_name = path_to_out_file.stem

    #Get the last geom from .out file (has at least 1 IF)
    im_freq_geom = get_last_geom(path_to_out_file) #this is a pd DF

    #pull the raw freqs from the out file
    extracted_freqs = get_orca5_freqs(path_to_out_file)

    imag_indices = [i for i, freq in enumerate(extracted_freqs) if freq <0]
    # if imag_indices:
    #     print(f"\nIndices of imaginary freq(s): {imag_indices}")

    #in our present case I think/hope I can just adjust a single IF and resub
    if len(imag_indices) >= 1:
        imag_index = imag_indices[0]
    #need to add a way of handling multiple IFs/sorting by magnitude etc.
    #for now let's assume they have one/just use the first IF index

    #pull the displacement vector data from freq output
    displacement_df = extract_displacement_vectors_as_df(path_to_out_file)

    #get the displacement vector corresponding to the index of the imaginary freq
    imag_displacement_vector = displacement_df.iloc[:, imag_index]
    vector_list = imag_displacement_vector.tolist() #convert it to a list

    #convert the displacement vector list (1 col) to a 3 col numpy array (x y z): 
    three_col_displ_vector = np.array(vector_list).reshape(-1, 3).astype(float)

    #apply the specified scaling factor to the displacement array
    #this matrix determines how much each atom's coordinates will be moved by via addition
    displacement_scaled_array = np.multiply(three_col_displ_vector, scaling_factor)

    raw_geom =im_freq_geom.drop('AtomID', axis=1) #drop the atom ID from the input geom
    start_geom_array = raw_geom.to_numpy().astype(float) #convert the initial geom to a float array

    #apply the calculated displacement to the starting geom (make a new geom)
    new_geom_coords_array = start_geom_array + displacement_scaled_array
    df_from_numpy = pd.DataFrame(new_geom_coords_array) #convert the resulting np array to df

    #make a new df using OG atom list and the new xyz coords
    new_geom_df = im_freq_geom.iloc[:, :1] #get the atom ID col
    new_geom_df = pd.concat([new_geom_df, df_from_numpy ], axis=1) #add our newly calc. df 
    new_geom_df = np.round(new_geom_df, decimals = 6) #can round to diff. floats, here, 6)

    df_str = new_geom_df.astype(str) #df is now a string for writing
    new_geom_xyz = [' '.join(row) for row in df_str.values]

    ### Now have the new geometry; get the initial job params for resub
    inp_from_out = get_orca5_inp_from_out(path_to_out_file)
    
    #Rip out the current xyz coordinates from captured input:
    stripped_block = strip_geometry_from_inp_orca5(inp_from_out)

    #splice in our new geom:
    new_inp = splice_new_geom_into_inp(stripped_block, new_geom_xyz)
    #have to flatten the list into a \n-sep string for writing - annoying
    new_inp_as_str = '\n'.join(new_inp)
    new_inp_as_str += '\n'

    inp_file_name = file_name+".inp"
    write_path = path_to_resub_dir / inp_file_name
    write_path.parent.mkdir(parents=True, exist_ok=True) #make sure the dir exists
    write_path.write_text(new_inp_as_str, encoding='utf-8') #write the new .inp file
    print(f'New inp for resubmission of {file_name} written to /{path_to_resub_dir.stem}/')

# %%
def find_extra_inp_out_files_in_dirs(dir_with_out_files: Path, dir_with_inp_files: Path):
#This cell compares the filenames (no extension) of a dir with .out files and a dir with .inp files
#It will create and return a list of filenames that are in one directory but not the other
    print(f"\033[1mParsing specified .inp/.out directories for extra .inp/.out files....") #debug
    print(f"Directory with .out files: {dir_with_out_files}")
    print(f"Directory with .inp files: {dir_with_inp_files}\n")
       
    #dir_with_outs
    out_files = get_filepaths_in_target_dir_recursive(dir_with_out_files, ".out")
    print(f"\033[1mFound {len(out_files)} 'ORCA.out' DFT output files in /{dir_with_out_files.stem}/") #debug
    
    #dir_with_inps
    inp_files = get_filepaths_in_target_dir_recursive(dir_with_inp_files, ".inp")
    print(f"\033[1mFound {len(inp_files)} 'ORCA.inp' DFT input files in /{dir_with_inp_files.stem}/") #debug

    outs_no_ext = [] #stores the filenames of .outs in /out_dir
    for out_file in out_files:
        out_no_ext = out_file.stem
        outs_no_ext.append(out_no_ext)
        
    inps_no_ext = [] #stores the filenames of .inps in /inp_dir
    for inp_file in inp_files:
        inp_no_ext = inp_file.stem
        inps_no_ext.append(inp_no_ext)
    
    # print(inps_no_ext[:5]) #debug to check formatting
    # print(outs_no_ext[:5]) #debug to check formatting

    #give some info back to user about where the extra files are and calc. the set difference 
    if len(outs_no_ext) > len(inps_no_ext):
        difference_list = set(outs_no_ext) ^ set(inps_no_ext)
        if len(difference_list) > 0:
            print(f"\nYou are missing .inps; {len(difference_list)} Missing .inps!\nLengths: outs = {len(outs_no_ext)}, .inps = {len(inps_no_ext)}")

        else:
            print(f"\nYou have extra .outs; Make sure you remove any extraneous .outs from reruns;\n.outs= {len(outs_no_ext)}, .inps = {len(inps_no_ext)}")
        
    elif len(inps_no_ext) > len(outs_no_ext):
        difference_list = set(outs_no_ext) ^ set(inps_no_ext)
        print(f"\nMore .inps than .outs; {len(difference_list)} missing .outs!\nLengths: .outs = {len(outs_no_ext)}, .inps = {len(inps_no_ext)}")
        
    else:
        difference_list = set(outs_no_ext) ^ set(inps_no_ext)
        print(f"\nNumber of .inps and .outs match!\nLengths: .outs = {len(outs_no_ext)}, .inps = {len(inps_no_ext)}")
    
    if len(difference_list) > 0: 
        #print(f'Number of extra files: {len(difference_list)}')
        print(f'\nMissing File Names:')
        for file in difference_list:
            print(f'\t{file}')

        return difference_list

    elif len(difference_list) == 0:
        return False #can pass a false as there's no difference between sets

# %%
def find_and_del_replaced_outs(path_to_success_outs: Path, path_to_failed_outs: Path):
    """
    Function: Searches your /failed_dir/ for any .out files that have been replaced by valid .outs in /success.
        ex: you re-ran 100 jobs that had IFs (and hence were in /failed/IFs dir) and 99 of them were successful;
        After downloading the second-pass .outs, this method is used to clear the replaced jobs in /IF 
        
    Input:
        -path_to_out_files: path to a directory containing orca.out files
        -path_to_failed_files: path to a directory containing old/potentially outdated .out files
    Returns:
        - 
    """

    #specify a dir with good jobs and 1 with bad/failed jobs
    target_success_dir = path_to_success_outs
    parent_success = target_success_dir.parent
    parent_success_name = parent_success.name
    
    target_fail_dir = path_to_failed_outs

    #get all the failed jobs in /failed dir
    fail_outs = get_filepaths_in_target_dir_recursive(target_fail_dir, ".out")
    print(f'Found {len(fail_outs)} failed ORCA.out files in /{target_fail_dir.stem}/.')

    num_deleted = 0
    
    #loop through the list of failed jobs and see if the same job exists in the "good" dir
    for fail_out in fail_outs:
        fail_filename = fail_out.name #get just the extension
        #print(fail_filename)

        #create a dir to check /success with - does /success have the same file name (bad has been replaced)
        file_dir_to_check = target_success_dir / fail_filename
        #print(f"searching for: {file_dir_to_check} in /success_dir.")

        if file_dir_to_check.is_file(): #if the .out file exists in /success, 
            print(f"Found successful '{file_dir_to_check.name}' in /{parent_success_name}/. Deleting redundant .out in /{target_fail_dir.stem}/")
            try:
                fail_out.unlink(missing_ok=True) # delete the .out file in /fail (it's been fixed)
                num_deleted += 1
            except: 
                print(f"Error: File '{fail_out}' not found.")

    if num_deleted > 0:
        print(f"\nDeleted {num_deleted} extraneous .out files from {target_fail_dir}.")

# %%
""" ### Perform Initial Pass/Fail Sort of arene.outs ### 

This cell performs a first pass/fail triage of any .out file in the targeted directory. It is looking
for 'Normal Termination' on the jobs as a minimum first pass - any failed convergence calcs are sent to
/failed_jobs for resubmission after generating a new .inp. Note - running this cell alone is not enough
to validate an .out file - you MUST verify (using the cell below) that the geometry corresponds to a 
minimum with no imaginary frequencies. 
"""

target_dir = arene_dft_output_path
print(f"\033[1mPerforming initial Pass/Fail triage of .out files in '/{target_dir.stem}/\033[0m'...\n")

output_files = get_filepaths_in_target_dir_recursive(target_dir, ".out")

#Print the first 5 paths for debug
for out_file in output_files[:5]:
    print(out_file)
print(f"...\n")

### First Pass Triage of Outputs - Do they terminate normally, fail to reach convergence, or fail totally
for out_file in output_files:
    sort_complete_fail_jobs_orca5(out_file)

print(f"\033[1m\nFinished Pass/Fail triage of {len(output_files)} .out files in '/{target_dir.stem}/\033[0m'")

initial_pass_fail = get_filepaths_in_target_dir_recursive(arene_failed_to_terminate, ".out")
# Out:
# Performing initial Pass/Fail triage of .out files in '/Arene_Orca_DFT_Outputs/'...
#
# Found 8247 .out files in '/Arene_Orca_DFT_Outputs/' (recursive)
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\Failed_Calculations\Convergence_Failure\arene_96_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\Failed_Calculations\Convergence_Failure\arene_239_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\Failed_Calculations\Convergence_Failure\arene_322_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\Failed_Calculations\Convergence_Failure\arene_509_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\Failed_Calculations\Convergence_Failure\arene_679_rdkit_conf_1.out
# ...
#
#
# Finished Pass/Fail triage of 8247 .out files in '/Arene_Orca_DFT_Outputs/'
# Found 194 .out files in '/Failed_Calculations/' (recursive)

# %%
""" ### Perform an Explicit Check for Optimization Convergence ###

This cell uses the 'check_opt_convergence()' and 'check_outs_for_convergence()'  methods to check .out files for explicit 
convergence success. Jobs that fail the check are moved to the /Failed_Calculations/Convergence_Failure directory. 

Note: This is a somewhat expensive file parsing task (likely the costliest in this notebook) and is 1:1 success-wise with
just checking for 'Normal Termination' with the 'sort_complete_fail_jobs_orca5()' method employed by the cell above....so
you don't really need to run this cell (I don't think), but it's a good check for the sake of completion. 

It's much slower as you're reading every line of an out file rather than only ~ 100 with the above method. 
"""

#Print some information to the user about how many files in the target directory
target_dir = arene_dft_output_path
print(f"\033[1mAnalyzing potentially valid .out files in '/{target_dir.stem}/' for optimization convergence...\033[0m\n")

#gather .out files in a target dir
output_files = get_filepaths_in_target_dir(target_dir, ".out")

#print out the first 5 jobs/paths for debug
for out_file in output_files[:5]:
    print(out_file)
print(f"...\n")

#employ the check_outs_for_convergence method to pass/fail jobs
num_passed, num_failed = check_outs_for_convergence(arene_dft_output_path, arene_no_convergence_dir)

#print how many successful jobs 
print(f"\033[1m\nOutput files in '/{target_dir.stem}/' with validated convergence: {num_passed}\033[0m")
#there likely won't be any failed outs 
if num_failed >= 1:
    print(f"\033[1mMoved {num_failed} failed convergence .outs to '/{arene_no_convergence_dir.stem}/' \033[0m")
# Out:
# Analyzing potentially valid .out files in '/Arene_Orca_DFT_Outputs/' for optimization convergence...
#
# Found 8053 .out files in '/Arene_Orca_DFT_Outputs/'
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene
# 	arene_8226_rdkit_conf_1.out: Optimization Converged
# 	arene_8227_rdkit_conf_1.out: Optimization Converged
# 	arene_8228_rdkit_conf_1.out: Optimization Converged
# 	arene_8229_rdkit_conf_1.out: Optimization Converged
# 	arene_8230_rdkit_conf_1.out: Optimization Converged
# 	arene_8232_rdkit_conf_1.out: Optimization Converged
# 	arene_8233_rdkit_conf_1.out: Optimization Converged
# 	arene_8234_rdkit_conf_1.out: Optimization Converged
# 	arene_8235_rdkit_conf_1.out: Optimization Converged
# 	arene_8236_rdkit_conf_1.out: Optimization Converged
# 	arene_8237_rdkit_conf_1.out: Optimization Converged
# 	arene_8238_rdkit_conf_1.out: Optimization Converged
# 	arene_8239_rdkit_conf_1.out: Optimization Converged
# 	arene_8240_rdkit_conf_1.out: Optimization Converged
# 	arene_8241_rdkit_conf_1.out: Optimization Converged
# 	arene_8242_rdkit_conf_1.out: Optimization Converged
# 	arene_8243_rdkit_conf_1.out: Optimization Converged
# 	arene_8244_rdkit_conf_1.out: Optimization Converged
# 	arene_8245_rdkit_conf_1.out: Optimization Converged
# 	arene_8246_rdkit_conf_1.out: Optimization Converged
# 	arene_8247_rdkit_conf_1.out: Optimization Converged
#
# Output files in '/Arene_Orca_DFT_Outputs/' with validated convergence: 8053

# %%
""" ### Perform FREQ analysis on ARENES ### 
This cell checks any .out that was deemed "potentially valid" by the preceding cell and checks the calc for
imaginary frequencies. Minima must have 0 imaginary frequencies, so if a job has one +, it is deemed a 
failure. These jobs can be reset, below, to try to remove the IF on a second pass. 
"""

target_dir = arene_dft_output_path
print(f"\033[1mAnalyzing frequency data in potentially valid .out files in '/{target_dir.stem}/\033[0m'...\n")

#gather .out files in a target dir
output_files = get_filepaths_in_target_dir(target_dir, ".out")

#print out the first 5 jobs/paths for debug
for out_file in output_files[:5]:
    print(out_file)
print(f"...\n")

#place to shove bad if calcs
imag_freq_dir = arene_im_freq_dir

#Loop over each .out file and determine if they have an IF or more
list_of_mol_freqs = []
for out_file in output_files:
    #check if the .out file contains any frequency data
    result = does_out_contain_freq_data(out_file)

    if result: #if true, file has frequency data in it
        extracted_freqs = get_orca5_freqs(out_file) #extract the frequency block

        #check if any of the extracted freqs are imaginary (condition of valid calc)
        freq_test_failed = has_imaginary_freqs_check(extracted_freqs)

        if freq_test_failed: #calculation has at least one IF (bad)
            #move the file to an error dir /no_freq_data/
            destination_file_path = imag_freq_dir / out_file.name
            try:
                shutil.move(out_file, destination_file_path)
                print(f"\t{out_file.name}: \tIMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.")
            except FileNotFoundError:
                print(f"Error: Source file not found at {out_file.parent}")
            except shutil.SameFileError:
                print(f"\tSkipped '{out_file.name}', already exists in destination.")
            except Exception as e:
                print(f"\tError copying {out_file.name}: {e}")
                
        else: #No imaginary frequncy found in calc => it's probably great
            print(f"\t{out_file.name}: Valid Calc")

print(f"\033[1m\nCompleted analysis of frequency data for .out files in '/{target_dir.stem}/'\033[0m")

failed_freqs = get_filepaths_in_target_dir(imag_freq_dir, ".out", printing=False)
if failed_freqs:
    print(f"\033[1m\nNumber of failed .outs due to imaginary frequencies: {len(failed_freqs)}\033[0m")
# Out:
# Analyzing frequency data in potentially valid .out files in '/Arene_Orca_DFT_Outputs/'...
#
# Found 8053 .out files in '/Arene_Orca_DFT_Outputs/'
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene_1_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene_2_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene_3_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene_4_rdkit_conf_1.out
# C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs\arene_5_rdkit_conf_1.out
# ...
#
# 	arene_1_rdkit_conf_1.out: Valid Calc
# 	arene_2_rdkit_conf_1.out: Valid Calc
# 	arene_3_rdkit_conf_1.out: Valid Calc
# 	arene_4_rdkit_conf_1.out: Valid Calc
# 	arene_5_rdkit_conf_1.out: Valid Calc
# 	arene_6_rdkit_conf_1.out: Valid Calc
# 	arene_7_rdkit_conf_1.out: Valid Calc
# 	arene_8_rdkit_conf_1.out: Valid Calc
# 	arene_9_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_10_rdkit_conf_1.out: Valid Calc
# 	arene_11_rdkit_conf_1.out: Valid Calc
# 	arene_12_rdkit_conf_1.out: Valid Calc
# 	arene_13_rdkit_conf_1.out: Valid Calc
# 	arene_14_rdkit_conf_1.out: Valid Calc
# 	arene_15_rdkit_conf_1.out: Valid Calc
# 	arene_16_rdkit_conf_1.out: Valid Calc
# 	arene_17_rdkit_conf_1.out: Valid Calc
# 	arene_18_rdkit_conf_1.out: Valid Calc
# 	arene_19_rdkit_conf_1.out: Valid Calc
# 	arene_20_rdkit_conf_1.out: Valid Calc
# 	arene_21_rdkit_conf_1.out: Valid Calc
# 	arene_22_rdkit_conf_1.out: Valid Calc
# 	arene_23_rdkit_conf_1.out: Valid Calc
# 	arene_24_rdkit_conf_1.out: Valid Calc
# 	arene_25_rdkit_conf_1.out: Valid Calc
# 	arene_26_rdkit_conf_1.out: Valid Calc
# 	arene_27_rdkit_conf_1.out: Valid Calc
# 	arene_28_rdkit_conf_1.out: Valid Calc
# 	arene_29_rdkit_conf_1.out: Valid Calc
# 	arene_30_rdkit_conf_1.out: Valid Calc
# 	arene_31_rdkit_conf_1.out: Valid Calc
# 	arene_32_rdkit_conf_1.out: Valid Calc
# 	arene_33_rdkit_conf_1.out: Valid Calc
# 	arene_34_rdkit_conf_1.out: Valid Calc
# 	arene_35_rdkit_conf_1.out: Valid Calc
# 	arene_36_rdkit_conf_1.out: Valid Calc
# 	arene_37_rdkit_conf_1.out: Valid Calc
# 	arene_38_rdkit_conf_1.out: Valid Calc
# 	arene_39_rdkit_conf_1.out: Valid Calc
# 	arene_40_rdkit_conf_1.out: Valid Calc
# 	arene_41_rdkit_conf_1.out: Valid Calc
# 	arene_42_rdkit_conf_1.out: Valid Calc
# 	arene_43_rdkit_conf_1.out: Valid Calc
# 	arene_44_rdkit_conf_1.out: Valid Calc
# 	arene_45_rdkit_conf_1.out: Valid Calc
# 	arene_46_rdkit_conf_1.out: Valid Calc
# 	arene_47_rdkit_conf_1.out: Valid Calc
# 	arene_48_rdkit_conf_1.out: Valid Calc
# 	arene_49_rdkit_conf_1.out: Valid Calc
# 	arene_50_rdkit_conf_1.out: Valid Calc
# 	arene_51_rdkit_conf_1.out: Valid Calc
# 	arene_52_rdkit_conf_1.out: Valid Calc
# 	arene_53_rdkit_conf_1.out: Valid Calc
# 	arene_54_rdkit_conf_1.out: Valid Calc
# 	arene_55_rdkit_conf_1.out: Valid Calc
# 	arene_56_rdkit_conf_1.out: Valid Calc
# 	arene_57_rdkit_conf_1.out: Valid Calc
# 	arene_58_rdkit_conf_1.out: Valid Calc
# 	arene_59_rdkit_conf_1.out: Valid Calc
# 	arene_60_rdkit_conf_1.out: Valid Calc
# 	arene_61_rdkit_conf_1.out: Valid Calc
# 	arene_62_rdkit_conf_1.out: Valid Calc
# 	arene_63_rdkit_conf_1.out: Valid Calc
# 	arene_64_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_65_rdkit_conf_1.out: Valid Calc
# 	arene_66_rdkit_conf_1.out: Valid Calc
# 	arene_67_rdkit_conf_1.out: Valid Calc
# 	arene_68_rdkit_conf_1.out: Valid Calc
# 	arene_69_rdkit_conf_1.out: Valid Calc
# 	arene_70_rdkit_conf_1.out: Valid Calc
# 	arene_71_rdkit_conf_1.out: Valid Calc
# 	arene_72_rdkit_conf_1.out: Valid Calc
# 	arene_73_rdkit_conf_1.out: Valid Calc
# 	arene_74_rdkit_conf_1.out: Valid Calc
# 	arene_75_rdkit_conf_1.out: Valid Calc
# 	arene_76_rdkit_conf_1.out: Valid Calc
# 	arene_77_rdkit_conf_1.out: Valid Calc
# 	arene_78_rdkit_conf_1.out: Valid Calc
# 	arene_79_rdkit_conf_1.out: Valid Calc
# 	arene_80_rdkit_conf_1.out: Valid Calc
# 	arene_81_rdkit_conf_1.out: Valid Calc
# 	arene_82_rdkit_conf_1.out: Valid Calc
# 	arene_83_rdkit_conf_1.out: Valid Calc
# 	arene_84_rdkit_conf_1.out: Valid Calc
# 	arene_85_rdkit_conf_1.out: Valid Calc
# 	arene_86_rdkit_conf_1.out: Valid Calc
# 	arene_87_rdkit_conf_1.out: Valid Calc
# 	arene_88_rdkit_conf_1.out: Valid Calc
# 	arene_89_rdkit_conf_1.out: Valid Calc
# 	arene_90_rdkit_conf_1.out: Valid Calc
# 	arene_91_rdkit_conf_1.out: Valid Calc
# 	arene_92_rdkit_conf_1.out: Valid Calc
# 	arene_93_rdkit_conf_1.out: Valid Calc
# 	arene_94_rdkit_conf_1.out: Valid Calc
# 	arene_95_rdkit_conf_1.out: Valid Calc
# 	arene_97_rdkit_conf_1.out: Valid Calc
# 	arene_98_rdkit_conf_1.out: Valid Calc
# 	arene_99_rdkit_conf_1.out: Valid Calc
# 	arene_100_rdkit_conf_1.out: Valid Calc
# 	arene_101_rdkit_conf_1.out: Valid Calc
# 	arene_102_rdkit_conf_1.out: Valid Calc
# 	arene_103_rdkit_conf_1.out: Valid Calc
# 	arene_104_rdkit_conf_1.out: Valid Calc
# 	arene_105_rdkit_conf_1.out: Valid Calc
# 	arene_106_rdkit_conf_1.out: Valid Calc
# 	arene_107_rdkit_conf_1.out: Valid Calc
# 	arene_108_rdkit_conf_1.out: Valid Calc
# 	arene_109_rdkit_conf_1.out: Valid Calc
# 	arene_110_rdkit_conf_1.out: Valid Calc
# 	arene_111_rdkit_conf_1.out: Valid Calc
# 	arene_112_rdkit_conf_1.out: Valid Calc
# 	arene_113_rdkit_conf_1.out: Valid Calc
# 	arene_114_rdkit_conf_1.out: Valid Calc
# 	arene_115_rdkit_conf_1.out: Valid Calc
# 	arene_116_rdkit_conf_1.out: Valid Calc
# 	arene_117_rdkit_conf_1.out: Valid Calc
# 	arene_118_rdkit_conf_1.out: Valid Calc
# 	arene_119_rdkit_conf_1.out: Valid Calc
# 	arene_120_rdkit_conf_1.out: Valid Calc
# 	arene_121_rdkit_conf_1.out: Valid Calc
# 	arene_122_rdkit_conf_1.out: Valid Calc
# 	arene_123_rdkit_conf_1.out: Valid Calc
# 	arene_124_rdkit_conf_1.out: Valid Calc
# 	arene_125_rdkit_conf_1.out: Valid Calc
# 	arene_126_rdkit_conf_1.out: Valid Calc
# 	arene_127_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_128_rdkit_conf_1.out: Valid Calc
# 	arene_129_rdkit_conf_1.out: Valid Calc
# 	arene_130_rdkit_conf_1.out: Valid Calc
# 	arene_131_rdkit_conf_1.out: Valid Calc
# 	arene_132_rdkit_conf_1.out: Valid Calc
# 	arene_133_rdkit_conf_1.out: Valid Calc
# 	arene_134_rdkit_conf_1.out: Valid Calc
# 	arene_135_rdkit_conf_1.out: Valid Calc
# 	arene_136_rdkit_conf_1.out: Valid Calc
# 	arene_137_rdkit_conf_1.out: Valid Calc
# 	arene_138_rdkit_conf_1.out: Valid Calc
# 	arene_139_rdkit_conf_1.out: Valid Calc
# 	arene_140_rdkit_conf_1.out: Valid Calc
# 	arene_141_rdkit_conf_1.out: Valid Calc
# 	arene_142_rdkit_conf_1.out: Valid Calc
# 	arene_143_rdkit_conf_1.out: Valid Calc
# 	arene_144_rdkit_conf_1.out: Valid Calc
# 	arene_145_rdkit_conf_1.out: Valid Calc
# 	arene_146_rdkit_conf_1.out: Valid Calc
# 	arene_147_rdkit_conf_1.out: Valid Calc
# 	arene_148_rdkit_conf_1.out: Valid Calc
# 	arene_149_rdkit_conf_1.out: Valid Calc
# 	arene_150_rdkit_conf_1.out: Valid Calc
# 	arene_151_rdkit_conf_1.out: Valid Calc
# 	arene_152_rdkit_conf_1.out: Valid Calc
# 	arene_153_rdkit_conf_1.out: Valid Calc
# 	arene_154_rdkit_conf_1.out: Valid Calc
# 	arene_155_rdkit_conf_1.out: Valid Calc
# 	arene_156_rdkit_conf_1.out: Valid Calc
# 	arene_157_rdkit_conf_1.out: Valid Calc
# 	arene_158_rdkit_conf_1.out: Valid Calc
# 	arene_159_rdkit_conf_1.out: Valid Calc
# 	arene_160_rdkit_conf_1.out: Valid Calc
# 	arene_161_rdkit_conf_1.out: Valid Calc
# 	arene_162_rdkit_conf_1.out: Valid Calc
# 	arene_163_rdkit_conf_1.out: Valid Calc
# 	arene_164_rdkit_conf_1.out: Valid Calc
# 	arene_165_rdkit_conf_1.out: Valid Calc
# 	arene_166_rdkit_conf_1.out: Valid Calc
# 	arene_167_rdkit_conf_1.out: Valid Calc
# 	arene_168_rdkit_conf_1.out: Valid Calc
# 	arene_169_rdkit_conf_1.out: Valid Calc
# 	arene_170_rdkit_conf_1.out: Valid Calc
# 	arene_171_rdkit_conf_1.out: Valid Calc
# 	arene_172_rdkit_conf_1.out: Valid Calc
# 	arene_173_rdkit_conf_1.out: Valid Calc
# 	arene_174_rdkit_conf_1.out: Valid Calc
# 	arene_175_rdkit_conf_1.out: Valid Calc
# 	arene_176_rdkit_conf_1.out: Valid Calc
# 	arene_177_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_178_rdkit_conf_1.out: Valid Calc
# 	arene_179_rdkit_conf_1.out: Valid Calc
# 	arene_180_rdkit_conf_1.out: Valid Calc
# 	arene_181_rdkit_conf_1.out: Valid Calc
# 	arene_182_rdkit_conf_1.out: Valid Calc
# 	arene_183_rdkit_conf_1.out: Valid Calc
# 	arene_184_rdkit_conf_1.out: Valid Calc
# 	arene_185_rdkit_conf_1.out: Valid Calc
# 	arene_186_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_187_rdkit_conf_1.out: Valid Calc
# 	arene_188_rdkit_conf_1.out: Valid Calc
# 	arene_189_rdkit_conf_1.out: Valid Calc
# 	arene_190_rdkit_conf_1.out: Valid Calc
# 	arene_191_rdkit_conf_1.out: Valid Calc
# 	arene_192_rdkit_conf_1.out: Valid Calc
# 	arene_193_rdkit_conf_1.out: Valid Calc
# 	arene_194_rdkit_conf_1.out: Valid Calc
# 	arene_195_rdkit_conf_1.out: Valid Calc
# 	arene_196_rdkit_conf_1.out: Valid Calc
# 	arene_197_rdkit_conf_1.out: Valid Calc
# 	arene_198_rdkit_conf_1.out: Valid Calc
# 	arene_199_rdkit_conf_1.out: Valid Calc
# 	arene_200_rdkit_conf_1.out: Valid Calc
# 	arene_201_rdkit_conf_1.out: Valid Calc
# 	arene_202_rdkit_conf_1.out: Valid Calc
# 	arene_203_rdkit_conf_1.out: Valid Calc
# 	arene_204_rdkit_conf_1.out: Valid Calc
# 	arene_205_rdkit_conf_1.out: Valid Calc
# 	arene_206_rdkit_conf_1.out: Valid Calc
# 	arene_207_rdkit_conf_1.out: Valid Calc
# 	arene_208_rdkit_conf_1.out: Valid Calc
# 	arene_209_rdkit_conf_1.out: Valid Calc
# 	arene_210_rdkit_conf_1.out: Valid Calc
# 	arene_211_rdkit_conf_1.out: Valid Calc
# 	arene_212_rdkit_conf_1.out: Valid Calc
# 	arene_213_rdkit_conf_1.out: Valid Calc
# 	arene_214_rdkit_conf_1.out: Valid Calc
# 	arene_215_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_216_rdkit_conf_1.out: Valid Calc
# 	arene_217_rdkit_conf_1.out: Valid Calc
# 	arene_218_rdkit_conf_1.out: Valid Calc
# 	arene_219_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_220_rdkit_conf_1.out: Valid Calc
# 	arene_221_rdkit_conf_1.out: Valid Calc
# 	arene_222_rdkit_conf_1.out: Valid Calc
# 	arene_223_rdkit_conf_1.out: Valid Calc
# 	arene_224_rdkit_conf_1.out: Valid Calc
# 	arene_225_rdkit_conf_1.out: Valid Calc
# 	arene_226_rdkit_conf_1.out: Valid Calc
# 	arene_227_rdkit_conf_1.out: Valid Calc
# 	arene_228_rdkit_conf_1.out: Valid Calc
# 	arene_229_rdkit_conf_1.out: Valid Calc
# 	arene_230_rdkit_conf_1.out: Valid Calc
# 	arene_231_rdkit_conf_1.out: Valid Calc
# 	arene_232_rdkit_conf_1.out: Valid Calc
# 	arene_233_rdkit_conf_1.out: Valid Calc
# 	arene_234_rdkit_conf_1.out: Valid Calc
# 	arene_235_rdkit_conf_1.out: Valid Calc
# 	arene_236_rdkit_conf_1.out: Valid Calc
# 	arene_237_rdkit_conf_1.out: Valid Calc
# 	arene_238_rdkit_conf_1.out: Valid Calc
# 	arene_240_rdkit_conf_1.out: Valid Calc
# 	arene_241_rdkit_conf_1.out: Valid Calc
# 	arene_242_rdkit_conf_1.out: Valid Calc
# 	arene_243_rdkit_conf_1.out: Valid Calc
# 	arene_244_rdkit_conf_1.out: Valid Calc
# 	arene_245_rdkit_conf_1.out: Valid Calc
# 	arene_246_rdkit_conf_1.out: Valid Calc
# 	arene_247_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_248_rdkit_conf_1.out: Valid Calc
# 	arene_249_rdkit_conf_1.out: Valid Calc
# 	arene_250_rdkit_conf_1.out: Valid Calc
# 	arene_251_rdkit_conf_1.out: Valid Calc
# 	arene_252_rdkit_conf_1.out: Valid Calc
# 	arene_253_rdkit_conf_1.out: Valid Calc
# 	arene_254_rdkit_conf_1.out: Valid Calc
# 	arene_255_rdkit_conf_1.out: Valid Calc
# 	arene_256_rdkit_conf_1.out: Valid Calc
# 	arene_257_rdkit_conf_1.out: Valid Calc
# 	arene_258_rdkit_conf_1.out: Valid Calc
# 	arene_259_rdkit_conf_1.out: Valid Calc
# 	arene_260_rdkit_conf_1.out: Valid Calc
# 	arene_261_rdkit_conf_1.out: Valid Calc
# 	arene_262_rdkit_conf_1.out: Valid Calc
# 	arene_263_rdkit_conf_1.out: Valid Calc
# 	arene_264_rdkit_conf_1.out: Valid Calc
# 	arene_265_rdkit_conf_1.out: Valid Calc
# 	arene_266_rdkit_conf_1.out: Valid Calc
# 	arene_267_rdkit_conf_1.out: Valid Calc
# 	arene_268_rdkit_conf_1.out: Valid Calc
# 	arene_269_rdkit_conf_1.out: Valid Calc
# 	arene_270_rdkit_conf_1.out: Valid Calc
# 	arene_271_rdkit_conf_1.out: Valid Calc
# 	arene_272_rdkit_conf_1.out: Valid Calc
# 	arene_273_rdkit_conf_1.out: Valid Calc
# 	arene_274_rdkit_conf_1.out: Valid Calc
# 	arene_275_rdkit_conf_1.out: Valid Calc
# 	arene_276_rdkit_conf_1.out: Valid Calc
# 	arene_277_rdkit_conf_1.out: Valid Calc
# 	arene_278_rdkit_conf_1.out: Valid Calc
# 	arene_279_rdkit_conf_1.out: Valid Calc
# 	arene_280_rdkit_conf_1.out: Valid Calc
# 	arene_281_rdkit_conf_1.out: Valid Calc
# 	arene_282_rdkit_conf_1.out: Valid Calc
# 	arene_283_rdkit_conf_1.out: Valid Calc
# 	arene_284_rdkit_conf_1.out: Valid Calc
# 	arene_285_rdkit_conf_1.out: Valid Calc
# 	arene_286_rdkit_conf_1.out: Valid Calc
# 	arene_287_rdkit_conf_1.out: Valid Calc
# 	arene_288_rdkit_conf_1.out: Valid Calc
# 	arene_289_rdkit_conf_1.out: Valid Calc
# 	arene_290_rdkit_conf_1.out: Valid Calc
# 	arene_291_rdkit_conf_1.out: Valid Calc
# 	arene_292_rdkit_conf_1.out: Valid Calc
# 	arene_293_rdkit_conf_1.out: Valid Calc
# 	arene_294_rdkit_conf_1.out: Valid Calc
# 	arene_295_rdkit_conf_1.out: Valid Calc
# 	arene_296_rdkit_conf_1.out: Valid Calc
# 	arene_297_rdkit_conf_1.out: Valid Calc
# 	arene_298_rdkit_conf_1.out: Valid Calc
# 	arene_299_rdkit_conf_1.out: Valid Calc
# 	arene_300_rdkit_conf_1.out: Valid Calc
# 	arene_301_rdkit_conf_1.out: Valid Calc
# 	arene_302_rdkit_conf_1.out: Valid Calc
# 	arene_303_rdkit_conf_1.out: Valid Calc
# 	arene_304_rdkit_conf_1.out: Valid Calc
# 	arene_305_rdkit_conf_1.out: Valid Calc
# 	arene_306_rdkit_conf_1.out: Valid Calc
# 	arene_307_rdkit_conf_1.out: Valid Calc
# 	arene_308_rdkit_conf_1.out: Valid Calc
# 	arene_309_rdkit_conf_1.out: Valid Calc
# 	arene_310_rdkit_conf_1.out: Valid Calc
# 	arene_311_rdkit_conf_1.out: Valid Calc
# 	arene_312_rdkit_conf_1.out: Valid Calc
# 	arene_313_rdkit_conf_1.out: Valid Calc
# 	arene_314_rdkit_conf_1.out: Valid Calc
# 	arene_315_rdkit_conf_1.out: Valid Calc
# 	arene_316_rdkit_conf_1.out: Valid Calc
# 	arene_317_rdkit_conf_1.out: Valid Calc
# 	arene_318_rdkit_conf_1.out: Valid Calc
# 	arene_319_rdkit_conf_1.out: Valid Calc
# 	arene_320_rdkit_conf_1.out: Valid Calc
# 	arene_321_rdkit_conf_1.out: Valid Calc
# 	arene_323_rdkit_conf_1.out: Valid Calc
# 	arene_324_rdkit_conf_1.out: Valid Calc
# 	arene_325_rdkit_conf_1.out: Valid Calc
# 	arene_326_rdkit_conf_1.out: Valid Calc
# 	arene_327_rdkit_conf_1.out: Valid Calc
# 	arene_328_rdkit_conf_1.out: Valid Calc
# 	arene_329_rdkit_conf_1.out: Valid Calc
# 	arene_330_rdkit_conf_1.out: Valid Calc
# 	arene_331_rdkit_conf_1.out: Valid Calc
# 	arene_332_rdkit_conf_1.out: Valid Calc
# 	arene_333_rdkit_conf_1.out: Valid Calc
# 	arene_334_rdkit_conf_1.out: Valid Calc
# 	arene_335_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_336_rdkit_conf_1.out: Valid Calc
# 	arene_337_rdkit_conf_1.out: Valid Calc
# 	arene_338_rdkit_conf_1.out: Valid Calc
# 	arene_339_rdkit_conf_1.out: Valid Calc
# 	arene_340_rdkit_conf_1.out: Valid Calc
# 	arene_341_rdkit_conf_1.out: Valid Calc
# 	arene_342_rdkit_conf_1.out: Valid Calc
# 	arene_343_rdkit_conf_1.out: Valid Calc
# 	arene_344_rdkit_conf_1.out: Valid Calc
# 	arene_345_rdkit_conf_1.out: Valid Calc
# 	arene_346_rdkit_conf_1.out: Valid Calc
# 	arene_347_rdkit_conf_1.out: Valid Calc
# 	arene_348_rdkit_conf_1.out: Valid Calc
# 	arene_349_rdkit_conf_1.out: Valid Calc
# 	arene_350_rdkit_conf_1.out: Valid Calc
# 	arene_351_rdkit_conf_1.out: Valid Calc
# 	arene_352_rdkit_conf_1.out: Valid Calc
# 	arene_353_rdkit_conf_1.out: Valid Calc
# 	arene_354_rdkit_conf_1.out: Valid Calc
# 	arene_355_rdkit_conf_1.out: Valid Calc
# 	arene_356_rdkit_conf_1.out: Valid Calc
# 	arene_357_rdkit_conf_1.out: Valid Calc
# 	arene_358_rdkit_conf_1.out: Valid Calc
# 	arene_359_rdkit_conf_1.out: Valid Calc
# 	arene_360_rdkit_conf_1.out: Valid Calc
# 	arene_361_rdkit_conf_1.out: Valid Calc
# 	arene_362_rdkit_conf_1.out: Valid Calc
# 	arene_363_rdkit_conf_1.out: Valid Calc
# 	arene_364_rdkit_conf_1.out: Valid Calc
# 	arene_365_rdkit_conf_1.out: Valid Calc
# 	arene_366_rdkit_conf_1.out: Valid Calc
# 	arene_367_rdkit_conf_1.out: Valid Calc
# 	arene_368_rdkit_conf_1.out: Valid Calc
# 	arene_369_rdkit_conf_1.out: Valid Calc
# 	arene_370_rdkit_conf_1.out: Valid Calc
# 	arene_371_rdkit_conf_1.out: Valid Calc
# 	arene_372_rdkit_conf_1.out: Valid Calc
# 	arene_373_rdkit_conf_1.out: Valid Calc
# 	arene_374_rdkit_conf_1.out: Valid Calc
# 	arene_375_rdkit_conf_1.out: Valid Calc
# 	arene_376_rdkit_conf_1.out: Valid Calc
# 	arene_377_rdkit_conf_1.out: Valid Calc
# 	arene_378_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_379_rdkit_conf_1.out: Valid Calc
# 	arene_380_rdkit_conf_1.out: Valid Calc
# 	arene_381_rdkit_conf_1.out: Valid Calc
# 	arene_382_rdkit_conf_1.out: Valid Calc
# 	arene_383_rdkit_conf_1.out: Valid Calc
# 	arene_384_rdkit_conf_1.out: Valid Calc
# 	arene_385_rdkit_conf_1.out: Valid Calc
# 	arene_386_rdkit_conf_1.out: Valid Calc
# 	arene_387_rdkit_conf_1.out: Valid Calc
# 	arene_388_rdkit_conf_1.out: Valid Calc
# 	arene_389_rdkit_conf_1.out: Valid Calc
# 	arene_390_rdkit_conf_1.out: Valid Calc
# 	arene_391_rdkit_conf_1.out: Valid Calc
# 	arene_392_rdkit_conf_1.out: Valid Calc
# 	arene_393_rdkit_conf_1.out: Valid Calc
# 	arene_394_rdkit_conf_1.out: Valid Calc
# 	arene_395_rdkit_conf_1.out: Valid Calc
# 	arene_396_rdkit_conf_1.out: Valid Calc
# 	arene_397_rdkit_conf_1.out: Valid Calc
# 	arene_398_rdkit_conf_1.out: Valid Calc
# 	arene_399_rdkit_conf_1.out: Valid Calc
# 	arene_400_rdkit_conf_1.out: Valid Calc
# 	arene_401_rdkit_conf_1.out: Valid Calc
# 	arene_402_rdkit_conf_1.out: Valid Calc
# 	arene_403_rdkit_conf_1.out: Valid Calc
# 	arene_404_rdkit_conf_1.out: Valid Calc
# 	arene_405_rdkit_conf_1.out: Valid Calc
# 	arene_406_rdkit_conf_1.out: Valid Calc
# 	arene_407_rdkit_conf_1.out: Valid Calc
# 	arene_408_rdkit_conf_1.out: Valid Calc
# 	arene_409_rdkit_conf_1.out: Valid Calc
# 	arene_410_rdkit_conf_1.out: Valid Calc
# 	arene_411_rdkit_conf_1.out: Valid Calc
# 	arene_412_rdkit_conf_1.out: Valid Calc
# 	arene_413_rdkit_conf_1.out: Valid Calc
# 	arene_414_rdkit_conf_1.out: Valid Calc
# 	arene_415_rdkit_conf_1.out: Valid Calc
# 	arene_416_rdkit_conf_1.out: Valid Calc
# 	arene_417_rdkit_conf_1.out: Valid Calc
# 	arene_418_rdkit_conf_1.out: Valid Calc
# 	arene_419_rdkit_conf_1.out: Valid Calc
# 	arene_420_rdkit_conf_1.out: Valid Calc
# 	arene_421_rdkit_conf_1.out: Valid Calc
# 	arene_422_rdkit_conf_1.out: Valid Calc
# 	arene_423_rdkit_conf_1.out: Valid Calc
# 	arene_424_rdkit_conf_1.out: Valid Calc
# 	arene_425_rdkit_conf_1.out: Valid Calc
# 	arene_426_rdkit_conf_1.out: Valid Calc
# 	arene_427_rdkit_conf_1.out: Valid Calc
# 	arene_428_rdkit_conf_1.out: Valid Calc
# 	arene_429_rdkit_conf_1.out: Valid Calc
# 	arene_430_rdkit_conf_1.out: Valid Calc
# 	arene_431_rdkit_conf_1.out: Valid Calc
# 	arene_432_rdkit_conf_1.out: Valid Calc
# 	arene_433_rdkit_conf_1.out: Valid Calc
# 	arene_434_rdkit_conf_1.out: Valid Calc
# 	arene_435_rdkit_conf_1.out: Valid Calc
# 	arene_436_rdkit_conf_1.out: Valid Calc
# 	arene_437_rdkit_conf_1.out: Valid Calc
# 	arene_438_rdkit_conf_1.out: Valid Calc
# 	arene_439_rdkit_conf_1.out: Valid Calc
# 	arene_440_rdkit_conf_1.out: Valid Calc
# 	arene_441_rdkit_conf_1.out: Valid Calc
# 	arene_442_rdkit_conf_1.out: Valid Calc
# 	arene_443_rdkit_conf_1.out: Valid Calc
# 	arene_444_rdkit_conf_1.out: Valid Calc
# 	arene_445_rdkit_conf_1.out: Valid Calc
# 	arene_446_rdkit_conf_1.out: Valid Calc
# 	arene_447_rdkit_conf_1.out: Valid Calc
# 	arene_448_rdkit_conf_1.out: Valid Calc
# 	arene_449_rdkit_conf_1.out: Valid Calc
# 	arene_450_rdkit_conf_1.out: Valid Calc
# 	arene_451_rdkit_conf_1.out: Valid Calc
# 	arene_452_rdkit_conf_1.out: Valid Calc
# 	arene_453_rdkit_conf_1.out: Valid Calc
# 	arene_454_rdkit_conf_1.out: Valid Calc
# 	arene_455_rdkit_conf_1.out: Valid Calc
# 	arene_456_rdkit_conf_1.out: Valid Calc
# 	arene_457_rdkit_conf_1.out: Valid Calc
# 	arene_458_rdkit_conf_1.out: Valid Calc
# 	arene_459_rdkit_conf_1.out: Valid Calc
# 	arene_460_rdkit_conf_1.out: Valid Calc
# 	arene_461_rdkit_conf_1.out: Valid Calc
# 	arene_462_rdkit_conf_1.out: Valid Calc
# 	arene_463_rdkit_conf_1.out: Valid Calc
# 	arene_464_rdkit_conf_1.out: Valid Calc
# 	arene_465_rdkit_conf_1.out: Valid Calc
# 	arene_466_rdkit_conf_1.out: Valid Calc
# 	arene_467_rdkit_conf_1.out: Valid Calc
# 	arene_468_rdkit_conf_1.out: Valid Calc
# 	arene_469_rdkit_conf_1.out: Valid Calc
# 	arene_470_rdkit_conf_1.out: Valid Calc
# 	arene_471_rdkit_conf_1.out: Valid Calc
# 	arene_472_rdkit_conf_1.out: Valid Calc
# 	arene_473_rdkit_conf_1.out: Valid Calc
# 	arene_474_rdkit_conf_1.out: Valid Calc
# 	arene_475_rdkit_conf_1.out: Valid Calc
# 	arene_476_rdkit_conf_1.out: Valid Calc
# 	arene_477_rdkit_conf_1.out: Valid Calc
# 	arene_478_rdkit_conf_1.out: Valid Calc
# 	arene_479_rdkit_conf_1.out: Valid Calc
# 	arene_480_rdkit_conf_1.out: Valid Calc
# 	arene_481_rdkit_conf_1.out: Valid Calc
# 	arene_482_rdkit_conf_1.out: Valid Calc
# 	arene_483_rdkit_conf_1.out: Valid Calc
# 	arene_484_rdkit_conf_1.out: Valid Calc
# 	arene_485_rdkit_conf_1.out: Valid Calc
# 	arene_486_rdkit_conf_1.out: Valid Calc
# 	arene_487_rdkit_conf_1.out: Valid Calc
# 	arene_488_rdkit_conf_1.out: Valid Calc
# 	arene_489_rdkit_conf_1.out: Valid Calc
# 	arene_490_rdkit_conf_1.out: Valid Calc
# 	arene_491_rdkit_conf_1.out: Valid Calc
# 	arene_492_rdkit_conf_1.out: Valid Calc
# 	arene_493_rdkit_conf_1.out: Valid Calc
# 	arene_494_rdkit_conf_1.out: Valid Calc
# 	arene_495_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_496_rdkit_conf_1.out: Valid Calc
# 	arene_497_rdkit_conf_1.out: Valid Calc
# 	arene_498_rdkit_conf_1.out: Valid Calc
# 	arene_499_rdkit_conf_1.out: Valid Calc
# 	arene_500_rdkit_conf_1.out: Valid Calc
# 	arene_501_rdkit_conf_1.out: Valid Calc
# 	arene_502_rdkit_conf_1.out: Valid Calc
# 	arene_503_rdkit_conf_1.out: Valid Calc
# 	arene_504_rdkit_conf_1.out: Valid Calc
# 	arene_505_rdkit_conf_1.out: Valid Calc
# 	arene_506_rdkit_conf_1.out: Valid Calc
# 	arene_507_rdkit_conf_1.out: Valid Calc
# 	arene_508_rdkit_conf_1.out: Valid Calc
# 	arene_510_rdkit_conf_1.out: Valid Calc
# 	arene_511_rdkit_conf_1.out: Valid Calc
# 	arene_512_rdkit_conf_1.out: Valid Calc
# 	arene_513_rdkit_conf_1.out: Valid Calc
# 	arene_514_rdkit_conf_1.out: Valid Calc
# 	arene_515_rdkit_conf_1.out: Valid Calc
# 	arene_516_rdkit_conf_1.out: Valid Calc
# 	arene_517_rdkit_conf_1.out: Valid Calc
# 	arene_518_rdkit_conf_1.out: Valid Calc
# 	arene_519_rdkit_conf_1.out: Valid Calc
# 	arene_520_rdkit_conf_1.out: Valid Calc
# 	arene_521_rdkit_conf_1.out: Valid Calc
# 	arene_522_rdkit_conf_1.out: Valid Calc
# 	arene_523_rdkit_conf_1.out: Valid Calc
# 	arene_524_rdkit_conf_1.out: Valid Calc
# 	arene_525_rdkit_conf_1.out: Valid Calc
# 	arene_526_rdkit_conf_1.out: Valid Calc
# 	arene_527_rdkit_conf_1.out: Valid Calc
# 	arene_528_rdkit_conf_1.out: Valid Calc
# 	arene_529_rdkit_conf_1.out: Valid Calc
# 	arene_530_rdkit_conf_1.out: Valid Calc
# 	arene_531_rdkit_conf_1.out: Valid Calc
# 	arene_532_rdkit_conf_1.out: Valid Calc
# 	arene_533_rdkit_conf_1.out: Valid Calc
# 	arene_534_rdkit_conf_1.out: Valid Calc
# 	arene_535_rdkit_conf_1.out: Valid Calc
# 	arene_536_rdkit_conf_1.out: Valid Calc
# 	arene_537_rdkit_conf_1.out: Valid Calc
# 	arene_538_rdkit_conf_1.out: Valid Calc
# 	arene_539_rdkit_conf_1.out: Valid Calc
# 	arene_540_rdkit_conf_1.out: Valid Calc
# 	arene_541_rdkit_conf_1.out: Valid Calc
# 	arene_542_rdkit_conf_1.out: Valid Calc
# 	arene_543_rdkit_conf_1.out: Valid Calc
# 	arene_544_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_545_rdkit_conf_1.out: Valid Calc
# 	arene_546_rdkit_conf_1.out: Valid Calc
# 	arene_547_rdkit_conf_1.out: Valid Calc
# 	arene_548_rdkit_conf_1.out: Valid Calc
# 	arene_549_rdkit_conf_1.out: Valid Calc
# 	arene_550_rdkit_conf_1.out: Valid Calc
# 	arene_551_rdkit_conf_1.out: Valid Calc
# 	arene_552_rdkit_conf_1.out: Valid Calc
# 	arene_553_rdkit_conf_1.out: Valid Calc
# 	arene_554_rdkit_conf_1.out: Valid Calc
# 	arene_555_rdkit_conf_1.out: Valid Calc
# 	arene_556_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_557_rdkit_conf_1.out: Valid Calc
# 	arene_558_rdkit_conf_1.out: Valid Calc
# 	arene_559_rdkit_conf_1.out: Valid Calc
# 	arene_560_rdkit_conf_1.out: Valid Calc
# 	arene_561_rdkit_conf_1.out: Valid Calc
# 	arene_562_rdkit_conf_1.out: Valid Calc
# 	arene_563_rdkit_conf_1.out: Valid Calc
# 	arene_564_rdkit_conf_1.out: Valid Calc
# 	arene_565_rdkit_conf_1.out: Valid Calc
# 	arene_566_rdkit_conf_1.out: Valid Calc
# 	arene_567_rdkit_conf_1.out: Valid Calc
# 	arene_568_rdkit_conf_1.out: Valid Calc
# 	arene_569_rdkit_conf_1.out: Valid Calc
# 	arene_570_rdkit_conf_1.out: Valid Calc
# 	arene_571_rdkit_conf_1.out: Valid Calc
# 	arene_572_rdkit_conf_1.out: Valid Calc
# 	arene_573_rdkit_conf_1.out: Valid Calc
# 	arene_574_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_575_rdkit_conf_1.out: Valid Calc
# 	arene_576_rdkit_conf_1.out: Valid Calc
# 	arene_577_rdkit_conf_1.out: Valid Calc
# 	arene_578_rdkit_conf_1.out: Valid Calc
# 	arene_579_rdkit_conf_1.out: Valid Calc
# 	arene_580_rdkit_conf_1.out: Valid Calc
# 	arene_581_rdkit_conf_1.out: Valid Calc
# 	arene_582_rdkit_conf_1.out: Valid Calc
# 	arene_583_rdkit_conf_1.out: Valid Calc
# 	arene_584_rdkit_conf_1.out: Valid Calc
# 	arene_585_rdkit_conf_1.out: Valid Calc
# 	arene_586_rdkit_conf_1.out: Valid Calc
# 	arene_587_rdkit_conf_1.out: Valid Calc
# 	arene_588_rdkit_conf_1.out: Valid Calc
# 	arene_589_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_590_rdkit_conf_1.out: Valid Calc
# 	arene_591_rdkit_conf_1.out: Valid Calc
# 	arene_592_rdkit_conf_1.out: Valid Calc
# 	arene_593_rdkit_conf_1.out: Valid Calc
# 	arene_594_rdkit_conf_1.out: Valid Calc
# 	arene_595_rdkit_conf_1.out: Valid Calc
# 	arene_596_rdkit_conf_1.out: Valid Calc
# 	arene_597_rdkit_conf_1.out: Valid Calc
# 	arene_598_rdkit_conf_1.out: Valid Calc
# 	arene_599_rdkit_conf_1.out: Valid Calc
# 	arene_600_rdkit_conf_1.out: Valid Calc
# 	arene_601_rdkit_conf_1.out: Valid Calc
# 	arene_603_rdkit_conf_1.out: Valid Calc
# 	arene_604_rdkit_conf_1.out: Valid Calc
# 	arene_605_rdkit_conf_1.out: Valid Calc
# 	arene_606_rdkit_conf_1.out: Valid Calc
# 	arene_607_rdkit_conf_1.out: Valid Calc
# 	arene_608_rdkit_conf_1.out: Valid Calc
# 	arene_609_rdkit_conf_1.out: Valid Calc
# 	arene_610_rdkit_conf_1.out: Valid Calc
# 	arene_611_rdkit_conf_1.out: Valid Calc
# 	arene_612_rdkit_conf_1.out: Valid Calc
# 	arene_613_rdkit_conf_1.out: Valid Calc
# 	arene_614_rdkit_conf_1.out: Valid Calc
# 	arene_615_rdkit_conf_1.out: Valid Calc
# 	arene_616_rdkit_conf_1.out: Valid Calc
# 	arene_617_rdkit_conf_1.out: Valid Calc
# 	arene_618_rdkit_conf_1.out: Valid Calc
# 	arene_619_rdkit_conf_1.out: Valid Calc
# 	arene_620_rdkit_conf_1.out: Valid Calc
# 	arene_621_rdkit_conf_1.out: Valid Calc
# 	arene_622_rdkit_conf_1.out: Valid Calc
# 	arene_623_rdkit_conf_1.out: Valid Calc
# 	arene_624_rdkit_conf_1.out: Valid Calc
# 	arene_625_rdkit_conf_1.out: Valid Calc
# 	arene_626_rdkit_conf_1.out: Valid Calc
# 	arene_627_rdkit_conf_1.out: Valid Calc
# 	arene_628_rdkit_conf_1.out: Valid Calc
# 	arene_629_rdkit_conf_1.out: Valid Calc
# 	arene_630_rdkit_conf_1.out: Valid Calc
# 	arene_631_rdkit_conf_1.out: Valid Calc
# 	arene_632_rdkit_conf_1.out: Valid Calc
# 	arene_633_rdkit_conf_1.out: Valid Calc
# 	arene_634_rdkit_conf_1.out: Valid Calc
# 	arene_635_rdkit_conf_1.out: Valid Calc
# 	arene_636_rdkit_conf_1.out: Valid Calc
# 	arene_637_rdkit_conf_1.out: Valid Calc
# 	arene_638_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_639_rdkit_conf_1.out: Valid Calc
# 	arene_640_rdkit_conf_1.out: Valid Calc
# 	arene_641_rdkit_conf_1.out: Valid Calc
# 	arene_642_rdkit_conf_1.out: Valid Calc
# 	arene_643_rdkit_conf_1.out: Valid Calc
# 	arene_644_rdkit_conf_1.out: Valid Calc
# 	arene_645_rdkit_conf_1.out: Valid Calc
# 	arene_646_rdkit_conf_1.out: Valid Calc
# 	arene_647_rdkit_conf_1.out: Valid Calc
# 	arene_648_rdkit_conf_1.out: Valid Calc
# 	arene_649_rdkit_conf_1.out: Valid Calc
# 	arene_650_rdkit_conf_1.out: Valid Calc
# 	arene_651_rdkit_conf_1.out: Valid Calc
# 	arene_652_rdkit_conf_1.out: Valid Calc
# 	arene_653_rdkit_conf_1.out: Valid Calc
# 	arene_654_rdkit_conf_1.out: Valid Calc
# 	arene_655_rdkit_conf_1.out: Valid Calc
# 	arene_656_rdkit_conf_1.out: Valid Calc
# 	arene_657_rdkit_conf_1.out: Valid Calc
# 	arene_658_rdkit_conf_1.out: Valid Calc
# 	arene_659_rdkit_conf_1.out: Valid Calc
# 	arene_660_rdkit_conf_1.out: Valid Calc
# 	arene_661_rdkit_conf_1.out: Valid Calc
# 	arene_662_rdkit_conf_1.out: Valid Calc
# 	arene_663_rdkit_conf_1.out: Valid Calc
# 	arene_664_rdkit_conf_1.out: Valid Calc
# 	arene_665_rdkit_conf_1.out: Valid Calc
# 	arene_666_rdkit_conf_1.out: Valid Calc
# 	arene_667_rdkit_conf_1.out: Valid Calc
# 	arene_668_rdkit_conf_1.out: Valid Calc
# 	arene_669_rdkit_conf_1.out: Valid Calc
# 	arene_670_rdkit_conf_1.out: Valid Calc
# 	arene_671_rdkit_conf_1.out: Valid Calc
# 	arene_672_rdkit_conf_1.out: Valid Calc
# 	arene_673_rdkit_conf_1.out: Valid Calc
# 	arene_674_rdkit_conf_1.out: Valid Calc
# 	arene_675_rdkit_conf_1.out: Valid Calc
# 	arene_676_rdkit_conf_1.out: Valid Calc
# 	arene_677_rdkit_conf_1.out: Valid Calc
# 	arene_678_rdkit_conf_1.out: Valid Calc
# 	arene_680_rdkit_conf_1.out: Valid Calc
# 	arene_681_rdkit_conf_1.out: Valid Calc
# 	arene_682_rdkit_conf_1.out: Valid Calc
# 	arene_683_rdkit_conf_1.out: Valid Calc
# 	arene_684_rdkit_conf_1.out: Valid Calc
# 	arene_685_rdkit_conf_1.out: Valid Calc
# 	arene_686_rdkit_conf_1.out: Valid Calc
# 	arene_687_rdkit_conf_1.out: Valid Calc
# 	arene_688_rdkit_conf_1.out: Valid Calc
# 	arene_689_rdkit_conf_1.out: Valid Calc
# 	arene_690_rdkit_conf_1.out: Valid Calc
# 	arene_691_rdkit_conf_1.out: Valid Calc
# 	arene_692_rdkit_conf_1.out: Valid Calc
# 	arene_693_rdkit_conf_1.out: Valid Calc
# 	arene_694_rdkit_conf_1.out: Valid Calc
# 	arene_695_rdkit_conf_1.out: Valid Calc
# 	arene_696_rdkit_conf_1.out: Valid Calc
# 	arene_697_rdkit_conf_1.out: Valid Calc
# 	arene_698_rdkit_conf_1.out: Valid Calc
# 	arene_699_rdkit_conf_1.out: Valid Calc
# 	arene_700_rdkit_conf_1.out: Valid Calc
# 	arene_701_rdkit_conf_1.out: Valid Calc
# 	arene_702_rdkit_conf_1.out: Valid Calc
# 	arene_703_rdkit_conf_1.out: Valid Calc
# 	arene_704_rdkit_conf_1.out: Valid Calc
# 	arene_705_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_706_rdkit_conf_1.out: Valid Calc
# 	arene_707_rdkit_conf_1.out: Valid Calc
# 	arene_708_rdkit_conf_1.out: Valid Calc
# 	arene_709_rdkit_conf_1.out: Valid Calc
# 	arene_710_rdkit_conf_1.out: Valid Calc
# 	arene_711_rdkit_conf_1.out: Valid Calc
# 	arene_712_rdkit_conf_1.out: Valid Calc
# 	arene_714_rdkit_conf_1.out: Valid Calc
# 	arene_715_rdkit_conf_1.out: Valid Calc
# 	arene_716_rdkit_conf_1.out: Valid Calc
# 	arene_717_rdkit_conf_1.out: Valid Calc
# 	arene_718_rdkit_conf_1.out: Valid Calc
# 	arene_719_rdkit_conf_1.out: Valid Calc
# 	arene_720_rdkit_conf_1.out: Valid Calc
# 	arene_721_rdkit_conf_1.out: Valid Calc
# 	arene_722_rdkit_conf_1.out: Valid Calc
# 	arene_723_rdkit_conf_1.out: Valid Calc
# 	arene_724_rdkit_conf_1.out: Valid Calc
# 	arene_725_rdkit_conf_1.out: Valid Calc
# 	arene_726_rdkit_conf_1.out: Valid Calc
# 	arene_727_rdkit_conf_1.out: Valid Calc
# 	arene_728_rdkit_conf_1.out: Valid Calc
# 	arene_729_rdkit_conf_1.out: Valid Calc
# 	arene_730_rdkit_conf_1.out: Valid Calc
# 	arene_731_rdkit_conf_1.out: Valid Calc
# 	arene_733_rdkit_conf_1.out: Valid Calc
# 	arene_735_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_736_rdkit_conf_1.out: Valid Calc
# 	arene_737_rdkit_conf_1.out: Valid Calc
# 	arene_739_rdkit_conf_1.out: Valid Calc
# 	arene_740_rdkit_conf_1.out: Valid Calc
# 	arene_741_rdkit_conf_1.out: Valid Calc
# 	arene_742_rdkit_conf_1.out: Valid Calc
# 	arene_743_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_744_rdkit_conf_1.out: Valid Calc
# 	arene_745_rdkit_conf_1.out: Valid Calc
# 	arene_746_rdkit_conf_1.out: Valid Calc
# 	arene_747_rdkit_conf_1.out: Valid Calc
# 	arene_748_rdkit_conf_1.out: Valid Calc
# 	arene_749_rdkit_conf_1.out: Valid Calc
# 	arene_750_rdkit_conf_1.out: Valid Calc
# 	arene_751_rdkit_conf_1.out: Valid Calc
# 	arene_752_rdkit_conf_1.out: Valid Calc
# 	arene_753_rdkit_conf_1.out: Valid Calc
# 	arene_754_rdkit_conf_1.out: Valid Calc
# 	arene_755_rdkit_conf_1.out: Valid Calc
# 	arene_756_rdkit_conf_1.out: Valid Calc
# 	arene_757_rdkit_conf_1.out: Valid Calc
# 	arene_758_rdkit_conf_1.out: Valid Calc
# 	arene_759_rdkit_conf_1.out: Valid Calc
# 	arene_760_rdkit_conf_1.out: Valid Calc
# 	arene_761_rdkit_conf_1.out: Valid Calc
# 	arene_762_rdkit_conf_1.out: Valid Calc
# 	arene_763_rdkit_conf_1.out: Valid Calc
# 	arene_764_rdkit_conf_1.out: Valid Calc
# 	arene_765_rdkit_conf_1.out: Valid Calc
# 	arene_766_rdkit_conf_1.out: Valid Calc
# 	arene_767_rdkit_conf_1.out: Valid Calc
# 	arene_768_rdkit_conf_1.out: Valid Calc
# 	arene_769_rdkit_conf_1.out: Valid Calc
# 	arene_770_rdkit_conf_1.out: Valid Calc
# 	arene_771_rdkit_conf_1.out: Valid Calc
# 	arene_772_rdkit_conf_1.out: Valid Calc
# 	arene_773_rdkit_conf_1.out: Valid Calc
# 	arene_774_rdkit_conf_1.out: Valid Calc
# 	arene_776_rdkit_conf_1.out: Valid Calc
# 	arene_777_rdkit_conf_1.out: Valid Calc
# 	arene_778_rdkit_conf_1.out: Valid Calc
# 	arene_779_rdkit_conf_1.out: Valid Calc
# 	arene_780_rdkit_conf_1.out: Valid Calc
# 	arene_781_rdkit_conf_1.out: Valid Calc
# 	arene_782_rdkit_conf_1.out: Valid Calc
# 	arene_783_rdkit_conf_1.out: Valid Calc
# 	arene_784_rdkit_conf_1.out: Valid Calc
# 	arene_785_rdkit_conf_1.out: Valid Calc
# 	arene_786_rdkit_conf_1.out: Valid Calc
# 	arene_787_rdkit_conf_1.out: Valid Calc
# 	arene_788_rdkit_conf_1.out: Valid Calc
# 	arene_789_rdkit_conf_1.out: Valid Calc
# 	arene_790_rdkit_conf_1.out: Valid Calc
# 	arene_791_rdkit_conf_1.out: Valid Calc
# 	arene_792_rdkit_conf_1.out: Valid Calc
# 	arene_793_rdkit_conf_1.out: Valid Calc
# 	arene_794_rdkit_conf_1.out: Valid Calc
# 	arene_796_rdkit_conf_1.out: Valid Calc
# 	arene_797_rdkit_conf_1.out: Valid Calc
# 	arene_798_rdkit_conf_1.out: Valid Calc
# 	arene_799_rdkit_conf_1.out: Valid Calc
# 	arene_800_rdkit_conf_1.out: Valid Calc
# 	arene_801_rdkit_conf_1.out: Valid Calc
# 	arene_802_rdkit_conf_1.out: Valid Calc
# 	arene_803_rdkit_conf_1.out: Valid Calc
# 	arene_804_rdkit_conf_1.out: Valid Calc
# 	arene_805_rdkit_conf_1.out: Valid Calc
# 	arene_806_rdkit_conf_1.out: Valid Calc
# 	arene_807_rdkit_conf_1.out: Valid Calc
# 	arene_808_rdkit_conf_1.out: Valid Calc
# 	arene_809_rdkit_conf_1.out: Valid Calc
# 	arene_810_rdkit_conf_1.out: Valid Calc
# 	arene_811_rdkit_conf_1.out: Valid Calc
# 	arene_813_rdkit_conf_1.out: Valid Calc
# 	arene_814_rdkit_conf_1.out: Valid Calc
# 	arene_815_rdkit_conf_1.out: Valid Calc
# 	arene_816_rdkit_conf_1.out: Valid Calc
# 	arene_817_rdkit_conf_1.out: Valid Calc
# 	arene_818_rdkit_conf_1.out: Valid Calc
# 	arene_819_rdkit_conf_1.out: Valid Calc
# 	arene_820_rdkit_conf_1.out: Valid Calc
# 	arene_821_rdkit_conf_1.out: Valid Calc
# 	arene_822_rdkit_conf_1.out: Valid Calc
# 	arene_823_rdkit_conf_1.out: Valid Calc
# 	arene_824_rdkit_conf_1.out: Valid Calc
# 	arene_825_rdkit_conf_1.out: Valid Calc
# 	arene_826_rdkit_conf_1.out: Valid Calc
# 	arene_827_rdkit_conf_1.out: Valid Calc
# 	arene_828_rdkit_conf_1.out: Valid Calc
# 	arene_829_rdkit_conf_1.out: Valid Calc
# 	arene_830_rdkit_conf_1.out: Valid Calc
# 	arene_831_rdkit_conf_1.out: Valid Calc
# 	arene_832_rdkit_conf_1.out: Valid Calc
# 	arene_833_rdkit_conf_1.out: Valid Calc
# 	arene_834_rdkit_conf_1.out: Valid Calc
# 	arene_835_rdkit_conf_1.out: Valid Calc
# 	arene_836_rdkit_conf_1.out: Valid Calc
# 	arene_837_rdkit_conf_1.out: Valid Calc
# 	arene_838_rdkit_conf_1.out: Valid Calc
# 	arene_839_rdkit_conf_1.out: Valid Calc
# 	arene_840_rdkit_conf_1.out: Valid Calc
# 	arene_841_rdkit_conf_1.out: Valid Calc
# 	arene_842_rdkit_conf_1.out: Valid Calc
# 	arene_843_rdkit_conf_1.out: Valid Calc
# 	arene_844_rdkit_conf_1.out: Valid Calc
# 	arene_845_rdkit_conf_1.out: Valid Calc
# 	arene_846_rdkit_conf_1.out: Valid Calc
# 	arene_847_rdkit_conf_1.out: Valid Calc
# 	arene_848_rdkit_conf_1.out: Valid Calc
# 	arene_849_rdkit_conf_1.out: Valid Calc
# 	arene_850_rdkit_conf_1.out: Valid Calc
# 	arene_852_rdkit_conf_1.out: Valid Calc
# 	arene_853_rdkit_conf_1.out: Valid Calc
# 	arene_854_rdkit_conf_1.out: Valid Calc
# 	arene_855_rdkit_conf_1.out: Valid Calc
# 	arene_856_rdkit_conf_1.out: Valid Calc
# 	arene_857_rdkit_conf_1.out: Valid Calc
# 	arene_858_rdkit_conf_1.out: Valid Calc
# 	arene_859_rdkit_conf_1.out: Valid Calc
# 	arene_860_rdkit_conf_1.out: Valid Calc
# 	arene_861_rdkit_conf_1.out: Valid Calc
# 	arene_862_rdkit_conf_1.out: Valid Calc
# 	arene_863_rdkit_conf_1.out: Valid Calc
# 	arene_864_rdkit_conf_1.out: Valid Calc
# 	arene_865_rdkit_conf_1.out: Valid Calc
# 	arene_866_rdkit_conf_1.out: Valid Calc
# 	arene_867_rdkit_conf_1.out: Valid Calc
# 	arene_868_rdkit_conf_1.out: Valid Calc
# 	arene_869_rdkit_conf_1.out: Valid Calc
# 	arene_870_rdkit_conf_1.out: Valid Calc
# 	arene_871_rdkit_conf_1.out: Valid Calc
# 	arene_872_rdkit_conf_1.out: Valid Calc
# 	arene_873_rdkit_conf_1.out: Valid Calc
# 	arene_874_rdkit_conf_1.out: Valid Calc
# 	arene_875_rdkit_conf_1.out: Valid Calc
# 	arene_876_rdkit_conf_1.out: Valid Calc
# 	arene_877_rdkit_conf_1.out: Valid Calc
# 	arene_878_rdkit_conf_1.out: Valid Calc
# 	arene_879_rdkit_conf_1.out: Valid Calc
# 	arene_880_rdkit_conf_1.out: Valid Calc
# 	arene_881_rdkit_conf_1.out: Valid Calc
# 	arene_882_rdkit_conf_1.out: Valid Calc
# 	arene_883_rdkit_conf_1.out: Valid Calc
# 	arene_884_rdkit_conf_1.out: Valid Calc
# 	arene_885_rdkit_conf_1.out: Valid Calc
# 	arene_886_rdkit_conf_1.out: Valid Calc
# 	arene_887_rdkit_conf_1.out: Valid Calc
# 	arene_888_rdkit_conf_1.out: Valid Calc
# 	arene_889_rdkit_conf_1.out: Valid Calc
# 	arene_890_rdkit_conf_1.out: Valid Calc
# 	arene_891_rdkit_conf_1.out: Valid Calc
# 	arene_892_rdkit_conf_1.out: Valid Calc
# 	arene_893_rdkit_conf_1.out: Valid Calc
# 	arene_894_rdkit_conf_1.out: Valid Calc
# 	arene_895_rdkit_conf_1.out: Valid Calc
# 	arene_896_rdkit_conf_1.out: Valid Calc
# 	arene_897_rdkit_conf_1.out: Valid Calc
# 	arene_898_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_899_rdkit_conf_1.out: Valid Calc
# 	arene_900_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_901_rdkit_conf_1.out: Valid Calc
# 	arene_902_rdkit_conf_1.out: Valid Calc
# 	arene_903_rdkit_conf_1.out: Valid Calc
# 	arene_904_rdkit_conf_1.out: Valid Calc
# 	arene_905_rdkit_conf_1.out: Valid Calc
# 	arene_906_rdkit_conf_1.out: Valid Calc
# 	arene_907_rdkit_conf_1.out: Valid Calc
# 	arene_908_rdkit_conf_1.out: Valid Calc
# 	arene_909_rdkit_conf_1.out: Valid Calc
# 	arene_910_rdkit_conf_1.out: Valid Calc
# 	arene_911_rdkit_conf_1.out: Valid Calc
# 	arene_912_rdkit_conf_1.out: Valid Calc
# 	arene_913_rdkit_conf_1.out: Valid Calc
# 	arene_914_rdkit_conf_1.out: Valid Calc
# 	arene_915_rdkit_conf_1.out: Valid Calc
# 	arene_916_rdkit_conf_1.out: Valid Calc
# 	arene_917_rdkit_conf_1.out: Valid Calc
# 	arene_918_rdkit_conf_1.out: Valid Calc
# 	arene_920_rdkit_conf_1.out: Valid Calc
# 	arene_921_rdkit_conf_1.out: Valid Calc
# 	arene_922_rdkit_conf_1.out: Valid Calc
# 	arene_923_rdkit_conf_1.out: Valid Calc
# 	arene_924_rdkit_conf_1.out: Valid Calc
# 	arene_925_rdkit_conf_1.out: Valid Calc
# 	arene_926_rdkit_conf_1.out: Valid Calc
# 	arene_927_rdkit_conf_1.out: Valid Calc
# 	arene_928_rdkit_conf_1.out: Valid Calc
# 	arene_929_rdkit_conf_1.out: Valid Calc
# 	arene_930_rdkit_conf_1.out: Valid Calc
# 	arene_931_rdkit_conf_1.out: Valid Calc
# 	arene_932_rdkit_conf_1.out: Valid Calc
# 	arene_933_rdkit_conf_1.out: Valid Calc
# 	arene_934_rdkit_conf_1.out: Valid Calc
# 	arene_935_rdkit_conf_1.out: Valid Calc
# 	arene_936_rdkit_conf_1.out: Valid Calc
# 	arene_937_rdkit_conf_1.out: Valid Calc
# 	arene_938_rdkit_conf_1.out: Valid Calc
# 	arene_940_rdkit_conf_1.out: Valid Calc
# 	arene_941_rdkit_conf_1.out: Valid Calc
# 	arene_942_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_943_rdkit_conf_1.out: Valid Calc
# 	arene_944_rdkit_conf_1.out: Valid Calc
# 	arene_945_rdkit_conf_1.out: Valid Calc
# 	arene_946_rdkit_conf_1.out: Valid Calc
# 	arene_947_rdkit_conf_1.out: Valid Calc
# 	arene_948_rdkit_conf_1.out: Valid Calc
# 	arene_949_rdkit_conf_1.out: Valid Calc
# 	arene_950_rdkit_conf_1.out: Valid Calc
# 	arene_951_rdkit_conf_1.out: Valid Calc
# 	arene_952_rdkit_conf_1.out: Valid Calc
# 	arene_953_rdkit_conf_1.out: Valid Calc
# 	arene_954_rdkit_conf_1.out: Valid Calc
# 	arene_955_rdkit_conf_1.out: Valid Calc
# 	arene_956_rdkit_conf_1.out: Valid Calc
# 	arene_957_rdkit_conf_1.out: Valid Calc
# 	arene_958_rdkit_conf_1.out: Valid Calc
# 	arene_959_rdkit_conf_1.out: Valid Calc
# 	arene_960_rdkit_conf_1.out: Valid Calc
# 	arene_961_rdkit_conf_1.out: Valid Calc
# 	arene_962_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_963_rdkit_conf_1.out: Valid Calc
# 	arene_964_rdkit_conf_1.out: Valid Calc
# 	arene_965_rdkit_conf_1.out: Valid Calc
# 	arene_966_rdkit_conf_1.out: Valid Calc
# 	arene_967_rdkit_conf_1.out: Valid Calc
# 	arene_968_rdkit_conf_1.out: Valid Calc
# 	arene_969_rdkit_conf_1.out: Valid Calc
# 	arene_970_rdkit_conf_1.out: Valid Calc
# 	arene_971_rdkit_conf_1.out: Valid Calc
# 	arene_972_rdkit_conf_1.out: Valid Calc
# 	arene_973_rdkit_conf_1.out: Valid Calc
# 	arene_974_rdkit_conf_1.out: Valid Calc
# 	arene_975_rdkit_conf_1.out: Valid Calc
# 	arene_976_rdkit_conf_1.out: Valid Calc
# 	arene_977_rdkit_conf_1.out: Valid Calc
# 	arene_978_rdkit_conf_1.out: Valid Calc
# 	arene_979_rdkit_conf_1.out: Valid Calc
# 	arene_980_rdkit_conf_1.out: Valid Calc
# 	arene_981_rdkit_conf_1.out: Valid Calc
# 	arene_982_rdkit_conf_1.out: Valid Calc
# 	arene_983_rdkit_conf_1.out: Valid Calc
# 	arene_984_rdkit_conf_1.out: Valid Calc
# 	arene_985_rdkit_conf_1.out: Valid Calc
# 	arene_986_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_987_rdkit_conf_1.out: Valid Calc
# 	arene_988_rdkit_conf_1.out: Valid Calc
# 	arene_989_rdkit_conf_1.out: Valid Calc
# 	arene_990_rdkit_conf_1.out: Valid Calc
# 	arene_991_rdkit_conf_1.out: Valid Calc
# 	arene_992_rdkit_conf_1.out: Valid Calc
# 	arene_993_rdkit_conf_1.out: Valid Calc
# 	arene_995_rdkit_conf_1.out: Valid Calc
# 	arene_996_rdkit_conf_1.out: Valid Calc
# 	arene_997_rdkit_conf_1.out: Valid Calc
# 	arene_998_rdkit_conf_1.out: Valid Calc
# 	arene_999_rdkit_conf_1.out: Valid Calc
# 	arene_1000_rdkit_conf_1.out: Valid Calc
# 	arene_1001_rdkit_conf_1.out: Valid Calc
# 	arene_1002_rdkit_conf_1.out: Valid Calc
# 	arene_1003_rdkit_conf_1.out: Valid Calc
# 	arene_1004_rdkit_conf_1.out: Valid Calc
# 	arene_1005_rdkit_conf_1.out: Valid Calc
# 	arene_1006_rdkit_conf_1.out: Valid Calc
# 	arene_1007_rdkit_conf_1.out: Valid Calc
# 	arene_1008_rdkit_conf_1.out: Valid Calc
# 	arene_1009_rdkit_conf_1.out: Valid Calc
# 	arene_1010_rdkit_conf_1.out: Valid Calc
# 	arene_1011_rdkit_conf_1.out: Valid Calc
# 	arene_1012_rdkit_conf_1.out: Valid Calc
# 	arene_1013_rdkit_conf_1.out: Valid Calc
# 	arene_1014_rdkit_conf_1.out: Valid Calc
# 	arene_1015_rdkit_conf_1.out: Valid Calc
# 	arene_1016_rdkit_conf_1.out: Valid Calc
# 	arene_1017_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_1018_rdkit_conf_1.out: Valid Calc
# 	arene_1019_rdkit_conf_1.out: Valid Calc
# 	arene_1020_rdkit_conf_1.out: Valid Calc
# 	arene_1021_rdkit_conf_1.out: Valid Calc
# 	arene_1022_rdkit_conf_1.out: Valid Calc
# 	arene_1023_rdkit_conf_1.out: Valid Calc
# 	arene_1024_rdkit_conf_1.out: Valid Calc
# 	arene_1025_rdkit_conf_1.out: Valid Calc
# 	arene_1026_rdkit_conf_1.out: Valid Calc
# 	arene_1027_rdkit_conf_1.out: Valid Calc
# 	arene_1028_rdkit_conf_1.out: Valid Calc
# 	arene_1029_rdkit_conf_1.out: Valid Calc
# 	arene_1030_rdkit_conf_1.out: Valid Calc
# 	arene_1031_rdkit_conf_1.out: Valid Calc
# 	arene_1032_rdkit_conf_1.out: Valid Calc
# 	arene_1033_rdkit_conf_1.out: Valid Calc
# 	arene_1034_rdkit_conf_1.out: Valid Calc
# 	arene_1035_rdkit_conf_1.out: Valid Calc
# 	arene_1036_rdkit_conf_1.out: Valid Calc
# 	arene_1037_rdkit_conf_1.out: Valid Calc
# 	arene_1038_rdkit_conf_1.out: Valid Calc
# 	arene_1039_rdkit_conf_1.out: Valid Calc
# 	arene_1040_rdkit_conf_1.out: Valid Calc
# 	arene_1041_rdkit_conf_1.out: Valid Calc
# 	arene_1042_rdkit_conf_1.out: Valid Calc
# 	arene_1043_rdkit_conf_1.out: Valid Calc
# 	arene_1044_rdkit_conf_1.out: Valid Calc
# 	arene_1045_rdkit_conf_1.out: Valid Calc
# 	arene_1046_rdkit_conf_1.out: Valid Calc
# 	arene_1047_rdkit_conf_1.out: Valid Calc
# 	arene_1048_rdkit_conf_1.out: Valid Calc
# 	arene_1049_rdkit_conf_1.out: Valid Calc
# 	arene_1050_rdkit_conf_1.out: Valid Calc
# 	arene_1051_rdkit_conf_1.out: Valid Calc
# 	arene_1052_rdkit_conf_1.out: Valid Calc
# 	arene_1053_rdkit_conf_1.out: Valid Calc
# 	arene_1054_rdkit_conf_1.out: Valid Calc
# 	arene_1056_rdkit_conf_1.out: Valid Calc
# 	arene_1057_rdkit_conf_1.out: Valid Calc
# 	arene_1058_rdkit_conf_1.out: Valid Calc
# 	arene_1059_rdkit_conf_1.out: Valid Calc
# 	arene_1060_rdkit_conf_1.out: Valid Calc
# 	arene_1061_rdkit_conf_1.out: Valid Calc
# 	arene_1062_rdkit_conf_1.out: Valid Calc
# 	arene_1063_rdkit_conf_1.out: Valid Calc
# 	arene_1064_rdkit_conf_1.out: Valid Calc
# 	arene_1065_rdkit_conf_1.out: Valid Calc
# 	arene_1067_rdkit_conf_1.out: Valid Calc
# 	arene_1068_rdkit_conf_1.out: Valid Calc
# 	arene_1069_rdkit_conf_1.out: Valid Calc
# 	arene_1070_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_1071_rdkit_conf_1.out: Valid Calc
# 	arene_1072_rdkit_conf_1.out: Valid Calc
# 	arene_1073_rdkit_conf_1.out: Valid Calc
# 	arene_1074_rdkit_conf_1.out: Valid Calc
# 	arene_1075_rdkit_conf_1.out: Valid Calc
# 	arene_1076_rdkit_conf_1.out: Valid Calc
# 	arene_1077_rdkit_conf_1.out: Valid Calc
# 	arene_1078_rdkit_conf_1.out: Valid Calc
# 	arene_1079_rdkit_conf_1.out: Valid Calc
# 	arene_1080_rdkit_conf_1.out: Valid Calc
# 	arene_1081_rdkit_conf_1.out: Valid Calc
# 	arene_1082_rdkit_conf_1.out: Valid Calc
# 	arene_1083_rdkit_conf_1.out: Valid Calc
# 	arene_1084_rdkit_conf_1.out: Valid Calc
# 	arene_1085_rdkit_conf_1.out: Valid Calc
# 	arene_1086_rdkit_conf_1.out: Valid Calc
# 	arene_1087_rdkit_conf_1.out: Valid Calc
# 	arene_1088_rdkit_conf_1.out: Valid Calc
# 	arene_1089_rdkit_conf_1.out: Valid Calc
# 	arene_1090_rdkit_conf_1.out: Valid Calc
# 	arene_1091_rdkit_conf_1.out: Valid Calc
# 	arene_1092_rdkit_conf_1.out: Valid Calc
# 	arene_1093_rdkit_conf_1.out: Valid Calc
# 	arene_1094_rdkit_conf_1.out: Valid Calc
# 	arene_1095_rdkit_conf_1.out: Valid Calc
# 	arene_1096_rdkit_conf_1.out: Valid Calc
# 	arene_1097_rdkit_conf_1.out: Valid Calc
# 	arene_1098_rdkit_conf_1.out: Valid Calc
# 	arene_1099_rdkit_conf_1.out: Valid Calc
# 	arene_1100_rdkit_conf_1.out: Valid Calc
# 	arene_1101_rdkit_conf_1.out: Valid Calc
# 	arene_1102_rdkit_conf_1.out: Valid Calc
# 	arene_1103_rdkit_conf_1.out: Valid Calc
# 	arene_1104_rdkit_conf_1.out: Valid Calc
# 	arene_1105_rdkit_conf_1.out: Valid Calc
# 	arene_1106_rdkit_conf_1.out: Valid Calc
# 	arene_1107_rdkit_conf_1.out: Valid Calc
# 	arene_1108_rdkit_conf_1.out: Valid Calc
# 	arene_1109_rdkit_conf_1.out: Valid Calc
# 	arene_1110_rdkit_conf_1.out: Valid Calc
# 	arene_1111_rdkit_conf_1.out: Valid Calc
# 	arene_1112_rdkit_conf_1.out: Valid Calc
# 	arene_1113_rdkit_conf_1.out: Valid Calc
# 	arene_1114_rdkit_conf_1.out: Valid Calc
# 	arene_1115_rdkit_conf_1.out: Valid Calc
# 	arene_1116_rdkit_conf_1.out: Valid Calc
# 	arene_1117_rdkit_conf_1.out: Valid Calc
# 	arene_1118_rdkit_conf_1.out: Valid Calc
# 	arene_1119_rdkit_conf_1.out: Valid Calc
# 	arene_1120_rdkit_conf_1.out: Valid Calc
# 	arene_1121_rdkit_conf_1.out: Valid Calc
# 	arene_1122_rdkit_conf_1.out: Valid Calc
# 	arene_1123_rdkit_conf_1.out: Valid Calc
# 	arene_1124_rdkit_conf_1.out: Valid Calc
# 	arene_1125_rdkit_conf_1.out: Valid Calc
# 	arene_1126_rdkit_conf_1.out: Valid Calc
# 	arene_1127_rdkit_conf_1.out: Valid Calc
# 	arene_1128_rdkit_conf_1.out: Valid Calc
# 	arene_1129_rdkit_conf_1.out: Valid Calc
# 	arene_1130_rdkit_conf_1.out: Valid Calc
# 	arene_1131_rdkit_conf_1.out: Valid Calc
# 	arene_1132_rdkit_conf_1.out: Valid Calc
# 	arene_1133_rdkit_conf_1.out: Valid Calc
# 	arene_1135_rdkit_conf_1.out: Valid Calc
# 	arene_1136_rdkit_conf_1.out: Valid Calc
# 	arene_1137_rdkit_conf_1.out: Valid Calc
# 	arene_1138_rdkit_conf_1.out: Valid Calc
# 	arene_1140_rdkit_conf_1.out: Valid Calc
# 	arene_1141_rdkit_conf_1.out: Valid Calc
# 	arene_1142_rdkit_conf_1.out: Valid Calc
# 	arene_1143_rdkit_conf_1.out: Valid Calc
# 	arene_1144_rdkit_conf_1.out: Valid Calc
# 	arene_1145_rdkit_conf_1.out: Valid Calc
# 	arene_1146_rdkit_conf_1.out: Valid Calc
# 	arene_1147_rdkit_conf_1.out: Valid Calc
# 	arene_1148_rdkit_conf_1.out: Valid Calc
# 	arene_1149_rdkit_conf_1.out: Valid Calc
# 	arene_1150_rdkit_conf_1.out: Valid Calc
# 	arene_1151_rdkit_conf_1.out: Valid Calc
# 	arene_1152_rdkit_conf_1.out: Valid Calc
# 	arene_1153_rdkit_conf_1.out: Valid Calc
# 	arene_1154_rdkit_conf_1.out: Valid Calc
# 	arene_1155_rdkit_conf_1.out: Valid Calc
# 	arene_1156_rdkit_conf_1.out: Valid Calc
# 	arene_1157_rdkit_conf_1.out: Valid Calc
# 	arene_1158_rdkit_conf_1.out: Valid Calc
# 	arene_1159_rdkit_conf_1.out: Valid Calc
# 	arene_1160_rdkit_conf_1.out: Valid Calc
# 	arene_1161_rdkit_conf_1.out: Valid Calc
# 	arene_1162_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_1163_rdkit_conf_1.out: Valid Calc
# 	arene_1164_rdkit_conf_1.out: Valid Calc
# 	arene_1165_rdkit_conf_1.out: Valid Calc
# 	arene_1166_rdkit_conf_1.out: Valid Calc
# 	arene_1167_rdkit_conf_1.out: Valid Calc
# 	arene_1168_rdkit_conf_1.out: Valid Calc
# 	arene_1169_rdkit_conf_1.out: Valid Calc
# 	arene_1170_rdkit_conf_1.out: Valid Calc
# 	arene_1171_rdkit_conf_1.out: Valid Calc
# ...
# 	arene_7866_rdkit_conf_1.out: Valid Calc
# 	arene_7867_rdkit_conf_1.out: Valid Calc
# 	arene_7868_rdkit_conf_1.out: Valid Calc
# 	arene_7869_rdkit_conf_1.out: Valid Calc
# 	arene_7870_rdkit_conf_1.out: Valid Calc
# 	arene_7871_rdkit_conf_1.out: Valid Calc
# 	arene_7872_rdkit_conf_1.out: Valid Calc
# 	arene_7873_rdkit_conf_1.out: Valid Calc
# 	arene_7874_rdkit_conf_1.out: Valid Calc
# 	arene_7875_rdkit_conf_1.out: Valid Calc
# 	arene_7876_rdkit_conf_1.out: Valid Calc
# 	arene_7877_rdkit_conf_1.out: Valid Calc
# 	arene_7878_rdkit_conf_1.out: Valid Calc
# 	arene_7879_rdkit_conf_1.out: Valid Calc
# 	arene_7880_rdkit_conf_1.out: Valid Calc
# 	arene_7881_rdkit_conf_1.out: Valid Calc
# 	arene_7882_rdkit_conf_1.out: Valid Calc
# 	arene_7884_rdkit_conf_1.out: Valid Calc
# 	arene_7885_rdkit_conf_1.out: Valid Calc
# 	arene_7886_rdkit_conf_1.out: Valid Calc
# 	arene_7887_rdkit_conf_1.out: Valid Calc
# 	arene_7888_rdkit_conf_1.out: Valid Calc
# 	arene_7889_rdkit_conf_1.out: Valid Calc
# 	arene_7890_rdkit_conf_1.out: Valid Calc
# 	arene_7891_rdkit_conf_1.out: Valid Calc
# 	arene_7892_rdkit_conf_1.out: Valid Calc
# 	arene_7893_rdkit_conf_1.out: Valid Calc
# 	arene_7894_rdkit_conf_1.out: Valid Calc
# 	arene_7895_rdkit_conf_1.out: Valid Calc
# 	arene_7896_rdkit_conf_1.out: Valid Calc
# 	arene_7897_rdkit_conf_1.out: Valid Calc
# 	arene_7898_rdkit_conf_1.out: Valid Calc
# 	arene_7899_rdkit_conf_1.out: Valid Calc
# 	arene_7900_rdkit_conf_1.out: Valid Calc
# 	arene_7901_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_7902_rdkit_conf_1.out: Valid Calc
# 	arene_7903_rdkit_conf_1.out: Valid Calc
# 	arene_7904_rdkit_conf_1.out: Valid Calc
# 	arene_7905_rdkit_conf_1.out: Valid Calc
# 	arene_7906_rdkit_conf_1.out: Valid Calc
# 	arene_7907_rdkit_conf_1.out: Valid Calc
# 	arene_7908_rdkit_conf_1.out: Valid Calc
# 	arene_7909_rdkit_conf_1.out: Valid Calc
# 	arene_7910_rdkit_conf_1.out: Valid Calc
# 	arene_7911_rdkit_conf_1.out: Valid Calc
# 	arene_7912_rdkit_conf_1.out: Valid Calc
# 	arene_7913_rdkit_conf_1.out: Valid Calc
# 	arene_7914_rdkit_conf_1.out: Valid Calc
# 	arene_7915_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_7916_rdkit_conf_1.out: Valid Calc
# 	arene_7917_rdkit_conf_1.out: Valid Calc
# 	arene_7918_rdkit_conf_1.out: Valid Calc
# 	arene_7919_rdkit_conf_1.out: Valid Calc
# 	arene_7920_rdkit_conf_1.out: Valid Calc
# 	arene_7921_rdkit_conf_1.out: Valid Calc
# 	arene_7922_rdkit_conf_1.out: Valid Calc
# 	arene_7923_rdkit_conf_1.out: Valid Calc
# 	arene_7924_rdkit_conf_1.out: Valid Calc
# 	arene_7925_rdkit_conf_1.out: Valid Calc
# 	arene_7926_rdkit_conf_1.out: Valid Calc
# 	arene_7927_rdkit_conf_1.out: Valid Calc
# 	arene_7928_rdkit_conf_1.out: Valid Calc
# 	arene_7929_rdkit_conf_1.out: Valid Calc
# 	arene_7930_rdkit_conf_1.out: Valid Calc
# 	arene_7931_rdkit_conf_1.out: Valid Calc
# 	arene_7932_rdkit_conf_1.out: Valid Calc
# 	arene_7933_rdkit_conf_1.out: Valid Calc
# 	arene_7934_rdkit_conf_1.out: Valid Calc
# 	arene_7935_rdkit_conf_1.out: Valid Calc
# 	arene_7936_rdkit_conf_1.out: Valid Calc
# 	arene_7937_rdkit_conf_1.out: Valid Calc
# 	arene_7938_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_7939_rdkit_conf_1.out: Valid Calc
# 	arene_7940_rdkit_conf_1.out: Valid Calc
# 	arene_7941_rdkit_conf_1.out: Valid Calc
# 	arene_7942_rdkit_conf_1.out: Valid Calc
# 	arene_7943_rdkit_conf_1.out: Valid Calc
# 	arene_7944_rdkit_conf_1.out: Valid Calc
# 	arene_7945_rdkit_conf_1.out: Valid Calc
# 	arene_7946_rdkit_conf_1.out: Valid Calc
# 	arene_7947_rdkit_conf_1.out: Valid Calc
# 	arene_7948_rdkit_conf_1.out: Valid Calc
# 	arene_7949_rdkit_conf_1.out: Valid Calc
# 	arene_7950_rdkit_conf_1.out: Valid Calc
# 	arene_7951_rdkit_conf_1.out: Valid Calc
# 	arene_7952_rdkit_conf_1.out: Valid Calc
# 	arene_7953_rdkit_conf_1.out: Valid Calc
# 	arene_7954_rdkit_conf_1.out: Valid Calc
# 	arene_7955_rdkit_conf_1.out: Valid Calc
# 	arene_7956_rdkit_conf_1.out: Valid Calc
# 	arene_7957_rdkit_conf_1.out: Valid Calc
# 	arene_7958_rdkit_conf_1.out: Valid Calc
# 	arene_7959_rdkit_conf_1.out: Valid Calc
# 	arene_7960_rdkit_conf_1.out: Valid Calc
# 	arene_7961_rdkit_conf_1.out: Valid Calc
# 	arene_7962_rdkit_conf_1.out: Valid Calc
# 	arene_7963_rdkit_conf_1.out: Valid Calc
# 	arene_7964_rdkit_conf_1.out: Valid Calc
# 	arene_7965_rdkit_conf_1.out: Valid Calc
# 	arene_7966_rdkit_conf_1.out: Valid Calc
# 	arene_7967_rdkit_conf_1.out: Valid Calc
# 	arene_7968_rdkit_conf_1.out: Valid Calc
# 	arene_7969_rdkit_conf_1.out: Valid Calc
# 	arene_7971_rdkit_conf_1.out: Valid Calc
# 	arene_7972_rdkit_conf_1.out: Valid Calc
# 	arene_7973_rdkit_conf_1.out: Valid Calc
# 	arene_7974_rdkit_conf_1.out: Valid Calc
# 	arene_7975_rdkit_conf_1.out: Valid Calc
# 	arene_7976_rdkit_conf_1.out: Valid Calc
# 	arene_7977_rdkit_conf_1.out: Valid Calc
# 	arene_7978_rdkit_conf_1.out: Valid Calc
# 	arene_7979_rdkit_conf_1.out: Valid Calc
# 	arene_7980_rdkit_conf_1.out: Valid Calc
# 	arene_7981_rdkit_conf_1.out: Valid Calc
# 	arene_7982_rdkit_conf_1.out: Valid Calc
# 	arene_7983_rdkit_conf_1.out: Valid Calc
# 	arene_7984_rdkit_conf_1.out: Valid Calc
# 	arene_7985_rdkit_conf_1.out: Valid Calc
# 	arene_7986_rdkit_conf_1.out: Valid Calc
# 	arene_7987_rdkit_conf_1.out: Valid Calc
# 	arene_7988_rdkit_conf_1.out: Valid Calc
# 	arene_7989_rdkit_conf_1.out: Valid Calc
# 	arene_7990_rdkit_conf_1.out: Valid Calc
# 	arene_7991_rdkit_conf_1.out: Valid Calc
# 	arene_7992_rdkit_conf_1.out: Valid Calc
# 	arene_7993_rdkit_conf_1.out: Valid Calc
# 	arene_7994_rdkit_conf_1.out: Valid Calc
# 	arene_7995_rdkit_conf_1.out: Valid Calc
# 	arene_7996_rdkit_conf_1.out: Valid Calc
# 	arene_7997_rdkit_conf_1.out: Valid Calc
# 	arene_7998_rdkit_conf_1.out: Valid Calc
# 	arene_7999_rdkit_conf_1.out: Valid Calc
# 	arene_8000_rdkit_conf_1.out: Valid Calc
# 	arene_8001_rdkit_conf_1.out: Valid Calc
# 	arene_8002_rdkit_conf_1.out: Valid Calc
# 	arene_8003_rdkit_conf_1.out: Valid Calc
# 	arene_8004_rdkit_conf_1.out: Valid Calc
# 	arene_8005_rdkit_conf_1.out: Valid Calc
# 	arene_8006_rdkit_conf_1.out: Valid Calc
# 	arene_8007_rdkit_conf_1.out: Valid Calc
# 	arene_8008_rdkit_conf_1.out: Valid Calc
# 	arene_8009_rdkit_conf_1.out: Valid Calc
# 	arene_8010_rdkit_conf_1.out: Valid Calc
# 	arene_8011_rdkit_conf_1.out: Valid Calc
# 	arene_8012_rdkit_conf_1.out: Valid Calc
# 	arene_8013_rdkit_conf_1.out: Valid Calc
# 	arene_8014_rdkit_conf_1.out: Valid Calc
# 	arene_8015_rdkit_conf_1.out: Valid Calc
# 	arene_8016_rdkit_conf_1.out: Valid Calc
# 	arene_8017_rdkit_conf_1.out: Valid Calc
# 	arene_8018_rdkit_conf_1.out: Valid Calc
# 	arene_8019_rdkit_conf_1.out: Valid Calc
# 	arene_8020_rdkit_conf_1.out: Valid Calc
# 	arene_8021_rdkit_conf_1.out: Valid Calc
# 	arene_8022_rdkit_conf_1.out: Valid Calc
# 	arene_8023_rdkit_conf_1.out: Valid Calc
# 	arene_8025_rdkit_conf_1.out: Valid Calc
# 	arene_8026_rdkit_conf_1.out: Valid Calc
# 	arene_8027_rdkit_conf_1.out: Valid Calc
# 	arene_8028_rdkit_conf_1.out: Valid Calc
# 	arene_8029_rdkit_conf_1.out: Valid Calc
# 	arene_8030_rdkit_conf_1.out: Valid Calc
# 	arene_8031_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8032_rdkit_conf_1.out: Valid Calc
# 	arene_8033_rdkit_conf_1.out: Valid Calc
# 	arene_8034_rdkit_conf_1.out: Valid Calc
# 	arene_8035_rdkit_conf_1.out: Valid Calc
# 	arene_8036_rdkit_conf_1.out: Valid Calc
# 	arene_8037_rdkit_conf_1.out: Valid Calc
# 	arene_8038_rdkit_conf_1.out: Valid Calc
# 	arene_8039_rdkit_conf_1.out: Valid Calc
# 	arene_8040_rdkit_conf_1.out: Valid Calc
# 	arene_8041_rdkit_conf_1.out: Valid Calc
# 	arene_8042_rdkit_conf_1.out: Valid Calc
# 	arene_8043_rdkit_conf_1.out: Valid Calc
# 	arene_8044_rdkit_conf_1.out: Valid Calc
# 	arene_8045_rdkit_conf_1.out: Valid Calc
# 	arene_8046_rdkit_conf_1.out: Valid Calc
# 	arene_8047_rdkit_conf_1.out: Valid Calc
# 	arene_8048_rdkit_conf_1.out: Valid Calc
# 	arene_8049_rdkit_conf_1.out: Valid Calc
# 	arene_8050_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8051_rdkit_conf_1.out: Valid Calc
# 	arene_8052_rdkit_conf_1.out: Valid Calc
# 	arene_8053_rdkit_conf_1.out: Valid Calc
# 	arene_8054_rdkit_conf_1.out: Valid Calc
# 	arene_8055_rdkit_conf_1.out: Valid Calc
# 	arene_8056_rdkit_conf_1.out: Valid Calc
# 	arene_8057_rdkit_conf_1.out: Valid Calc
# 	arene_8058_rdkit_conf_1.out: Valid Calc
# 	arene_8059_rdkit_conf_1.out: Valid Calc
# 	arene_8060_rdkit_conf_1.out: Valid Calc
# 	arene_8061_rdkit_conf_1.out: Valid Calc
# 	arene_8062_rdkit_conf_1.out: Valid Calc
# 	arene_8063_rdkit_conf_1.out: Valid Calc
# 	arene_8064_rdkit_conf_1.out: Valid Calc
# 	arene_8065_rdkit_conf_1.out: Valid Calc
# 	arene_8066_rdkit_conf_1.out: Valid Calc
# 	arene_8067_rdkit_conf_1.out: Valid Calc
# 	arene_8068_rdkit_conf_1.out: Valid Calc
# 	arene_8069_rdkit_conf_1.out: Valid Calc
# 	arene_8070_rdkit_conf_1.out: Valid Calc
# 	arene_8071_rdkit_conf_1.out: Valid Calc
# 	arene_8072_rdkit_conf_1.out: Valid Calc
# 	arene_8073_rdkit_conf_1.out: Valid Calc
# 	arene_8074_rdkit_conf_1.out: Valid Calc
# 	arene_8075_rdkit_conf_1.out: Valid Calc
# 	arene_8076_rdkit_conf_1.out: Valid Calc
# 	arene_8077_rdkit_conf_1.out: Valid Calc
# 	arene_8078_rdkit_conf_1.out: Valid Calc
# 	arene_8079_rdkit_conf_1.out: Valid Calc
# 	arene_8080_rdkit_conf_1.out: Valid Calc
# 	arene_8081_rdkit_conf_1.out: Valid Calc
# 	arene_8082_rdkit_conf_1.out: Valid Calc
# 	arene_8083_rdkit_conf_1.out: Valid Calc
# 	arene_8084_rdkit_conf_1.out: Valid Calc
# 	arene_8085_rdkit_conf_1.out: Valid Calc
# 	arene_8086_rdkit_conf_1.out: Valid Calc
# 	arene_8087_rdkit_conf_1.out: Valid Calc
# 	arene_8088_rdkit_conf_1.out: Valid Calc
# 	arene_8089_rdkit_conf_1.out: Valid Calc
# 	arene_8090_rdkit_conf_1.out: Valid Calc
# 	arene_8091_rdkit_conf_1.out: Valid Calc
# 	arene_8092_rdkit_conf_1.out: Valid Calc
# 	arene_8093_rdkit_conf_1.out: Valid Calc
# 	arene_8094_rdkit_conf_1.out: Valid Calc
# 	arene_8095_rdkit_conf_1.out: Valid Calc
# 	arene_8096_rdkit_conf_1.out: Valid Calc
# 	arene_8097_rdkit_conf_1.out: Valid Calc
# 	arene_8098_rdkit_conf_1.out: Valid Calc
# 	arene_8099_rdkit_conf_1.out: Valid Calc
# 	arene_8100_rdkit_conf_1.out: Valid Calc
# 	arene_8101_rdkit_conf_1.out: Valid Calc
# 	arene_8102_rdkit_conf_1.out: Valid Calc
# 	arene_8103_rdkit_conf_1.out: Valid Calc
# 	arene_8104_rdkit_conf_1.out: Valid Calc
# 	arene_8105_rdkit_conf_1.out: Valid Calc
# 	arene_8106_rdkit_conf_1.out: Valid Calc
# 	arene_8107_rdkit_conf_1.out: Valid Calc
# 	arene_8108_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8109_rdkit_conf_1.out: Valid Calc
# 	arene_8110_rdkit_conf_1.out: Valid Calc
# 	arene_8111_rdkit_conf_1.out: Valid Calc
# 	arene_8112_rdkit_conf_1.out: Valid Calc
# 	arene_8113_rdkit_conf_1.out: Valid Calc
# 	arene_8114_rdkit_conf_1.out: Valid Calc
# 	arene_8115_rdkit_conf_1.out: Valid Calc
# 	arene_8116_rdkit_conf_1.out: Valid Calc
# 	arene_8117_rdkit_conf_1.out: Valid Calc
# 	arene_8118_rdkit_conf_1.out: Valid Calc
# 	arene_8119_rdkit_conf_1.out: Valid Calc
# 	arene_8120_rdkit_conf_1.out: Valid Calc
# 	arene_8121_rdkit_conf_1.out: Valid Calc
# 	arene_8122_rdkit_conf_1.out: Valid Calc
# 	arene_8123_rdkit_conf_1.out: Valid Calc
# 	arene_8124_rdkit_conf_1.out: Valid Calc
# 	arene_8125_rdkit_conf_1.out: Valid Calc
# 	arene_8126_rdkit_conf_1.out: Valid Calc
# 	arene_8127_rdkit_conf_1.out: Valid Calc
# 	arene_8128_rdkit_conf_1.out: Valid Calc
# 	arene_8129_rdkit_conf_1.out: Valid Calc
# 	arene_8130_rdkit_conf_1.out: Valid Calc
# 	arene_8131_rdkit_conf_1.out: Valid Calc
# 	arene_8132_rdkit_conf_1.out: Valid Calc
# 	arene_8133_rdkit_conf_1.out: Valid Calc
# 	arene_8134_rdkit_conf_1.out: Valid Calc
# 	arene_8135_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8136_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8137_rdkit_conf_1.out: Valid Calc
# 	arene_8138_rdkit_conf_1.out: Valid Calc
# 	arene_8139_rdkit_conf_1.out: Valid Calc
# 	arene_8140_rdkit_conf_1.out: Valid Calc
# 	arene_8141_rdkit_conf_1.out: Valid Calc
# 	arene_8142_rdkit_conf_1.out: Valid Calc
# 	arene_8143_rdkit_conf_1.out: Valid Calc
# 	arene_8144_rdkit_conf_1.out: Valid Calc
# 	arene_8145_rdkit_conf_1.out: Valid Calc
# 	arene_8146_rdkit_conf_1.out: Valid Calc
# 	arene_8147_rdkit_conf_1.out: Valid Calc
# 	arene_8148_rdkit_conf_1.out: Valid Calc
# 	arene_8149_rdkit_conf_1.out: Valid Calc
# 	arene_8150_rdkit_conf_1.out: Valid Calc
# 	arene_8151_rdkit_conf_1.out: Valid Calc
# 	arene_8152_rdkit_conf_1.out: Valid Calc
# 	arene_8153_rdkit_conf_1.out: Valid Calc
# 	arene_8154_rdkit_conf_1.out: Valid Calc
# 	arene_8155_rdkit_conf_1.out: Valid Calc
# 	arene_8156_rdkit_conf_1.out: Valid Calc
# 	arene_8157_rdkit_conf_1.out: Valid Calc
# 	arene_8158_rdkit_conf_1.out: Valid Calc
# 	arene_8159_rdkit_conf_1.out: Valid Calc
# 	arene_8160_rdkit_conf_1.out: Valid Calc
# 	arene_8161_rdkit_conf_1.out: Valid Calc
# 	arene_8162_rdkit_conf_1.out: Valid Calc
# 	arene_8163_rdkit_conf_1.out: Valid Calc
# 	arene_8164_rdkit_conf_1.out: Valid Calc
# 	arene_8165_rdkit_conf_1.out: Valid Calc
# 	arene_8166_rdkit_conf_1.out: Valid Calc
# 	arene_8167_rdkit_conf_1.out: Valid Calc
# 	arene_8168_rdkit_conf_1.out: Valid Calc
# 	arene_8169_rdkit_conf_1.out: Valid Calc
# 	arene_8170_rdkit_conf_1.out: Valid Calc
# 	arene_8171_rdkit_conf_1.out: Valid Calc
# 	arene_8172_rdkit_conf_1.out: Valid Calc
# 	arene_8173_rdkit_conf_1.out: Valid Calc
# 	arene_8174_rdkit_conf_1.out: Valid Calc
# 	arene_8175_rdkit_conf_1.out: Valid Calc
# 	arene_8176_rdkit_conf_1.out: Valid Calc
# 	arene_8177_rdkit_conf_1.out: Valid Calc
# 	arene_8178_rdkit_conf_1.out: Valid Calc
# 	arene_8179_rdkit_conf_1.out: Valid Calc
# 	arene_8180_rdkit_conf_1.out: Valid Calc
# 	arene_8181_rdkit_conf_1.out: Valid Calc
# 	arene_8182_rdkit_conf_1.out: Valid Calc
# 	arene_8183_rdkit_conf_1.out: Valid Calc
# 	arene_8184_rdkit_conf_1.out: Valid Calc
# 	arene_8185_rdkit_conf_1.out: Valid Calc
# 	arene_8186_rdkit_conf_1.out: Valid Calc
# 	arene_8187_rdkit_conf_1.out: Valid Calc
# 	arene_8188_rdkit_conf_1.out: Valid Calc
# 	arene_8189_rdkit_conf_1.out: Valid Calc
# 	arene_8190_rdkit_conf_1.out: Valid Calc
# 	arene_8191_rdkit_conf_1.out: Valid Calc
# 	arene_8193_rdkit_conf_1.out: Valid Calc
# 	arene_8194_rdkit_conf_1.out: Valid Calc
# 	arene_8195_rdkit_conf_1.out: Valid Calc
# 	arene_8196_rdkit_conf_1.out: Valid Calc
# 	arene_8197_rdkit_conf_1.out: Valid Calc
# 	arene_8198_rdkit_conf_1.out: Valid Calc
# 	arene_8199_rdkit_conf_1.out: Valid Calc
# 	arene_8200_rdkit_conf_1.out: Valid Calc
# 	arene_8201_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8202_rdkit_conf_1.out: Valid Calc
# 	arene_8203_rdkit_conf_1.out: Valid Calc
# 	arene_8204_rdkit_conf_1.out: Valid Calc
# 	arene_8205_rdkit_conf_1.out: Valid Calc
# 	arene_8206_rdkit_conf_1.out: Valid Calc
# 	arene_8207_rdkit_conf_1.out: 	IMAGINARY FREQS! Moved to /Extra_Imaginary_Frequency/.
# 	arene_8208_rdkit_conf_1.out: Valid Calc
# 	arene_8209_rdkit_conf_1.out: Valid Calc
# 	arene_8210_rdkit_conf_1.out: Valid Calc
# 	arene_8211_rdkit_conf_1.out: Valid Calc
# 	arene_8212_rdkit_conf_1.out: Valid Calc
# 	arene_8213_rdkit_conf_1.out: Valid Calc
# 	arene_8214_rdkit_conf_1.out: Valid Calc
# 	arene_8215_rdkit_conf_1.out: Valid Calc
# 	arene_8216_rdkit_conf_1.out: Valid Calc
# 	arene_8217_rdkit_conf_1.out: Valid Calc
# 	arene_8218_rdkit_conf_1.out: Valid Calc
# 	arene_8219_rdkit_conf_1.out: Valid Calc
# 	arene_8220_rdkit_conf_1.out: Valid Calc
# 	arene_8221_rdkit_conf_1.out: Valid Calc
# 	arene_8223_rdkit_conf_1.out: Valid Calc
# 	arene_8225_rdkit_conf_1.out: Valid Calc
# 	arene_8226_rdkit_conf_1.out: Valid Calc
# 	arene_8227_rdkit_conf_1.out: Valid Calc
# 	arene_8228_rdkit_conf_1.out: Valid Calc
# 	arene_8229_rdkit_conf_1.out: Valid Calc
# 	arene_8230_rdkit_conf_1.out: Valid Calc
# 	arene_8232_rdkit_conf_1.out: Valid Calc
# 	arene_8233_rdkit_conf_1.out: Valid Calc
# 	arene_8234_rdkit_conf_1.out: Valid Calc
# 	arene_8235_rdkit_conf_1.out: Valid Calc
# 	arene_8236_rdkit_conf_1.out: Valid Calc
# 	arene_8237_rdkit_conf_1.out: Valid Calc
# 	arene_8238_rdkit_conf_1.out: Valid Calc
# 	arene_8239_rdkit_conf_1.out: Valid Calc
# 	arene_8240_rdkit_conf_1.out: Valid Calc
# 	arene_8241_rdkit_conf_1.out: Valid Calc
# 	arene_8242_rdkit_conf_1.out: Valid Calc
# 	arene_8243_rdkit_conf_1.out: Valid Calc
# 	arene_8244_rdkit_conf_1.out: Valid Calc
# 	arene_8245_rdkit_conf_1.out: Valid Calc
# 	arene_8246_rdkit_conf_1.out: Valid Calc
# 	arene_8247_rdkit_conf_1.out: Valid Calc
#
# Completed analysis of frequency data for .out files in '/Arene_Orca_DFT_Outputs/'
#
# Number of failed .outs due to imaginary frequencies: 173

# %%
### Get some analytics on pass/fail after a big pass of DFT calculations ### 
"""
This cell is for analysis on job completion/failures. It will report how many jobs are still "successful" and
also tell you the # of failures based on how they were triaged. Ideally you should have all of your .outs accounted
for, but the cells below this one can help find missing .inps/.outs. The next step after this is to reset any
failed .outs/resubmit jobs as desired. 
"""

#Directories that contain .inps, "good".outs, and fail.outs, respectively
target_inp_dir = arene_dft_input_path
target_out_dir = arene_dft_output_path
target_fail_dir = arene_failed_to_terminate

#how many .inp files in /target_inp_dir?
input_filepaths = get_filepaths_in_target_dir_recursive(target_inp_dir, ".inp")
num_expected = len(input_filepaths)
print(f"\033[1mFound {num_expected} 'ORCA.inp' DFT input files in '{target_inp_dir.stem}' => Expected ORCA.outs: {num_expected}\n\033[0m") #debug

#get a list of the validated .outs in output directory
#MAKE SURE YOU HAVE PROCESSED YOUR DATA USING THE ABOVE 2 CELLS! Or I'll haunt you 0.0
validated_out_filepaths = get_filepaths_in_target_dir(target_out_dir, ".out")

#Gather all the failed .outs (recursive, so will get all files in /target_fail_dir/subdir(s))
failed_out_filepaths = get_filepaths_in_target_dir_recursive(target_fail_dir, ".out")

#how many total good and failed .outs are in the /target_out_dir
accounted_for_filepaths = list(validated_out_filepaths + failed_out_filepaths)
num_outs_accounted_for = len(accounted_for_filepaths)

#gives some extra details
how_many_jobs_where(target_out_dir)
# Out:
# Found 8247 .inp files in '/Arene_Orca_DFT_Inputs/' (recursive)
# Found 8247 'ORCA.inp' DFT input files in 'Arene_Orca_DFT_Inputs' => Expected ORCA.outs: 8247
#
# Found 7880 .out files in '/Arene_Orca_DFT_Outputs/'
# Found 367 .out files in '/Failed_Calculations/' (recursive)
#
# Checking C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs for Orca.out files after processesing...
#
# Number of VALIDATED ORCA.out files in Arene_Orca_DFT_Outputs: 7880
#
# Number of FAILED ORCA.outs in /Failed_Calculations/:          367
# 	- Failed due to extraneous Imaginary Freqs:           173
# 	- Failed due to lack of convergence:                  155
# 	- Complete and Utter Hopeless Failures:                39
# 	- Failed due to missing freq data:                      0
#
# Total number of ORCA.out files in /Arene_Orca_DFT_Outputs/ accounted for: 8247

# %%
### DO YOUR .OUTs =/= YOUR .INPs? Use this cell/method to find the offending file names ### 
"""
Ex: 
    - you ran a first round of DFT calculations and you don't have all your .outs (missing .outs)
    - you find out you are missing .inp files somehow and want to find out which to regen/find
"""
#(dir containing your .out files, dir containing your .inp files
difference_found = find_extra_inp_out_files_in_dirs(arene_dft_output_path, arene_dft_input_path)

if difference_found: #this will print an error message if you are missing .inp files
    print("")
    print("Look for your .inp file(s)!")
# Out:
# Parsing specified .inp/.out directories for extra .inp/.out files....
# Directory with .out files: C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs
# Directory with .inp files: C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Inputs
#
# Found 8247 .out files in '/Arene_Orca_DFT_Outputs/' (recursive)
# Found 8247 'ORCA.out' DFT output files in /Arene_Orca_DFT_Outputs/
# Found 8247 .inp files in '/Arene_Orca_DFT_Inputs/' (recursive)
# Found 8247 'ORCA.inp' DFT input files in /Arene_Orca_DFT_Inputs/
#
# Number of .inps and .outs match!
# Lengths: .outs = 8247, .inps = 8247

# %%
### DO YOU HAVE EXTRA .OUTS? Use this cell/method ###
"""
#Ex: you used this notebook to regenerate new .inp files for failed .outs in /convergence_failure 
    #and/or #/extra_imaginary_frequency. You then re-ran those jobs and downloaded the new .outs 
    #to your /out_files_dir. You've parsed the .outs but now you have too many. There are likely 
    #extra .outs in your failed_dir that need to be deleted since now the job has terminated without 
    #an #error/has been deemed a success. This method will find and delete and extra failed .outs.
"""
#path to your successful .outs, path to your failed .outs
find_and_del_replaced_outs(arene_dft_output_path, arene_failed_to_terminate)
#check_for_replaced_outs(aryne_dft_output_path, aryne_failed_to_terminate)
# Out:
# Found 367 .out files in '/Failed_Calculations/' (recursive)
# Found 367 failed ORCA.out files in /Failed_Calculations/.

# %%
### RESET FAILED.OUTs in /failed_convergence/ - WRITE NEW .INPs for Resubmission on HPC ### 
"""
    Run this cell to generate new .inp files for any jobs currently in the /failed_calculation/..
    ../convergence_failure/ directory. New inputs will be written to input/resub by default, here. 
    New input files are generated using the last geometry extracted from the .out file and reads 
    the input details/level of theory from the .out file. 
"""
print(f'Generating new .inp files for jobs that failed to converge.\n')

#point at the correct dirs
failed_conv_dir = arene_no_convergence_dir
resub_dir = arene_dft_resub_input

#grab the files in the failed convergence directory
fail_conv_filepaths = get_filepaths_in_target_dir(failed_conv_dir, ".out")
print(f'Located {len(fail_conv_filepaths)} .out files to make new .inps for.\n')

write_count = 0 #number of files written to /resub

#Reset just pulls the last geom from the .out file
### To-Do - some inferencing on prior job outcome => better input handling
for bad_opt in fail_conv_filepaths:
    #pulls inp data from .out file; pulls last geometry from prev. opt; gens new .inp 
    #with same LOT and writes to a specified dir. 
    write_resub_inp_for_failed_conv(bad_opt, resub_dir)
    write_count +=1 #inc the counter 

print(f"\nWrote {write_count} new .inp files for resubmission to {resub_dir}")
# Out:
# Generating new .inp files for jobs that failed to converge.
#
# Found 155 .out files in '/Convergence_Failure/'
# Located 155 .out files to make new .inps for.
#
# New inp for resubmission of arene_96_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_239_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_322_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_509_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_679_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_713_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_732_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_734_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_738_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_775_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_812_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_851_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_919_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_939_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1055_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1066_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1134_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1216_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1226_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1292_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1412_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1606_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1641_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1710_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1725_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1767_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1780_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1929_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2171_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2408_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2467_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2469_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2488_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2492_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2499_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2524_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2608_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2639_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2715_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2754_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2768_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2917_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2973_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2979_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3109_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3132_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3134_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3203_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3205_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3249_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3309_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3326_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3342_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3346_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3486_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3501_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3506_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3729_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3810_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3892_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3925_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3956_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3991_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4026_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4042_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4054_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4080_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4165_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4172_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4243_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4299_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4323_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4387_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4407_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4421_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4455_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4461_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4502_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4540_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4742_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4764_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4823_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4857_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4930_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4980_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5040_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5150_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5297_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5299_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5303_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5417_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5467_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5497_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5499_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5507_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5549_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5586_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5677_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5723_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5778_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5782_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5788_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5790_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5871_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5913_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5937_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5993_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6059_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6103_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6251_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6306_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6325_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6481_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6538_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6647_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6655_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6805_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6846_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6854_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6872_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6875_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6917_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6941_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6964_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6968_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6996_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7009_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7043_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7070_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7116_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7126_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7157_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7169_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7314_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7323_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7329_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7331_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7364_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7393_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7410_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7512_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7526_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7586_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7701_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7726_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7766_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7781_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7789_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7883_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7970_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8024_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8192_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8222_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8224_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8231_rdkit_conf_1 written to /Arene_Resubs/
#
# Wrote 155 new .inp files for resubmission to C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Inputs\Arene_Resubs

# %%
### Resetting /extra_imaginary_frequency/ jobs: Write new .inp files for jobs that failed due to IF(s) ### 
print(f'Generating new .inp files for jobs that failed due to having imaginary frequency/ies.\n')

"""
    Run this cell to generate new .inp files for any jobs currently in the /failed_calculation/..
    ../extra_imaginary_frequency directory. New inputs will be written to input/resub by default, here. 
    New geometries are generated by displacing geometries along an imaginary frequency using the norm-
    alized displacement vector and a 0.15 Ang. scalar. 
"""

target_dir = arene_im_freq_dir
resub_dir = arene_dft_resub_input

filepaths = get_filepaths_in_target_dir(target_dir, ".out")
print(f'Located {len(filepaths)} .out files to make new .inps for.\n')

write_count = 0 #number of files written to /resub

#calculate a new inp. geometry for resub
#uses the last geom in the .inp file in a dumb way so these can still fail to opt
for if_opt in filepaths:
    write_resub_inp_for_failed_imag_freq(if_opt, resub_dir)
    write_count +=1 #inc the counter 

print(f"\nWrote {write_count} new .inp files for resubmission to {resub_dir}")
# Out:
# Generating new .inp files for jobs that failed due to having imaginary frequency/ies.
#
# Found 173 .out files in '/Extra_Imaginary_Frequency/'
# Located 173 .out files to make new .inps for.
#
# New inp for resubmission of arene_9_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_64_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_127_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_177_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_186_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_215_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_219_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_247_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_335_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_378_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_495_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_544_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_556_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_574_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_589_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_638_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_705_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_735_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_743_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_898_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_900_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_942_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_962_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_986_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1017_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1070_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1162_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1283_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1453_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1494_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1499_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1569_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1608_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1612_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1637_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1660_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1720_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1730_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1734_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1737_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1749_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_1988_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2026_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2056_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2061_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2146_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2177_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2231_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2237_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2251_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2274_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2334_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2403_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2427_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2433_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2451_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2560_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2665_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2713_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2752_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2927_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2951_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2963_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_2974_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3179_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3235_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3281_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3337_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3358_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3366_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3381_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3436_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3504_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3521_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3684_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3759_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3761_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3825_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3858_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_3920_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4013_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4050_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4096_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4140_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4204_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4259_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4293_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4332_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4335_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4406_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4488_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4558_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4762_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4828_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4874_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4892_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4896_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_4966_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5015_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5036_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5052_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5056_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5073_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5080_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5240_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5414_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5439_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5456_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5460_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5626_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5644_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5660_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5675_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5757_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5796_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5811_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5845_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5929_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5980_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_5992_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6001_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6005_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6172_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6346_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6425_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6426_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6441_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6442_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6448_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6472_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6547_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6550_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6608_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6649_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6650_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6659_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6705_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6742_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6780_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6784_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6870_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_6954_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7030_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7033_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7062_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7082_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7135_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7144_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7161_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7184_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7192_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7213_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7304_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7320_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7337_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7351_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7503_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7594_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7681_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7752_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7779_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7858_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7860_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7901_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7915_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_7938_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8031_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8050_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8108_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8135_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8136_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8201_rdkit_conf_1 written to /Arene_Resubs/
# New inp for resubmission of arene_8207_rdkit_conf_1 written to /Arene_Resubs/
#
# Wrote 173 new .inp files for resubmission to C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Inputs\Arene_Resubs

# %%
resub_dir = arene_dft_resub_input
split_dir_into_subdirs(resub_dir, 50)
# Out:
# Found 328 DFT Orca.inp files in C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Inputs\Arene_Resubs
