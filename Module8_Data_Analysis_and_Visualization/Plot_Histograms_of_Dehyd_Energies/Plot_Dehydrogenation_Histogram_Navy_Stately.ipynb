# %%
from pathlib import Path
import pandas as pd
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# %%
### Read in the Arene/Aryne SMILES.csv dataset ###

#script is located in cwd
histo_path = Path.cwd()

#mod8 path is one above
mod8_path = histo_path.parent #get the path above this current dir

#tld is one above mod8
project_dir = mod8_path.parent

#data is located in the mod7 dir
data_path = project_dir / "Module7_Extract_DFT_Molecular_Descriptors" / "Aryne_Calculated_Molecular_Descriptors.csv"
incoming_data = pd.read_csv(data_path)
incoming_data.head()
# Out:
#   arene_ID          arene_smiles  arene_energy aryne_ID  \
# 0  arene_1       O=c1nc2ccsc2cs1    -1156.0883  aryne_1
# 1  arene_2    c1csn2nn[nH]cc-2o1     -846.4294  aryne_2
# 2  arene_3   O=c1cnc2occsc=2c1=O     -946.3140  aryne_3
# 3  arene_4  O=c1cnc2sc(=O)ccc2s1    -1269.2819  aryne_4
# 4  arene_5   O=c1ccn2sccsn2[nH]1    -1228.5052  aryne_5
#
#             aryne_smiles  aryne_energy  dehydrogenation_energy  Sz_Aryne_Ring  \
# 0       O=c1nc2c#csc2cs1    -1154.7269                124.0423              5
# 1    c1oc2c[nH]nnn-2sc#1     -845.1003                103.7738              6
# 2   O=c1cnc2oc#csc=2c1=O     -944.9744                110.3626              6
# 3  O=c1c#cc2sc(=O)cnc2s1    -1267.9693                 93.4199              6
# 4   O=c1c#cn2sccsn2[nH]1    -1227.1702                107.4761              6
#
#   RingSys_Type  Aryne_Aindx_1  ...  Max_angle_dev Sum_abs_dev Aryne_DiH_Ang  \
# 0        multi              4  ...        17.4185     20.9698         0.091
# 1        multi              9  ...        28.1870     32.3229         9.361
# 2        multi              6  ...        27.9700     28.5260         0.049
# 3        multi              2  ...        16.0394     29.2699         0.582
# 4        multi              2  ...        11.5546     15.8775        28.895
#
#    eHOMO(eV) eLUMO(eV) H_L_Gap(eV)  Hirsh_chgs_Aindx_1 Hirsh_chgs_Aindx_2  \
# 0    -8.2033   -3.1162      5.0871              0.0001            -0.0688
# 1    -7.5885   -1.8409      5.7476             -0.1534             0.0712
# 2    -7.6077   -3.6957      3.9120              0.0756            -0.1217
# 3    -8.2904   -2.7467      5.5437             -0.0285            -0.0286
# 4    -7.5024   -1.8204      5.6820             -0.1116             0.0126
#
#   Sum_Abs_Hirsh_aryne  Abs_Dif_Bnd_Angl
# 0              0.0689           13.8672
# 1              0.2246           32.3229
# 2              0.1973           27.4140
# 3              0.0571            2.8089
# 4              0.1242           15.8775
#
# [5 rows x 33 columns]

# %%
ax = sns.displot(data=incoming_data["dehydrogenation_energy"], kde=False, rug=False, bins=80, color='midnightblue', 
                 height=6, aspect=1.3333, label='8,115 Total Hetarynes')

ax.set(xlabel='Dehydrogenation Energy (kcal/mol)')
ax.set(ylabel='Frequency of Hetarynes (n = 8110)')
plt.legend()
plt.xlim(80,170)
plt.axvline(x=115, color='green', linestyle='--')
plt.axvline(x=130, color='red', linestyle='--')

#ax.patches[0].set_facecolor('green')

#save the figure, locally.
plt.savefig('dehydrogenation_energy_histogram_navy_boring.png', bbox_inches="tight", transparent=True)
