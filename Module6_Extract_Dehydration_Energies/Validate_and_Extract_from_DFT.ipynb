# %%
#General Dependencies
from pathlib import Path
import shutil, os, glob, re
import pandas as pd
import numpy as np
from itertools import islice
from natsort import natsorted
from file_read_backwards import FileReadBackwards

#RDKit Dependencies
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import BondType
from rdkit.Chem import rdMolTransforms
from rdkit.Chem import GetPeriodicTable
from rdkit.Chem import PeriodicTable

# %% [markdown]
# """
# ### Notebook Overview:
# Written by @GCH v1.0 - last updt. 05/05/2026
#
# This notebook contains code to perform more project-specific DFT validation and to extract relevant data from validated ORCA 5.0.3 output (.out) files and write output files (ex: .xyz, .sdf) from the DFT-optimized .out files. Once the DFT.out files are validated, extract dE for arenes/arynes and calculate a dE(dehydration) = dE(Arene) ==> dE(Aryne) + dE(H2) in kcal/mol. Outputs a 'Calculated_Dehydration_Energies.csv' to the /Project_dir and prepares files/directories for Featurization/Parameterization.
#
# ### Planned Features:
# 1. Ensure all methods are commented/have documentation
# 2. Better Error-Handling/exceptions
# 3. Fine-tune the cutoffs for bond breaking/formation checks/isomerization
#
# ### Motivation:
# The "Bacon" notebook is intended to do a strict pass/fail analysis on raw DFT .out files. Bacon will indicate whether a DFT
# .out is valid or not (completed successfully, converged to a min., no imaginary freqs) but not if the calculation itself was
# actually successful/chemically meaningful for a specific task. Ex: In the current arynes case, it's possible for an aryne to
# break open during optimization. These calculations can converge successfully but are essentially meaningless in the context
# of a dataset curation/ML-training task as the calculation itself is invalid. This notebook is a futher layer of validation on
# calculations and also is a means of generating accessory files necessary for archival or dataset curation online (.xyz/.sdfs).
#
# ### How to Use this Notebook:
# 1. Define relevant Paths to necessary files in the PATH cell, below.
# 2. Define relevant output Paths for new files to be written to in the PATH cell, below.
# 3. Run the notebook from the top-level project directory to process .outs and generate .xyz and .sd-files
# 4. There are several project-specific cells in this notebook find and exclude any arynes that broke open during optimization
# 5. Once validated, DFT energies are extracted from .outs and used to calculate dE(dehyd.)
# 6. An output .csv containing dE(dehyd.) data is written to a loccal dir
# 7. The final cell will operate on all specified directories to ensure that only validated .outs/.xyzs/sdfs remain for analysis
#
# ### Example:
# I have a dir with 8760 putatively valid DFT .out files in /Aryne_Orca_DFT_Outputs/ that I've validated using Bacon (or some
# equiv software, ex: AQME QCORR). I want to generate an .xyz file containing the optimized molecular geometry for each valid
# calculation. I also want to generate an .sd-file (.sdf) for long-term archival, as .sdfs contain connectivity explicitly. I
# run all the cells in this notebook and discover that 66 of my arynes broke open during optimization. Thus at the end of this
# process I should have 8694 final .outs, .xyzs, and .sdfs in their respective top level dirs within my .outs dir.
#
# ### Program Details
# Input: Directories containing Orca 5.0.3 DFT output files (opt+freq; M06-2X-D3 / def2-SVP)
#
# ### Validation/GeometryExtraction/File Generation ###
# -Extracts optimized .xyz coordinates from Orca 5.0.3 DFT output files and outputs .xyz files to /optimized_xyz_files/
# -Uses generated .xyz files to create new .sdf files containing the optimized geometry, output to /Optimized_SDFs/
#
# ### Find and remove broken/invalid arynes from the dataset
# -For aryne structures, compares the pre/post-opt .sdf files for bond cleavage to ID arynes broken open during optimization
# -Removes broken arynes to arynes/success/broken_arynes to remove them from the dataset, output to /Excluded_Aryne_Outs/
#
# ### Truncate Dataset to include only entries for "complete" reactions (Arene => Aryne + H2)
# - Identifies validated but unpaired .out files in the /success/ dirs that don't form dehydrogenation pairs
# - Moves those non-utilized arene/aryne.outs to /excluded subdir within each Arene/Aryne subdirs
#
# ### Calclulate dE(dehydrogenation) for remaining pairs
# - for any remaining structures, calculate the dE(dehydrogenation) between validated structures
# - Output a cleaned .csv file with data pertaining only to validated .out/.sdf/.xyz/RDKit mol structures
#
# ### Clean local directories for downstream parameterization
# - Removes any unpaired files to subdirs to ensure a 1:1 match for directory parsing during parameterization
# """

# %%
### Define PATHS/relevant directories ### "
#top level project dir (TLD)
project_dir = Path.cwd()

#dirs containing 'Bacon'-processed 'orca.out' DFT output files (or in theory any opt+freq .out files)
arene_dft_output_path = project_dir/"DFT_Arene_Data"/"Arene_Orca_DFT_Outputs"
aryne_dft_output_path = project_dir/"DFT_Aryne_Data"/"Aryne_Orca_DFT_Outputs"

#dirs to contain post-optimization .xyz files (extracted from Orca DFT .outs)
arene_post_opt_xyz_path = arene_dft_output_path/"Arene_Opt_xyz_Files"
aryne_post_opt_xyz_path = aryne_dft_output_path/"Aryne_Opt_xyz_Files"
arene_post_opt_xyz_path.mkdir(parents=True, exist_ok=True)
aryne_post_opt_xyz_path.mkdir(parents=True, exist_ok=True)

#dirs to contain post-optimization .sd-files (generated using DFT .xyz data)
arene_post_opt_sdf_path = arene_dft_output_path/"Arene_Post_Opt_sdfs"
aryne_post_opt_sdf_path = aryne_dft_output_path/"Aryne_Post_Opt_sdfs"
arene_post_opt_sdf_path.mkdir(parents=True, exist_ok=True)
aryne_post_opt_sdf_path.mkdir(parents=True, exist_ok=True)

#dirs which contain the pre-optimization .sdf files (used to generate DFT .inps/fix the bad SDF connect.)
arene_pre_opt_sdf_path = project_dir/"DFT_Arene_Data"/"Arene_Orca_DFT_Inputs"/"Arene_PreOpt_sdfs"
aryne_pre_opt_sdf_path = project_dir/"DFT_Aryne_Data"/"Aryne_Orca_DFT_Inputs"/"Aryne_PreOpt_sdfs"
arene_pre_opt_sdf_path.mkdir(parents=True, exist_ok=True)
aryne_pre_opt_sdf_path.mkdir(parents=True, exist_ok=True)

# %%
def get_filepaths_in_target_dir(target_directory: Path, extension: str, printing=True):
    """
    Function: returns a list of Path objects pertaining to files in a specified directory. Searches for specific .ext
    
    Input:
        - target_directory; Path containing files with the '.extension'
        - extension; str: a string specifying an extension to use, ex: ".out", ".inp", ".sdf" etc.
        - printing; bool; Default value = True; controls printing back to user
        
    Returns: 
        - filepaths - a list of filepaths for each file wit .extension' in 'target_directory'
    """
    
    #grab user extension with a search wildcard
    file_extension = f"*{extension}"
    
    #gather and sort .ext files in /target_directory/
    filepaths = target_directory.glob(file_extension)
    filepaths = natsorted(filepaths, key=str)

    #return some user info
    if printing:
        print(f"\033[1mFound {len(filepaths)} {extension} files in '/{target_directory.stem}/\033[0m'")

    #return the list of located filepaths
    return filepaths

# %%
def write_opt_xyz_files_orca(outputs_dir: Path, destination_dir: Path):
    """
    Function:
        1. Extracts optimized DFT coordinates from Orca 5.x output files contained in '/target_directory/'
        2. If one doesn't exist, writes a formatted .xyz file for each output file to '/destination_dir/'
        
    Input:
        - outputs_dir: Path; a directory containing Orca dft .out files (output files)
        - destination_dir: Path; a directory that will contain the newly written .xyz files
        
    Returns:
        - N/A - no direct return but writes .xyz files to specified directory; output text to terminal. 
    """

    #print a notice to user about what is happening
    print(f"\033[1mWriting new .xyz files from DFT-optimized .out files in '/{outputs_dir.stem}/'....\033[0m")

    #get the list of output files in 'target_directory' to extract xyz coords from
    dft_out_paths = get_filepaths_in_target_dir(outputs_dir, ".out")

    #Next loop over all the gathered .out files; from each one, extract the opt. geom as .xyz
    written_count = 0 #keeping track for printing summary to user
    existing_count = 0
    for dft_out_path in dft_out_paths:
        
        #get the output's filename with no extension
        dft_out_name = dft_out_path.stem

        #use the filename to generate a new .xyz file
        xyz_out_name = dft_out_name + ".xyz"
        
        #store a name for the to-be-made xyz file's path 
        new_xyz_path = destination_dir / xyz_out_name

        #Check if an .xyz file already exists
        if new_xyz_path.is_file(): 
            existing_count += 1
            continue

        #if not, make a new one; pull the opt'd geom from the .out file
        else:
            #extract the optimized .xyz coords using the get_opt_geom() method
            opt_geom = get_opt_geom(dft_out_path)

            #count the number of lines in the geom for .xyz header
            num_atoms_in_xyz = len(opt_geom)

            #generate an empty file to populate with data
            new_xyz_path.touch()
            
            #write the .xyz data into the .xyz file
            with open(new_xyz_path, 'w') as file_object:

                #for progress monitoring
                print(f"\tOptimized .xyz file written: '{new_xyz_path.name}'")
                
                #write the number of atoms at the top plus blank line (following .xyz convention)
                file_object.write(str(num_atoms_in_xyz) + "\n\n")
                
                #write the opt geom DF as a string, below
                file_object.write(opt_geom.to_string(header=False, index=False))
                
                written_count += 1 #count that an .xyz was written

    #give user some diagnostics on how many files existed
    if existing_count >= 1:
        print(f"\033[1m\nExisting .xyz files in '/{destination_dir.name}/': {existing_count}\033[0m")

    #give user some diagnostics on how many files were newly made
    if written_count != 0:
        print(f"\033[1m\nOptimized .xyz files written to '/{destination_dir.name}/': {written_count}\033[0m")

# %%
def sdf_to_mol_rdkit(path_to_sd_file: Path):
    """
    Function: Converts an SD-file containing a single molecule to an RDKit mol object. Returns the mol object. 
    
    Input:
        - path_to_sd_file: Path; a path to a single named .sd-file
        
    Returns:
        - mol: an RDKit MOL object (assuming a single mol in each .sdf)
    """

    #SDMolSupplier is a class that supplies mol data from an SD-file. SDFs can contain many mols in seq
    #so you need to "supply" them one at a time from the sdf. 
    supplier = Chem.SDMolSupplier(path_to_sd_file, removeHs=False, sanitize=True)

    mol = None # assign a default none to mol 
    
    for m in supplier: #for each of the objects pulled from the sdf and retained in "supplier"
        if m is not None: #If RDKit can interpret the object as a mol, 
            mol = m #assign the mol object to "mol"

        else: #if RDkit can't interpret the supplied object,
            
            continue #go to the next object in supplier; N/A here

    #return the mol if it's good
    return mol

# %%
def sdfs_to_mols_rdkit(path_to_sdfs: Path):
    """
    Function: Given a directory containing many sd-files, get all the .sdfs and convert them to RDKit
        mol objects. Returns a list of RDKit mol objects. 

        1. If there are failed sdf => mol conversions, prints erroneous file names
        2. Creates an /sdfs_not_convertible_to_mols/ dir within /path_to_sdfs/
        3. Moves failed_sdfs (.sdf files not convertible to mols) to dir in #2
        
    Input:
        - path_to_sdfs: Path; a path to directory containing multiple .sd-files
    
    Returns:
        - rdkit_mols: List; a list of RDKit MOL objects read from .sdfs
    """
    
    #get the list of .sdf files in 'target_directory' 
    sdf_paths = get_filepaths_in_target_dir(path_to_sdfs, ".sdf", printing=False)

    #empty lists to keep track of files
    rdkit_mols = []
    failed_sdfs = []
    
    #Loop through each sd-file contained in the specified directory
    for sdf_file in sdf_paths:
        #SDMolSupplier is a class that supplies mol data from an SD-file. SDFs can contain many mols in seq
        #so you need to "supply" them one at a time from the sdf. 
        supplier = Chem.SDMolSupplier(sdf_file)
        #Chem.SDMolSupplier

        for mol in supplier:
            if mol is None:
                print(f'Error Mol: {sdf_file.stem}')
                failed_sdfs.append(sdf_file)
                continue
                
            elif mol is not None:
                print(f"Validated RDKit mol: '{sdf_file.name}'")
                rdkit_mols.append(mol)

    #if there are no errors, code continues past this check        
    if len(failed_sdfs) != 0:
        print(f'\nFailed mols: {len(failed_sdfs)}') #if there ARE errors, print them out, here
        #move those failed .sdf files to an 'error_sdfs" directory
        source_dir = path_to_sdfs
        dest_dir = path_to_sdfs/"sdfs_not_convertible_to_mols"
        dest_dir.mkdir(parents=True, exist_ok=True)

        for failed_sdf in failed_sdfs:
            if failed_sdf.is_file():
                new_file_path = dest_dir/failed_sdf.name
                shutil.move(failed_sdf, new_file_path)
                print(f"Moved '{failed_sdf.name}' to /error_sdfs dir")
                  
    return rdkit_mols

# %%
def get_opt_geom(dft_output_file_path: Path):
    """
    Function: Parses a DFT .out file (Orca 5.0.3) for the optimized geometry in .xyz coordinates.
        Returns the geometry as a Pandas DF with column format: AtomID X Y Z
    
    Input:
        - dft_output_file_path: Path; A filepath to a DFT output file (Orca)
        
    Returns: 
        - geom_df: a Pandas DF containing the optimized geometry extracted from a DFT .out
    """

    file_name = dft_output_file_path

    captured_geom_blocks = []

    #empty string to store captured geom lines
    geom_block = []
    geom_block_list = []
    
    #regex match pattern
    END_PATTERN = '^-'
    
    #turn off printing as default
    printing = False
    found_start = False

    #read through a file line-by-line
    with open(file_name, "r") as file:
        for line in file:
            #Read through lines until hitting the Final Geometry Block indicator in text
            if line.strip().startswith("CARTESIAN COORDINATES (ANGSTROEM)"):
                #once the line has been found, indicate that it's time to start printing lines
                found_start = True
                #stops the current loop iteration and goes to the next line
                continue
    
            #once a loop iter hits the end pattern, do one of two things:	
            elif re.match(END_PATTERN, line):
    
                #if a second end (the last '---' is hit, stop printing. 
                if printing:
                    found_start = False
                    printing = False
                    #get the current geom block and save it to a list
                    geom_block_list.append(geom_block)
                    #empty the geom block so the next can be captured
                    geom_block = []
                    continue
    
                #if a start has been found, capture lines
                #this skips the first --- right under the start line
                if found_start:
                    printing = True
                continue
    
            #if match is found, printing is "on"
            #print/capture the line
            if printing:
                geom_block.append(line.strip())
    
    #the last geometry in this list should be the optimized one
    #can confirm looking for "*** FINAL ENERGY EVALUATION AT THE STATIONARY POINT ***" line
    optimized_geom_raw = geom_block_list[-1]
    final_geom = []
    for line in optimized_geom_raw[:-1]:
        stripped = line.strip()
        geom_line = stripped.split()
        final_geom.append(geom_line)
        
    #convert the geometry to a pd DF
    geom_df = pd.DataFrame(final_geom, columns=["AtomID", "x", "y", "z"])
    #set the index to be from 1 rather than 0 - we will work from atom index indices
    #geom_df.index = pd.RangeIndex(1, len(geom_df.index) + 1)
    
    #note the atom indices are 0, not 1
    return geom_df

# %%
def compare_mol_connectivity(mol_in: Chem.Mol, atomic_symbols: list[str], xyz_coords: np.ndarray) -> list[str]:
    """
    Function: Distance-based check for bonds that have broken (or formed, in this instance maybe not relevant)

    For each bonded pair in the input, flag if the optimized distance has grown beyond sum_cov_radii +
    breaking_tolerance during DFT geometry optimization. For each non-bonded pair of heavy atoms (Non-H) that 
    are close, flag possible bond formation (currently this is not performed but can uncomment to do it)

    Input:
        - mol_in: Chem.Mol; RDKit Mol object read in from a pre-optimization .sd-file; serves as reference struc.
        - atomic_symbols: list[str]; a list of atomic symbols read in from an optimized .xyz file
        - xyz_coords: np.ndarray; a Numpy array containing DFT-optimized 3D (xyz) coordinates

    Returns: 
        - issues: list[str]; a list of issues found for each mol. 
    """

    ###May need to adjust these threshold values for including/excluding mols
    #In angstroms, a tunable distance cutoff to determine if a bond is breaking/has broken
    #This is how much the distance between a pair of "bonded" atoms can expand
    #before we consider the bond to have broken.  
    breaking_tolerance = 0.5

    #in Angstroms, a tunable distance cutoff to determine if a bond is possibly forming/formed
    #This is how much the distance between a pair of "non-bonded" atoms can shrink
    #before we consider it to be "putatively bonded." 
    forming_tolerance = 0.3

    #not sure what this does yet
    DEFAULT_RADIUS = 0.80

    #in Angstroms, the approx. VDW radii for common organic atoms
    #These are used as a rough ball-and-stick model estimate of the boundaries of interacting atoms
    COVALENT_RADII = {
        "H": 0.31, "C": 0.76, "N": 0.71, "O": 0.66, "F": 0.57, "P": 1.07, "S": 1.05, "Cl": 1.02,
        "Br": 1.20, "I": 1.39, "B": 0.84, "Si": 1.11, "Se": 1.20,
        }

    #init a list to store any found issues
    issues = []

    bonds_in_input_mol = {frozenset((bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()))
                 for bond in mol_in.GetBonds()}

    ### Check bond-by-bond for bonds that have stretched/maybe broken during optimization ### 
    #loop over each pair of atoms that are inferred to be putatively bonded in the input sdf
    for atom_pair in bonds_in_input_mol: 
        a, b = sorted(atom_pair) #assign atoms a and b from each atom pair
        
        a_b_distance_after_opt = float(np.linalg.norm(xyz_coords[a] - xyz_coords[b]))
        #print(f"Atomic Pair distance: {a_b_distance_after_opt}")
        
        # dist = _pair_distance(coords_out, a, b) #calculate the euclidean distance between 
        #r_sum = _cov_radius_sum(atomic_symbols, a, b)
        sum_of_vdw_radii = (COVALENT_RADII.get(atomic_symbols[a], DEFAULT_RADIUS) + COVALENT_RADII.get(atomic_symbols[b], DEFAULT_RADIUS))
        #print(f"Sum of VDW Radii: {sum_of_vdw_radii}")

        #If the post-opt AB distance is longer than 1.5 Angstrongs + the VDW Radii, 
        #Add a "Bond likely Broken" issue to the list of potential issues 
        if a_b_distance_after_opt > sum_of_vdw_radii + 1.0 + breaking_tolerance: # May need to tune the 1.0 val. or breaking_tol. 
            issues.append(
                f"Bond STRETCH WARNING: atoms {a}–{b} "
                f"({atomic_symbols[a]}–{atomic_symbols[b]})"
                f"dist={a_b_distance_after_opt:.2f} Å (sum cov radii={sum_of_vdw_radii:.2f} Å)"
            )

    ## Currently I'm not sure that 'forming bonds' needs to be checked; breaking is much more common 
    ### Next check if any new bonds formed between Non-H atoms during optimization ###
    #Get a list of Heavy Atoms in the optimized geom (non-Hydrogen atoms) 
    heavy_atoms = [i for i, sym in enumerate(atomic_symbols) if sym != "H"]
    num_heavy_atoms = len(heavy_atoms) #how many non-H atoms in the geom

    ### Next check if any new bonds formed between Non-H atoms during optimization ###
    #loop over each of the heavy atoms in the 3D coordinates
    for i in range(num_heavy_atoms):
        
        #make unique pairs of heavy atoms
        for j in range(i + 1, num_heavy_atoms):
            a, b = heavy_atoms[i], heavy_atoms[j]
            
            #check if a and b are already a bond in the input mol
            if frozenset((a, b)) in bonds_in_input_mol:
                continue #if they are already considered bonded, skip them

            #calculate the Eucl. distance between A and B in angstroms
            a_b_distance_after_opt = float(np.linalg.norm(xyz_coords[a] - xyz_coords[b]))

            #Sum the VDW radii of A and B - this is an estimate of the expected bond length 
            sum_of_vdw_radii = (COVALENT_RADII.get(atomic_symbols[a], DEFAULT_RADIUS) + COVALENT_RADII.get(atomic_symbols[b], DEFAULT_RADIUS))

            #If the distance has shrunk below our threshold, consider the heavy atoms bonded/raise a flag
            if a_b_distance_after_opt < sum_of_vdw_radii + forming_tolerance:
                issues.append(
                    f"New CLOSE CONTACT (possible bond formation): "
                    f"atoms {a}–{b} ({atomic_symbols[a]}–{atomic_symbols[b]}) "
                    f"dist={a_b_distance_after_opt:.2f} Å"
                )

    if issues:
        return issues

# %%
def build_mol_from_coords(pre_opt_mol: Chem.Mol, opt_atomic_symbols: list[str], xyz_coords: np.ndarray) -> Chem.Mol:
    """
    Function: Given a pre-optimization SD-File, Generates a new/updated RDkit mol object from optimized 3D (xyz) coordinates. 

    Inputs: 
        - pre_opt_mol: Chem.Mol; an RDkit Mol object imported from a pre-optimization .sd-file
        - opt_atomic_symbols: list[str]; a list of strings corresponding to atomic symbols; extracted from .xyz file
        - xyz_coords: np.ndarray; a Numpy array consisting of optimized 3D coordinates; extracted from .xyz file

    Returns:
        - updated_mol: Chem.Mol; an RDkit Mol object with DFT-optimizec coordinates
    
    Create an RDKit Mol with the ORCA-optimized coordinates, using the
    template's connectivity (bond graph) and atom ordering.

    The template and ORCA output must have the same atom ordering.
    """

    #check that the number of atoms in the .sdf and the .xyz match
    #(should always be true unless you do something loco)
    if pre_opt_mol.GetNumAtoms() != len(opt_atomic_symbols):
        raise ValueError(
            f"Atom count mismatch: SDF has {pre_opt_mol.GetNumAtoms()} atoms, "
            f"ORCA output has {len(opt_atomic_symbols)} atoms."
        )

    # Verify element symbols match
    for i, (sdf_atom, xyz_symbol) in enumerate(zip(pre_opt_mol.GetAtoms(), opt_atomic_symbols)):
        sdf_symbol = sdf_atom.GetSymbol()

        #explicitly check that both lists match in content/order
        if sdf_symbol.upper() != xyz_symbol.upper():
            raise ValueError(
                f"Atom {i}: SDF has '{sdf_symbol}', ORCA has '{xyz_symbol}'."
                "Atom ordering must be identical."
            )

    # Build editable copy with new coordinates
    editable_mol = Chem.RWMol(Chem.Mol(pre_opt_mol))
    conformer = editable_mol.GetConformer()
    for i, (x, y, z) in enumerate(xyz_coords):
        conformer.SetAtomPosition(i, (x, y, z))

    updated_mol = editable_mol.GetMol()

    if updated_mol is not None:
        return updated_mol

    #I think here we should just write an output .sdf immediately - no mussing about

# %%
def identify_broken_arynes(path_to_pre_opt_sdfs: Path, path_to_opt_xyzs: Path):
    """
    Function: Given a pre-optimization .sd-file for an aryne, compare its pre-opt connectivity to its post-opt
        geometry (via an optimized .xyz file) looking for changes in connectivity/isomerisim. Changes suggest
        that bond(s) have broken/formed => significant alteration of the connectivity pre/post optimization. 
        Used as a triage method to find arynes that have broken open during geometry optimization. 
        
    Inputs:
        - path_to_pre_opt_sdfs: Path; a filepath to directory containing .sdf files with pre-optimization geometries
        - path_to_opt_xyzs: Path; a filepath to directory containing .xyz files generated from optimized coords. 
        
    Returns:
        - broken_xyz_paths: list[Path]; a list of paths corresponding to .xyz files that broke open during opt. 
    """

    ### Working with SD-Files
    #gather all the .sd-files in pre-opt .sdf directory; sort them numerically
    pre_opt_sdfs = get_filepaths_in_target_dir(path_to_pre_opt_sdfs, ".sdf", printing=False)

    #init a list to store broken filepaths
    broken_xyz_paths = []
    
    #loop over each sdf in the pre-opt .sdf dir
    for sd_file in pre_opt_sdfs:
        if sd_file.is_file(): #confirm the .sdf exists
            
            #Attempt to convert incoming .sdf to RDKit mol
            mol_in = sdf_to_mol_rdkit(sd_file)

            #if mol was successfully imported, get the name of the .sdf for matching an .xyz
            if mol_in is not None: 
                #print(f"\n{sd_file.name}: Valid mol from sdf") #debug text
                sdf_name = sd_file.stem #get the name of the file 
                matched_xyz_name = f"{sdf_name}_conf_1.xyz" #infer the name of the matching .out
                matched_xyz_path = path_to_opt_xyzs / matched_xyz_name #path where the .out should be

                ##Below we extract the optimized .xyz coords from the generated .xyz files
                if matched_xyz_path.is_file(): #confirm the .out file exists
                    #print(f"\tFound matching .xyz: {matched_xyz_path.name}")
                    #want to extract the .xyz coords and atom IDs from this small file instead of an .out
                    try:
                        with open(matched_xyz_path, 'r') as file:
                            #init a list to store the geom lines from an .xyz
                            xyz_lines = []

                            #start appending .xyz lines from index 2 (3rd line)
                            for line in islice(file, 2, None):
                                stripped = line.strip()
                                geom_line = stripped.split()
                                xyz_lines.append(geom_line)

                        #explicitly close the file to clear mem
                        file.close()
                        
                    #throw an exception if the matching .xyz can't be opened for parsing
                    except Exception as e:
                        print(f"Could not read .out {matched_xyz_path.name}: {e}")     

                #If an optimized .xyz file doesn't exist, skip the .sdf 
                elif not matched_xyz_path.is_file():
                    #print(f"Did not find matching .xyz: {matched_xyz_path.name} Skipped.")
                    continue

                #convert the captured lines to a DF
                opt_geom_df = pd.DataFrame(xyz_lines, columns=["AtomID", "x", "y", "z"])

                #get the AtomID col as a list of atomic symbols
                opt_atomic_symbols = opt_geom_df['AtomID'].to_list()

                #convert the 3D coords from the Pd.df to a numpy array
                float_coords = opt_geom_df[["x", "y", "z"]].astype(float)
                opt_xyz_array = float_coords[["x", "y", "z"]].to_numpy()
                
                ## Now we have a valid mol from an .sdf (and its geometry/connections)
                #we also have a list of atoms from the optimized geometry as "opt_atomic_symbols"
                #and we have a np.array of the optimized .xyz coordinates
                broken_mols = 0 #init a counter
                issues = compare_mol_connectivity(mol_in, opt_atomic_symbols, opt_xyz_array)

                if not issues:
                    print(f"\tValid Molecule: {matched_xyz_path.name}")

                if issues:
                    print(f"Broken Molecule: {matched_xyz_path.name}")
                    broken_xyz_paths.append(matched_xyz_path)

                # #need to do this AFTER checking for connectivity changes; no need to write a mol until ready to output a .sdf
                # #build a new RDKit mol object using the original mol/connectivity as a template
                # #populate it with the optimized xyz coordinates extracted from the matched .xyz
                # mol_out = build_mol_from_coords(mol_in, opt_atomic_symbols, opt_xyz_array)

                # #check that the generated mol with updated/DFT-optimized xyz coords is RDKit-valid
                # if mol_out is not None:
                #     print(f"\tGenerated a valid RDkit Mol with updated xyz coordinates for {matched_xyz_path.name}")

    if broken_xyz_paths:
        return broken_xyz_paths

# %%
def exclude_broken_arynes(broken_aryne_path_list: list[Path]):
    """
    Function: Given a list of filepaths to .xyzs that have broken open, remove the offending
        .xyz and its matching .out to "broken" directories within their parent dirs. 

    Inputs:
        - broken_aryne_path_list: list[Path]; a list of aryne filepaths that have broken as
            identified by the 'identify_broken_arynes()' method. 

    Returns:
        - N/A; operates directly on filepaths/directories
    """

    #make a directory to store broken xyz's 
    broken_xyz_dir = aryne_post_opt_xyz_path / "Broken_Aryne_xyzs"
    broken_xyz_dir.mkdir(parents=True, exist_ok=True)

    #make a directory to store broken .outs (in /Failed_Calculations)
    broken_out_dir = aryne_dft_output_path / "Failed_Calculations" / "Broken_Open_During_Opt"
    broken_out_dir.mkdir(parents=True, exist_ok=True)

    for broken_aryne_xyz_path in broken_aryne_path_list:
        broken_xyz_name = broken_aryne_xyz_path.stem

        #find the corresponding .out in the aryne_outputs dir
        broken_out_name = f"{broken_xyz_name}.out"
        print(broken_out_name)
        broken_out_source = aryne_dft_output_path / broken_out_name

        #If the matching .out exists, try to move it to the /failed dir
        if broken_out_source.is_file():
            print("out found")
            try:
                #write a destination dir
                broken_out_destination = broken_out_dir / broken_out_name 

                broken_out_source.rename(broken_out_destination)
                print(f"Moved '{broken_out_name}' to '/{broken_out_source.name}/'") 
            
            except OSError as e:
                print(f"Error moving '{broken_out_name}': {e}")

            except FileNotFoundError: #no matching .out (should never happen)
                print(f"Error: {broken_out_name} was not found.")

        #with the matching .out moved, now sequester the .xyz file, as well
        broken_xyz_destination = broken_xyz_dir / broken_aryne_xyz_path.name 

        try:
            #try to move the broken .xyz to its own sequestered dir
            broken_aryne_xyz_path.rename(broken_xyz_destination)
            #print(f"Moved '{broken_aryne_xyz_path.name}' to '/{broken_xyz_destination.name}/'") 
        
        except OSError as e:
            print(f"Error moving '{broken_aryne_xyz_path.name}': {e}")

        except FileNotFoundError: #no matching .out (should never happen)
            print(f"Error: {broken_aryne_xyz_path.name} was not found.")

# %%
def write_optimized_sdfs(path_to_out_files: Path, path_to_xyz_files: Path, path_to_pre_opt_sdfs: Path, new_sdf_dir: Path): 
    """
    Function: Write a new valid .sdf containing a DFT-optimized 3D geom (as .xyz) from an existing pre-optimization .sdf
        - Make a copy of old .sdf; Replace pre-opt 3D coords in old .sdf with optimized.xyz geom formatted for .sdf
        - Retain connectivity/charge/etc from original .sdf 
        - avoid using any eternal dep.
        
    Inputs:
        - path_to_out_files: Path; directory containing optimized/validated .out files
        - path_to_xyz_files: Path; directory containing optimized .xyz files extracted from .outs
        - path_to_pre_opt_sdfs: Path; directory containing pre-DFT .sdfs (used to write .inps)
        - new_sdf_dir: Path; directory to write the newly written .sdfs to
        
    Returns:
        - N/A - operates on dirs and files without a return
    """

    #print a notice to user about what is happening
    print(f"\033[1mWriting new .sd-files from DFT-optimized .out files in '/{path_to_out_files.stem}/'....\n\033[0m")

    #string format for a row in the atoms block of an .sdf 
    # {X} {Y} {Z} {AtomID} {massdif} {massdif} {chg} {chg} {chg} ... 16 elements
    sdf_str_format = "{:>10}{:>10}{:>10} {:<3} {}  {}  {}  {}  {}  {}  {}  {}  {}  {}  {}  {}"

    #Specify dirs containing necessary files
    out_files = get_filepaths_in_target_dir(path_to_out_files, ".out") #DFT output files
    xyz_files = get_filepaths_in_target_dir(path_to_xyz_files, ".xyz") #DFT-optimized .xyz's
    pre_sdfs = get_filepaths_in_target_dir(path_to_pre_opt_sdfs, ".sdf") #.sdfs used to gen .inps

    #Debug/Transparency - report the number of files in each spec. dir
    print("Checking for necessary files in /target_dirs/...")
    print(f"Found '{len(out_files)}' validated output.outs in '/{path_to_out_files.stem}/'")
    print(f"Found '{len(xyz_files)}' optimized .xyzs in '/{path_to_xyz_files.stem}/'")
    print(f"Found '{len(pre_sdfs)}' pre-opt.sdfs in '/{path_to_pre_opt_sdfs.stem}/'")

    #make a dir for new .sdfs to be written to
    print(f"Writing new .sdfs to: '/{new_sdf_dir.stem}/'")
    
    #Verify that matching .xyz and pre-opt.sdf files are found for each .out   
    for out_file in out_files:
        #Get the mol_ID header (the first 2 elements of the file name) for matching
        out_file_name = out_file.stem
        split_name = out_file_name.split("_") #splits the filename on underscore char
        out_mol_id = f"{split_name[0]}_{split_name[1]}_*" #format a new str to search for
        print(f"\nWorking file: '{out_file.name}'")
        
        #flags indicating presence of targeted files - start false and True if found
        found_sdf = False
        found_xyz = False
        
        #check the /sdf_dir for a matching mol_ID.sdf
        matched_sdf = path_to_pre_opt_sdfs.glob(out_mol_id) #using our formatted header
        
        if matched_sdf: #If a matched file is found, 
            for match in matched_sdf: #could potentially be multiple IDs? 
                #get the path of the matched file
                matched_sdf_path = match #record the path of the target file
                found_sdf = True #turn flag to True
                print(f"\tFound matching .sdf: '{matched_sdf_path.name}'")
        
        else: #no matching .sdf found 
            print(f"\tFound no matching .sdf for '{out_file.name}'\n")
            break
        
        #check the /xyz_dir for a matching mol_ID.xyz
        matched_xyz = path_to_xyz_files.glob(out_mol_id)
        if matched_xyz:
            for match in matched_xyz:
                matched_xyz_path = match #record the path of the target file
                found_xyz = True
                print(f"\tFound matching .xyz: '{matched_xyz_path.name}'")
        
        else: #no matching .xyz found
            print(f"\tFound no matching .xyz for '{out_file.name}'\n")
            break
    
        #Copy the pre-opt.sdf to a new dir
        if found_sdf and found_xyz: #both matching files were located
            print(f"Copying '{matched_sdf_path.name}' to '/{new_sdf_dir.stem}/'")
            
            #set up a target dir / name of file to copy
            new_sdf_name = f"{out_file_name}_post_opt.sdf"
            new_sdf_path = new_sdf_dir / new_sdf_name
    
            # Check if the destination file already exists before copying
            if not new_sdf_path.is_file():
                shutil.copy(matched_sdf_path, new_sdf_path)
                print(f"\tCopied '{matched_sdf_path.name}' to /{new_sdf_dir.stem}/")

                #Verify that the copied .sdf just contains a single mol (remove extraneous confs)
                mol_footer = '$$$$' #separates mol blocks within an .sdf
                found_footer = False
                truncated_content = [] #will store the first mol only for rewrite
                
                try: #look for instances of the "$$$$" string in the text - separates mols
                    with open(new_sdf_path) as file:
                        for line in file:
                            if mol_footer in line and not found_footer: #if you find footer, this is the end
                                truncated_content.append(line) #save the last line
                                found_footer = True #turn on the marker
                                break #stop after the first match/exit the loop
                                
                            elif not found_footer: #append lines until we find the footer 
                                truncated_content.append(line)
                
                except IOError as e: #kind of a placeholder - already checked that it exists and should open
                    print(f"Error reading file: {e}")
                    return 

                try: #now overwrite the captured lines for the first mol only to the .sdf 
                    with open(new_sdf_path, 'w') as f:
                        f.writelines(truncated_content)
                        #print(f"File '{new_sdf_path.name}' truncated successfully after the first occurrence of '{mol_footer}'.") #debug
                        
                except IOError as e:
                    print(f"Error writing to file: {e}")
                
            else: #if it exists, skip the copy - maybe overwrite anyway is better
                print(f"\t'{matched_sdf_path.name}' already exists in '/{new_sdf_dir.stem}/'. Copy skipped.")

        #get the .xyz geom from the post-opt .xyz dir
        try:
            with open(matched_xyz_path, 'r') as file:
                xyz_lines = file.readlines() #pull in all .xyz lines
                xyz_geom_lines = xyz_lines[2:] #the geom starts at the 3rd line
                
                #make a dict of the .xyz 
                xyz_dict_list = [] 
                xyz_cols = ['atom_ID', 'x', 'y', 'z']
                
                for xyz_line in xyz_geom_lines: #we just want lines that correspond to the geom
                    split_xyz_line = xyz_line.split() #split on whitespace
                    
                    if len(split_xyz_line) == len(xyz_cols): #pull the xyz data into a dict
                        row_dict = dict(zip(xyz_cols, split_xyz_line))
                        xyz_dict_list.append(row_dict)
                        
                    else: #hopefully never happens
                        print(f'Len split xyz line: {split_xyz_line}')
                        print(f"Skipping line due to format mismatch.")

        except FileNotFoundError: #no matching .xyz (should never happen)
            print(f"Error: {matched_xyz_path.name} was not found.")

        #now have a copy of pre-opt.sdf in post-opt-sdf dir
        #We want to keep all of the valence/charge/connectivity info from the OG .sdf since that is "good"
        #in the eyes of RDkit => We will replace only the XYZ coords from the DFT-optimized geom
        try: #here we are finding the block of text we will need to parse/replace (the atom block)
            with open(new_sdf_path) as file:
                lines = file.readlines() #probably OK since sdf in this case is small
                #print(lines)

            if len(lines) >= 4: #the "counts line" starts on the 4th line (3rd index)
                fourth_line = lines[3] #we are searching the 4th line for # of atoms (first element of 4th line)
                match = re.search(r'\d+', fourth_line) #mach it wtih regex for digits

                if match: #if you've found a match, what is the int value? that's the num atoms
                    num_atoms = int(match.group())
                    #print(f'\t{new_sdf_path.name} contains {num_atoms} atoms.') #debug
            
            #Next we want to retain the useful portion of the "atoms block" - atomID, charge, etc. 
            #this block is of length = num of atoms, so get a slice of the lines from the 4th line to the # of atomsth line
            # aka: (num_atoms + 4 preceding lines)
            len_geom = num_atoms + 4
            old_geom_lines = lines[4:len_geom] #get everything up to the #
            
            old_valence_data = [] #stores the atomID, charge/valence/etc. cols of .sdf
            
            #set up to convert this to a df for easier manipul./dropping cols/reordering
            retained_cols = ['atom_ID',
                             'c1', 'c2', 'c3', 'c4',
                            'c5', 'c6', 'c7', 'c8',
                             'c9', 'c10', 'c11', 'c12'
                            ]
            
            #loop over lines in the atom block and remove just the xyz columns (first 3 elements)
            #these data are stored in 'old_valence_data' to be combined with a new set of xyz's
            for line in old_geom_lines:
                split_line = line.split()
                old_valence_data.append(split_line[3:]) #saving the atomID =>
            
            #store as a list of formatted data;
            old_sdf_data_list = [] #will be converted to a df
            
            #convert each row of the geom section to col-matched dict
            for processed_line in old_valence_data: 
                
                # Ensure the processed line has the same number of items as columns
                if len(processed_line) == len(retained_cols):
                    
                    # Create a dictionary for the row and append to the list
                    row_dict = dict(zip(retained_cols, processed_line))
                    old_sdf_data_list.append(row_dict)
                    
                else:
                    print(f"Skipping line due to format mismatch.")
            
            #convert .xyz dict to a DF
            new_xyz_df = pd.DataFrame(xyz_dict_list)
        
            #convert to a DF to append in the .xyz data
            old_sdf_df = pd.DataFrame(old_sdf_data_list)

            #now combining the old SDF atoms block (sans xyz) with the optimized xyz coords
            #check that the atom_ID cols are equal (same atoms/ordering)
            if new_xyz_df['atom_ID'].equals(old_sdf_df['atom_ID']):

                dropped_xyz = new_xyz_df.drop('atom_ID', axis=1)
                dropped_xyz = dropped_xyz.astype(float)
                rounded_xyz = dropped_xyz.round(4)
            
                new_sdf_df = pd.concat([rounded_xyz, old_sdf_df], axis=1)

                formatted_strings = [sdf_str_format.format(row[0], row[1], row[2], row[3],
                                                          row[4], row[5], row[6], row[7],
                                                          row[8], row[9], row[10], row[11],
                                                          row[12], row[13], row[14], row[15]) for row in new_sdf_df.values.tolist()] 

                #the lines to enter have to have explicit newline characters at the end; ensure they do, here
                formatted_replacement = [line if line.endswith('\n') else line + '\n' for line in formatted_strings]
                
                # #test our formatted .sdf atoms block
                # for line in formatted_replacement:
                #     print(line) #(it looks good)

                #now we do the replacement by reassigning our formatted_replacement lines to the old slice:
                lines[4:len_geom] = formatted_replacement
                
            else:
                print("df matching seems messed up")

            #now we have a copied/parsed .sdf and the block of text we want to replace into it
            #we next need to do the actual substitution in the copied .sdf
            with open(new_sdf_path, "w") as file:
                file.writelines(lines)
 
        except FileNotFoundError: #no matching .sdf (should never happen)
            print(f"Error: {new_sdf_path.name} was not found.")

# %%
def get_scf_energy_orca5(path_to_out_file: Path):
    """
    Function: Extract the last SCF energy from an opt'd geom

    Input:
        -path_to_out_file: Path; path to an Orca 5.0.3 DFT .out file 
        
    Returns: 
        - SCF Energy (dE) in Hartrees
    """

    #Orca5 reports SCF energies using this str line format (the energy immediately follows as the 5th element)
    scf_line_marker = "FINAL SINGLE POINT ENERGY"

    #read through the file backwards matching for our desired text line
    if path_to_out_file.is_file():
        try:
            #read the .out file back to front; the first SCF line is the final SCF energy of the calc.
            with FileReadBackwards(path_to_out_file, encoding="utf-8") as out_file:
                for line in out_file: #remember we are going backwards
    
                    #Reading from back to front, the first SCF line is the final energy 
                    if scf_line_marker in line:
    
                        #split the matched line on whitespace delimiter
                        split_line = line.split()
                        
                        #the energy is 5th element; convert it to float
                        final_energy = float(split_line[4])
    
                        #round the val to 4 dps
                        final_energy_rounded = round(final_energy, 4)
    
                        #exit as soon as the first match is found (the last SCF line)
                        break 
                        
                else:  #can't read the energy for some reason
                    print(f'{file_path.name} does not contain a final SCF energy - Check your calculation.')
    
        except Exception as e:
                print(f"Could not read .out {path_to_out_file.stem}: {e}")
            
    elif not path_to_out_file.is_file():
        print(f"{path_to_out_file.stem} not found in '/{path_to_out_file.parent}/'")
        
    #return just the final energy
    return final_energy_rounded

# %%
def extract_dE_to_dataframe(df_column, target_directory: Path):
    '''
    Function: Given a dataframe containing a column of molecular IDs, for example (Arene_1, ..., Arene_n), look
        in the passed directory for a corresponding Orca DFT .out file. If the file exists in passed dir, attempt
        to extract the final SCF energy (in Hartrees) from the .out file. Save energies to a list; if the energy
        can't be read, append a 'NaN'. Returns the list of parsed energies/NaNs. 

    Input:
        -df_column - a column in a Pandas DF that contains mol ID headers - in this case "arene_x" or "aryne_y"
        -target_directory: Path; a directory containing .out files
        
    Returns:
        - scf_energies: list - a list of floats/NaNs corresponding to extracted SCF energies (hartrees)
    '''

    scf_energies = []

    #Get the mol_ID from the mol_ID col of a DF (ex: arene_3) 
    for mol_id in df_column: 

        #convert the dir passed to a str (constructing a path to the .out file)
        str_dir = str(target_directory)

        #build the name of the formatted .out file using the captured mol_ID
        out_name = Path(mol_id+"_rdkit_conf_1.out")

        #Define the full path to the .out file 
        log_file = str_dir/out_name
        
        #if the file exists, attempt to extract the final SCF energy
        try:
            energy = get_scf_energy_orca5(log_file) 
            
        #If unreadable (.out doesn't exist or error in calc), append a NaN  
        except:
            energy = np.nan #append NaN for any unreadable energies

        #append the energy (either # or NaN to a list)
        scf_energies.append(energy)

    #return the list of scf_energies
    return scf_energies

# %%
""" Extract Geometries and Generate Optimized .XYZ Files for ARENES 

rdkit_conf_1.xyz'
# 	Optimized .xyz file written: 'aryne_9458_rdkit_conf_1.xyz'
# 	Optimized .xyz file written: 'aryne_9459_rdkit_conf_1.xyz'
#
# Optimized .xyz files written to '/Aryne_Opt_xyz_Files/': 8760

# %%
""" ### Identify and Isolate Broken Aryne Calculations ###

This is a project-specific cell used to identify broken arynes (rings that open during optimization).
By comparing pre- and post-opt # of bonds, we can reliably ID arynes that have broken open during optimization. 

The "exclude_broken_arynes" method excludes aryne.sdfs on the basis of a dramatic reduction in # of bonds. 
Arynes that break exhibit fewer net bonds than their pre-opt num of bonds. If post < pre, aryne broke. 
"""

#Print some text to the user
print(f"Parsing Input/Output files for Arynes that have broken open during optimization...\n")

# #compare geometries before/after optimization and search for bonds that have broken
broken_arynes = identify_broken_arynes(aryne_pre_opt_sdf_path, aryne_post_opt_xyz_path)

#send the broken .outs/.xyzs to the abyss
if broken_arynes:
    #give some feedback on the number of broken structures
    print(f"\nNumber of arynes identified as broken: {len(broken_arynes)}")
    exclude_broken_arynes(broken_arynes)
# Out:
# Parsing Input/Output files for Arynes that have broken open during optimization...
#
# 	Valid Molecule: aryne_1_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_2_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_3_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_4_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_5_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_8_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_9_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_10_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_11_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_12_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_13_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_14_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_15_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_16_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_17_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_18_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_19_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_20_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_21_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_22_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_23_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_24_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_25_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_26_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_27_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_29_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_30_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_32_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_33_rdkit_conf_1.xyz
# Broken Molecule: aryne_35_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_36_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_37_rdkit_conf_1.xyz
# Broken Molecule: aryne_38_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_39_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_41_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_42_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_43_rdkit_conf_1.xyz
# Broken Molecule: aryne_44_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_45_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_46_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_47_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_48_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_49_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_50_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_51_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_52_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_53_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_54_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_55_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_56_rdkit_conf_1.xyz
# Broken Molecule: aryne_57_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_58_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_59_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_60_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_61_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_62_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_63_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_64_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_65_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_67_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_68_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_69_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_70_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_71_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_72_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_73_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_75_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_76_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_77_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_78_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_79_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_80_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_81_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_82_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_83_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_84_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_85_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_86_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_87_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_88_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_89_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_90_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_92_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_93_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_94_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_95_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_96_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_97_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_98_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_99_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_100_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_101_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_102_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_103_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_104_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_105_rdkit_conf_1.xyz
# Broken Molecule: aryne_106_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_107_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_108_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_109_rdkit_conf_1.xyz
# Broken Molecule: aryne_110_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_111_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_112_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_113_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_114_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_115_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_116_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_117_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_118_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_119_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_120_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_121_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_122_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_123_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_124_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_125_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_126_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_127_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_128_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_129_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_130_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_131_rdkit_conf_1.xyz
# Broken Molecule: aryne_132_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_133_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_134_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_135_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_136_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_137_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_138_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_139_rdkit_conf_1.xyz
# Broken Molecule: aryne_140_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_141_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_142_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_143_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_144_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_145_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_146_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_147_rdkit_conf_1.xyz
# Broken Molecule: aryne_148_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_150_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_151_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_152_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_153_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_154_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_155_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_156_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_158_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_159_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_160_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_161_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_162_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_163_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_164_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_165_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_166_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_167_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_168_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_169_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_170_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_171_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_172_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_173_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_174_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_175_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_176_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_177_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_178_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_179_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_180_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_181_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_182_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_183_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_184_rdkit_conf_1.xyz
# Broken Molecule: aryne_185_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_186_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_188_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_189_rdkit_conf_1.xyz
# Broken Molecule: aryne_190_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_191_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_192_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_193_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_194_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_195_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_196_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_197_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_198_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_199_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_200_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_201_rdkit_conf_1.xyz
# 	Valid Molecule: aryne_203_rdkit_conf_1.xyz
# 	Valid Molecule: aryne
# out found
# Moved 'aryne_5658_rdkit_conf_1.out' to '/aryne_5658_rdkit_conf_1.out/'
# aryne_5684_rdkit_conf_1.out
# out found
# Moved 'aryne_5684_rdkit_conf_1.out' to '/aryne_5684_rdkit_conf_1.out/'
# aryne_5718_rdkit_conf_1.out
# out found
# Moved 'aryne_5718_rdkit_conf_1.out' to '/aryne_5718_rdkit_conf_1.out/'
# aryne_5728_rdkit_conf_1.out
# out found
# Moved 'aryne_5728_rdkit_conf_1.out' to '/aryne_5728_rdkit_conf_1.out/'
# aryne_5729_rdkit_conf_1.out
# out found
# Moved 'aryne_5729_rdkit_conf_1.out' to '/aryne_5729_rdkit_conf_1.out/'
# aryne_5761_rdkit_conf_1.out
# out found
# Moved 'aryne_5761_rdkit_conf_1.out' to '/aryne_5761_rdkit_conf_1.out/'
# aryne_5860_rdkit_conf_1.out
# out found
# Moved 'aryne_5860_rdkit_conf_1.out' to '/aryne_5860_rdkit_conf_1.out/'
# aryne_5914_rdkit_conf_1.out
# out found
# Moved 'aryne_5914_rdkit_conf_1.out' to '/aryne_5914_rdkit_conf_1.out/'
# aryne_5930_rdkit_conf_1.out
# out found
# Moved 'aryne_5930_rdkit_conf_1.out' to '/aryne_5930_rdkit_conf_1.out/'
# aryne_6007_rdkit_conf_1.out
# out found
# Moved 'aryne_6007_rdkit_conf_1.out' to '/aryne_6007_rdkit_conf_1.out/'
# aryne_6008_rdkit_conf_1.out
# out found
# Moved 'aryne_6008_rdkit_conf_1.out' to '/aryne_6008_rdkit_conf_1.out/'
# aryne_6018_rdkit_conf_1.out
# out found
# Moved 'aryne_6018_rdkit_conf_1.out' to '/aryne_6018_rdkit_conf_1.out/'
# aryne_6034_rdkit_conf_1.out
# out found
# Moved 'aryne_6034_rdkit_conf_1.out' to '/aryne_6034_rdkit_conf_1.out/'
# aryne_6053_rdkit_conf_1.out
# out found
# Moved 'aryne_6053_rdkit_conf_1.out' to '/aryne_6053_rdkit_conf_1.out/'
# aryne_6058_rdkit_conf_1.out
# out found
# Moved 'aryne_6058_rdkit_conf_1.out' to '/aryne_6058_rdkit_conf_1.out/'
# aryne_6063_rdkit_conf_1.out
# out found
# Moved 'aryne_6063_rdkit_conf_1.out' to '/aryne_6063_rdkit_conf_1.out/'
# aryne_6076_rdkit_conf_1.out
# out found
# Moved 'aryne_6076_rdkit_conf_1.out' to '/aryne_6076_rdkit_conf_1.out/'
# aryne_6077_rdkit_conf_1.out
# out found
# Moved 'aryne_6077_rdkit_conf_1.out' to '/aryne_6077_rdkit_conf_1.out/'
# aryne_6086_rdkit_conf_1.out
# out found
# Moved 'aryne_6086_rdkit_conf_1.out' to '/aryne_6086_rdkit_conf_1.out/'
# aryne_6099_rdkit_conf_1.out
# out found
# Moved 'aryne_6099_rdkit_conf_1.out' to '/aryne_6099_rdkit_conf_1.out/'
# aryne_6135_rdkit_conf_1.out
# out found
# Moved 'aryne_6135_rdkit_conf_1.out' to '/aryne_6135_rdkit_conf_1.out/'
# aryne_6146_rdkit_conf_1.out
# out found
# Moved 'aryne_6146_rdkit_conf_1.out' to '/aryne_6146_rdkit_conf_1.out/'
# aryne_6218_rdkit_conf_1.out
# out found
# Moved 'aryne_6218_rdkit_conf_1.out' to '/aryne_6218_rdkit_conf_1.out/'
# aryne_6296_rdkit_conf_1.out
# out found
# Moved 'aryne_6296_rdkit_conf_1.out' to '/aryne_6296_rdkit_conf_1.out/'
# aryne_6328_rdkit_conf_1.out
# out found
# Moved 'aryne_6328_rdkit_conf_1.out' to '/aryne_6328_rdkit_conf_1.out/'
# aryne_6370_rdkit_conf_1.out
# out found
# Moved 'aryne_6370_rdkit_conf_1.out' to '/aryne_6370_rdkit_conf_1.out/'
# aryne_6373_rdkit_conf_1.out
# out found
# Moved 'aryne_6373_rdkit_conf_1.out' to '/aryne_6373_rdkit_conf_1.out/'
# aryne_6522_rdkit_conf_1.out
# out found
# Moved 'aryne_6522_rdkit_conf_1.out' to '/aryne_6522_rdkit_conf_1.out/'
# aryne_6555_rdkit_conf_1.out
# out found
# Moved 'aryne_6555_rdkit_conf_1.out' to '/aryne_6555_rdkit_conf_1.out/'
# aryne_6577_rdkit_conf_1.out
# out found
# Moved 'aryne_6577_rdkit_conf_1.out' to '/aryne_6577_rdkit_conf_1.out/'
# aryne_6584_rdkit_conf_1.out
# out found
# Moved 'aryne_6584_rdkit_conf_1.out' to '/aryne_6584_rdkit_conf_1.out/'
# aryne_6619_rdkit_conf_1.out
# out found
# Moved 'aryne_6619_rdkit_conf_1.out' to '/aryne_6619_rdkit_conf_1.out/'
# aryne_6630_rdkit_conf_1.out
# out found
# Moved 'aryne_6630_rdkit_conf_1.out' to '/aryne_6630_rdkit_conf_1.out/'
# aryne_6642_rdkit_conf_1.out
# out found
# Moved 'aryne_6642_rdkit_conf_1.out' to '/aryne_6642_rdkit_conf_1.out/'
# aryne_6658_rdkit_conf_1.out
# out found
# Moved 'aryne_6658_rdkit_conf_1.out' to '/aryne_6658_rdkit_conf_1.out/'
# aryne_6674_rdkit_conf_1.out
# out found
# Moved 'aryne_6674_rdkit_conf_1.out' to '/aryne_6674_rdkit_conf_1.out/'
# aryne_6717_rdkit_conf_1.out
# out found
# Moved 'aryne_6717_rdkit_conf_1.out' to '/aryne_6717_rdkit_conf_1.out/'
# aryne_6728_rdkit_conf_1.out
# out found
# Moved 'aryne_6728_rdkit_conf_1.out' to '/aryne_6728_rdkit_conf_1.out/'
# aryne_6762_rdkit_conf_1.out
# out found
# Moved 'aryne_6762_rdkit_conf_1.out' to '/aryne_6762_rdkit_conf_1.out/'
# aryne_6782_rdkit_conf_1.out
# out found
# Moved 'aryne_6782_rdkit_conf_1.out' to '/aryne_6782_rdkit_conf_1.out/'
# aryne_6785_rdkit_conf_1.out
# out found
# Moved 'aryne_6785_rdkit_conf_1.out' to '/aryne_6785_rdkit_conf_1.out/'
# aryne_6789_rdkit_conf_1.out
# out found
# Moved 'aryne_6789_rdkit_conf_1.out' to '/aryne_6789_rdkit_conf_1.out/'
# aryne_6831_rdkit_conf_1.out
# out found
# Moved 'aryne_6831_rdkit_conf_1.out' to '/aryne_6831_rdkit_conf_1.out/'
# aryne_6992_rdkit_conf_1.out
# out found
# Moved 'aryne_6992_rdkit_conf_1.out' to '/aryne_6992_rdkit_conf_1.out/'
# aryne_7057_rdkit_conf_1.out
# out found
# Moved 'aryne_7057_rdkit_conf_1.out' to '/aryne_7057_rdkit_conf_1.out/'
# aryne_7078_rdkit_conf_1.out
# out found
# Moved 'aryne_7078_rdkit_conf_1.out' to '/aryne_7078_rdkit_conf_1.out/'
# aryne_7090_rdkit_conf_1.out
# out found
# Moved 'aryne_7090_rdkit_conf_1.out' to '/aryne_7090_rdkit_conf_1.out/'
# aryne_7162_rdkit_conf_1.out
# out found
# Moved 'aryne_7162_rdkit_conf_1.out' to '/aryne_7162_rdkit_conf_1.out/'
# aryne_7184_rdkit_conf_1.out
# out found
# Moved 'aryne_7184_rdkit_conf_1.out' to '/aryne_7184_rdkit_conf_1.out/'
# aryne_7186_rdkit_conf_1.out
# out found
# Moved 'aryne_7186_rdkit_conf_1.out' to '/aryne_7186_rdkit_conf_1.out/'
# aryne_7199_rdkit_conf_1.out
# out found
# Moved 'aryne_7199_rdkit_conf_1.out' to '/aryne_7199_rdkit_conf_1.out/'
# aryne_7227_rdkit_conf_1.out
# out found
# Moved 'aryne_7227_rdkit_conf_1.out' to '/aryne_7227_rdkit_conf_1.out/'
# aryne_7251_rdkit_conf_1.out
# out found
# Moved 'aryne_7251_rdkit_conf_1.out' to '/aryne_7251_rdkit_conf_1.out/'
# aryne_7270_rdkit_conf_1.out
# out found
# Moved 'aryne_7270_rdkit_conf_1.out' to '/aryne_7270_rdkit_conf_1.out/'
# aryne_7286_rdkit_conf_1.out
# out found
# Moved 'aryne_7286_rdkit_conf_1.out' to '/aryne_7286_rdkit_conf_1.out/'
# aryne_7305_rdkit_conf_1.out
# out found
# Moved 'aryne_7305_rdkit_conf_1.out' to '/aryne_7305_rdkit_conf_1.out/'
# aryne_7318_rdkit_conf_1.out
# out found
# Moved 'aryne_7318_rdkit_conf_1.out' to '/aryne_7318_rdkit_conf_1.out/'
# aryne_7337_rdkit_conf_1.out
# out found
# Moved 'aryne_7337_rdkit_conf_1.out' to '/aryne_7337_rdkit_conf_1.out/'
# aryne_7340_rdkit_conf_1.out
# out found
# Moved 'aryne_7340_rdkit_conf_1.out' to '/aryne_7340_rdkit_conf_1.out/'
# aryne_7400_rdkit_conf_1.out
# out found
# Moved 'aryne_7400_rdkit_conf_1.out' to '/aryne_7400_rdkit_conf_1.out/'
# aryne_7413_rdkit_conf_1.out
# out found
# Moved 'aryne_7413_rdkit_conf_1.out' to '/aryne_7413_rdkit_conf_1.out/'
# aryne_7422_rdkit_conf_1.out
# out found
# Moved 'aryne_7422_rdkit_conf_1.out' to '/aryne_7422_rdkit_conf_1.out/'
# aryne_7451_rdkit_conf_1.out
# out found
# Moved 'aryne_7451_rdkit_conf_1.out' to '/aryne_7451_rdkit_conf_1.out/'
# aryne_7452_rdkit_conf_1.out
# out found
# Moved 'aryne_7452_rdkit_conf_1.out' to '/aryne_7452_rdkit_conf_1.out/'
# aryne_7534_rdkit_conf_1.out
# out found
# Moved 'aryne_7534_rdkit_conf_1.out' to '/aryne_7534_rdkit_conf_1.out/'
# aryne_7544_rdkit_conf_1.out
# out found
# Moved 'aryne_7544_rdkit_conf_1.out' to '/aryne_7544_rdkit_conf_1.out/'
# aryne_7558_rdkit_conf_1.out
# out found
# Moved 'aryne_7558_rdkit_conf_1.out' to '/aryne_7558_rdkit_conf_1.out/'
# aryne_7572_rdkit_conf_1.out
# out found
# Moved 'aryne_7572_rdkit_conf_1.out' to '/aryne_7572_rdkit_conf_1.out/'
# aryne_7598_rdkit_conf_1.out
# out found
# Moved 'aryne_7598_rdkit_conf_1.out' to '/aryne_7598_rdkit_conf_1.out/'
# aryne_7648_rdkit_conf_1.out
# out found
# Moved 'aryne_7648_rdkit_conf_1.out' to '/aryne_7648_rdkit_conf_1.out/'
# aryne_7663_rdkit_conf_1.out
# out found
# Moved 'aryne_7663_rdkit_conf_1.out' to '/aryne_7663_rdkit_conf_1.out/'
# aryne_7673_rdkit_conf_1.out
# out found
# Moved 'aryne_7673_rdkit_conf_1.out' to '/aryne_7673_rdkit_conf_1.out/'
# aryne_7675_rdkit_conf_1.out
# out found
# Moved 'aryne_7675_rdkit_conf_1.out' to '/aryne_7675_rdkit_conf_1.out/'
# aryne_7697_rdkit_conf_1.out
# out found
# Moved 'aryne_7697_rdkit_conf_1.out' to '/aryne_7697_rdkit_conf_1.out/'
# aryne_7725_rdkit_conf_1.out
# out found
# Moved 'aryne_7725_rdkit_conf_1.out' to '/aryne_7725_rdkit_conf_1.out/'
# aryne_7726_rdkit_conf_1.out
# out found
# Moved 'aryne_7726_rdkit_conf_1.out' to '/aryne_7726_rdkit_conf_1.out/'
# aryne_7779_rdkit_conf_1.out
# out found
# Moved 'aryne_7779_rdkit_conf_1.out' to '/aryne_7779_rdkit_conf_1.out/'
# aryne_7810_rdkit_conf_1.out
# out found
# Moved 'aryne_7810_rdkit_conf_1.out' to '/aryne_7810_rdkit_conf_1.out/'
# aryne_7845_rdkit_conf_1.out
# out found
# Moved 'aryne_7845_rdkit_conf_1.out' to '/aryne_7845_rdkit_conf_1.out/'
# aryne_7860_rdkit_conf_1.out
# out found
# Moved 'aryne_7860_rdkit_conf_1.out' to '/aryne_7860_rdkit_conf_1.out/'
# aryne_7931_rdkit_conf_1.out
# out found
# Moved 'aryne_7931_rdkit_conf_1.out' to '/aryne_7931_rdkit_conf_1.out/'
# aryne_7935_rdkit_conf_1.out
# out found
# Moved 'aryne_7935_rdkit_conf_1.out' to '/aryne_7935_rdkit_conf_1.out/'
# aryne_7973_rdkit_conf_1.out
# out found
# Moved 'aryne_7973_rdkit_conf_1.out' to '/aryne_7973_rdkit_conf_1.out/'
# aryne_8029_rdkit_conf_1.out
# out found
# Moved 'aryne_8029_rdkit_conf_1.out' to '/aryne_8029_rdkit_conf_1.out/'
# aryne_8041_rdkit_conf_1.out
# out found
# Moved 'aryne_8041_rdkit_conf_1.out' to '/aryne_8041_rdkit_conf_1.out/'
# aryne_8091_rdkit_conf_1.out
# out found
# Moved 'aryne_8091_rdkit_conf_1.out' to '/aryne_8091_rdkit_conf_1.out/'
# aryne_8103_rdkit_conf_1.out
# out found
# Moved 'aryne_8103_rdkit_conf_1.out' to '/aryne_8103_rdkit_conf_1.out/'
# aryne_8132_rdkit_conf_1.out
# out found
# Moved 'aryne_8132_rdkit_conf_1.out' to '/aryne_8132_rdkit_conf_1.out/'
# aryne_8149_rdkit_conf_1.out
# out found
# Moved 'aryne_8149_rdkit_conf_1.out' to '/aryne_8149_rdkit_conf_1.out/'
# aryne_8160_rdkit_conf_1.out
# out found
# Moved 'aryne_8160_rdkit_conf_1.out' to '/aryne_8160_rdkit_conf_1.out/'
# aryne_8161_rdkit_conf_1.out
# out found
# Moved 'aryne_8161_rdkit_conf_1.out' to '/aryne_8161_rdkit_conf_1.out/'
# aryne_8175_rdkit_conf_1.out
# out found
# Moved 'aryne_8175_rdkit_conf_1.out' to '/aryne_8175_rdkit_conf_1.out/'
# aryne_8196_rdkit_conf_1.out
# out found
# Moved 'aryne_8196_rdkit_conf_1.out' to '/aryne_8196_rdkit_conf_1.out/'
# aryne_8206_rdkit_conf_1.out
# out found
# Moved 'aryne_8206_rdkit_conf_1.out' to '/aryne_8206_rdkit_conf_1.out/'
# aryne_8215_rdkit_conf_1.out
# out found
# Moved 'aryne_8215_rdkit_conf_1.out' to '/aryne_8215_rdkit_conf_1.out/'
# aryne_8220_rdkit_conf_1.out
# out found
# Moved 'aryne_8220_rdkit_conf_1.out' to '/aryne_8220_rdkit_conf_1.out/'
# aryne_8226_rdkit_conf_1.out
# out found
# Moved 'aryne_8226_rdkit_conf_1.out' to '/aryne_8226_rdkit_conf_1.out/'
# aryne_8233_rdkit_conf_1.out
# out found
# Moved 'aryne_8233_rdkit_conf_1.out' to '/aryne_8233_rdkit_conf_1.out/'
# aryne_8267_rdkit_conf_1.out
# out found
# Moved 'aryne_8267_rdkit_conf_1.out' to '/aryne_8267_rdkit_conf_1.out/'
# aryne_8316_rdkit_conf_1.out
# out found
# Moved 'aryne_8316_rdkit_conf_1.out' to '/aryne_8316_rdkit_conf_1.out/'
# aryne_8356_rdkit_conf_1.out
# out found
# Moved 'aryne_8356_rdkit_conf_1.out' to '/aryne_8356_rdkit_conf_1.out/'
# aryne_8365_rdkit_conf_1.out
# out found
# Moved 'aryne_8365_rdkit_conf_1.out' to '/aryne_8365_rdkit_conf_1.out/'
# aryne_8393_rdkit_conf_1.out
# out found
# Moved 'aryne_8393_rdkit_conf_1.out' to '/aryne_8393_rdkit_conf_1.out/'
# aryne_8394_rdkit_conf_1.out
# out found
# Moved 'aryne_8394_rdkit_conf_1.out' to '/aryne_8394_rdkit_conf_1.out/'
# aryne_8403_rdkit_conf_1.out
# out found
# Moved 'aryne_8403_rdkit_conf_1.out' to '/aryne_8403_rdkit_conf_1.out/'
# aryne_8440_rdkit_conf_1.out
# out found
# Moved 'aryne_8440_rdkit_conf_1.out' to '/aryne_8440_rdkit_conf_1.out/'
# aryne_8573_rdkit_conf_1.out
# out found
# Moved 'aryne_8573_rdkit_conf_1.out' to '/aryne_8573_rdkit_conf_1.out/'
# aryne_8592_rdkit_conf_1.out
# out found
# Moved 'aryne_8592_rdkit_conf_1.out' to '/aryne_8592_rdkit_conf_1.out/'
# aryne_8598_rdkit_conf_1.out
# out found
# Moved 'aryne_8598_rdkit_conf_1.out' to '/aryne_8598_rdkit_conf_1.out/'
# aryne_8624_rdkit_conf_1.out
# out found
# Moved 'aryne_8624_rdkit_conf_1.out' to '/aryne_8624_rdkit_conf_1.out/'
# aryne_8655_rdkit_conf_1.out
# out found
# Moved 'aryne_8655_rdkit_conf_1.out' to '/aryne_8655_rdkit_conf_1.out/'
# aryne_8711_rdkit_conf_1.out
# out found
# Moved 'aryne_8711_rdkit_conf_1.out' to '/aryne_8711_rdkit_conf_1.out/'
# aryne_8751_rdkit_conf_1.out
# out found
# Moved 'aryne_8751_rdkit_conf_1.out' to '/aryne_8751_rdkit_conf_1.out/'
# aryne_8755_rdkit_conf_1.out
# out found
# Moved 'aryne_8755_rdkit_conf_1.out' to '/aryne_8755_rdkit_conf_1.out/'
# aryne_8772_rdkit_conf_1.out
# out found
# Moved 'aryne_8772_rdkit_conf_1.out' to '/aryne_8772_rdkit_conf_1.out/'
# aryne_8775_rdkit_conf_1.out
# out found
# Moved 'aryne_8775_rdkit_conf_1.out' to '/aryne_8775_rdkit_conf_1.out/'
# aryne_8776_rdkit_conf_1.out
# out found
# Moved 'aryne_8776_rdkit_conf_1.out' to '/aryne_8776_rdkit_conf_1.out/'
# aryne_8789_rdkit_conf_1.out
# out found
# Moved 'aryne_8789_rdkit_conf_1.out' to '/aryne_8789_rdkit_conf_1.out/'
# aryne_8824_rdkit_conf_1.out
# out found
# Moved 'aryne_8824_rdkit_conf_1.out' to '/aryne_8824_rdkit_conf_1.out/'
# aryne_8838_rdkit_conf_1.out
# out found
# Moved 'aryne_8838_rdkit_conf_1.out' to '/aryne_8838_rdkit_conf_1.out/'
# aryne_8848_rdkit_conf_1.out
# out found
# Moved 'aryne_8848_rdkit_conf_1.out' to '/aryne_8848_rdkit_conf_1.out/'
# aryne_8857_rdkit_conf_1.out
# out found
# Moved 'aryne_8857_rdkit_conf_1.out' to '/aryne_8857_rdkit_conf_1.out/'
# aryne_8955_rdkit_conf_1.out
# out found
# Moved 'aryne_8955_rdkit_conf_1.out' to '/aryne_8955_rdkit_conf_1.out/'
# aryne_9003_rdkit_conf_1.out
# out found
# Moved 'aryne_9003_rdkit_conf_1.out' to '/aryne_9003_rdkit_conf_1.out/'
# aryne_9021_rdkit_conf_1.out
# out found
# Moved 'aryne_9021_rdkit_conf_1.out' to '/aryne_9021_rdkit_conf_1.out/'
# aryne_9040_rdkit_conf_1.out
# out found
# Moved 'aryne_9040_rdkit_conf_1.out' to '/aryne_9040_rdkit_conf_1.out/'
# aryne_9048_rdkit_conf_1.out
# out found
# Moved 'aryne_9048_rdkit_conf_1.out' to '/aryne_9048_rdkit_conf_1.out/'
# aryne_9061_rdkit_conf_1.out
# out found
# Moved 'aryne_9061_rdkit_conf_1.out' to '/aryne_9061_rdkit_conf_1.out/'
# aryne_9069_rdkit_conf_1.out
# out found
# Moved 'aryne_9069_rdkit_conf_1.out' to '/aryne_9069_rdkit_conf_1.out/'
# aryne_9071_rdkit_conf_1.out
# out found
# Moved 'aryne_9071_rdkit_conf_1.out' to '/aryne_9071_rdkit_conf_1.out/'
# aryne_9072_rdkit_conf_1.out
# out found
# Moved 'aryne_9072_rdkit_conf_1.out' to '/aryne_9072_rdkit_conf_1.out/'
# aryne_9116_rdkit_conf_1.out
# out found
# Moved 'aryne_9116_rdkit_conf_1.out' to '/aryne_9116_rdkit_conf_1.out/'
# aryne_9128_rdkit_conf_1.out
# out found
# Moved 'aryne_9128_rdkit_conf_1.out' to '/aryne_9128_rdkit_conf_1.out/'
# aryne_9145_rdkit_conf_1.out
# out found
# Moved 'aryne_9145_rdkit_conf_1.out' to '/aryne_9145_rdkit_conf_1.out/'
# aryne_9148_rdkit_conf_1.out
# out found
# Moved 'aryne_9148_rdkit_conf_1.out' to '/aryne_9148_rdkit_conf_1.out/'
# aryne_9151_rdkit_conf_1.out
# out found
# Moved 'aryne_9151_rdkit_conf_1.out' to '/aryne_9151_rdkit_conf_1.out/'
# aryne_9154_rdkit_conf_1.out
# out found
# Moved 'aryne_9154_rdkit_conf_1.out' to '/aryne_9154_rdkit_conf_1.out/'
# aryne_9156_rdkit_conf_1.out
# out found
# Moved 'aryne_9156_rdkit_conf_1.out' to '/aryne_9156_rdkit_conf_1.out/'
# aryne_9182_rdkit_conf_1.out
# out found
# Moved 'aryne_9182_rdkit_conf_1.out' to '/aryne_9182_rdkit_conf_1.out/'
# aryne_9211_rdkit_conf_1.out
# out found
# Moved 'aryne_9211_rdkit_conf_1.out' to '/aryne_9211_rdkit_conf_1.out/'
# aryne_9244_rdkit_conf_1.out
# out found
# Moved 'aryne_9244_rdkit_conf_1.out' to '/aryne_9244_rdkit_conf_1.out/'
# aryne_9271_rdkit_conf_1.out
# out found
# Moved 'aryne_9271_rdkit_conf_1.out' to '/aryne_9271_rdkit_conf_1.out/'
# aryne_9293_rdkit_conf_1.out
# out found
# Moved 'aryne_9293_rdkit_conf_1.out' to '/aryne_9293_rdkit_conf_1.out/'
# aryne_9326_rdkit_conf_1.out
# out found
# Moved 'aryne_9326_rdkit_conf_1.out' to '/aryne_9326_rdkit_conf_1.out/'

# %%
""" ### Write Final Arene.SDFs ###

This cell generates finalized .sd-files (.sdf) for archival.
The atomic connectivity is retained from pre-opt sd-files. 
The geometry is extracted from the DFT calculation (it is a DFT-optimized geom). 
"""
present_sdfs = get_filepaths_in_target_dir(arene_post_opt_sdf_path, ".sdf")

if present_sdfs:
    print(f"Found {len(present_sdfs)} .sdfs in '/{arene_post_opt_sdf_path.name}/'")
else: 
    #Fields: (.output dir, .xyz dir, pre-opt SDF dir, target dir to write to) 
    write_optimized_sdfs(arene_dft_output_path, arene_post_opt_xyz_path, arene_pre_opt_sdf_path, arene_post_opt_sdf_path)
# Out:
# Found 7880 .sdf files in '/Arene_Post_Opt_sdfs/'
# Found 7880 .sdfs in '/Arene_Post_Opt_sdfs/'

# %%
""" ### Write Final Aryne.SDFs for archival ###

This cell generates finalized .sd-files (.sdf) for archival.
The connectivity is retained from pre-opt sd-files. 
The geometry is extracted from the DFT calculation (it is a DFT-optimized geom). 
"""

#Fields: (.output dir, .xyz dir, pre-opt SDF dir, target dir to write to) 
write_optimized_sdfs(aryne_dft_output_path, aryne_post_opt_xyz_path, aryne_pre_opt_sdf_path, aryne_post_opt_sdf_path)
# Out:
# Writing new .sd-files from DFT-optimized .out files in '/Aryne_Orca_DFT_Outputs/'....
#
# Found 8420 .out files in '/Aryne_Orca_DFT_Outputs/'
# Found 8420 .xyz files in '/Aryne_Opt_xyz_Files/'
# Found 9459 .sdf files in '/Aryne_PreOpt_sdfs/'
# Checking for necessary files in /target_dirs/...
# Found '8420' validated output.outs in '/Aryne_Orca_DFT_Outputs/'
# Found '8420' optimized .xyzs in '/Aryne_Opt_xyz_Files/'
# Found '9459' pre-opt.sdfs in '/Aryne_PreOpt_sdfs/'
# Writing new .sdfs to: '/Aryne_Post_Opt_sdfs/'
#
# Working file: 'aryne_1_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_1_rdkit.sdf'
# 	Found matching .xyz: 'aryne_1_rdkit_conf_1.xyz'
# Copying 'aryne_1_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_1_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_2_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_2_rdkit.sdf'
# 	Found matching .xyz: 'aryne_2_rdkit_conf_1.xyz'
# Copying 'aryne_2_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_2_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_3_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_3_rdkit.sdf'
# 	Found matching .xyz: 'aryne_3_rdkit_conf_1.xyz'
# Copying 'aryne_3_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_3_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_4_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_4_rdkit.sdf'
# 	Found matching .xyz: 'aryne_4_rdkit_conf_1.xyz'
# Copying 'aryne_4_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_4_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_5_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_5_rdkit.sdf'
# 	Found matching .xyz: 'aryne_5_rdkit_conf_1.xyz'
# Copying 'aryne_5_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_5_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_8_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_8_rdkit.sdf'
# 	Found matching .xyz: 'aryne_8_rdkit_conf_1.xyz'
# Copying 'aryne_8_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_8_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_9_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_9_rdkit.sdf'
# 	Found matching .xyz: 'aryne_9_rdkit_conf_1.xyz'
# Copying 'aryne_9_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_9_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_10_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_10_rdkit.sdf'
# 	Found matching .xyz: 'aryne_10_rdkit_conf_1.xyz'
# Copying 'aryne_10_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_10_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_11_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_11_rdkit.sdf'
# 	Found matching .xyz: 'aryne_11_rdkit_conf_1.xyz'
# Copying 'aryne_11_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_11_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_12_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_12_rdkit.sdf'
# 	Found matching .xyz: 'aryne_12_rdkit_conf_1.xyz'
# Copying 'aryne_12_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_12_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_13_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_13_rdkit.sdf'
# 	Found matching .xyz: 'aryne_13_rdkit_conf_1.xyz'
# Copying 'aryne_13_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_13_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_14_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_14_rdkit.sdf'
# 	Found matching .xyz: 'aryne_14_rdkit_conf_1.xyz'
# Copying 'aryne_14_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_14_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_15_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_15_rdkit.sdf'
# 	Found matching .xyz: 'aryne_15_rdkit_conf_1.xyz'
# Copying 'aryne_15_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_15_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_16_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_16_rdkit.sdf'
# 	Found matching .xyz: 'aryne_16_rdkit_conf_1.xyz'
# Copying 'aryne_16_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_16_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_17_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_17_rdkit.sdf'
# 	Found matching .xyz: 'aryne_17_rdkit_conf_1.xyz'
# Copying 'aryne_17_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_17_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_18_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_18_rdkit.sdf'
# 	Found matching .xyz: 'aryne_18_rdkit_conf_1.xyz'
# Copying 'aryne_18_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_18_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_19_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_19_rdkit.sdf'
# 	Found matching .xyz: 'aryne_19_rdkit_conf_1.xyz'
# Copying 'aryne_19_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_19_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_20_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_20_rdkit.sdf'
# 	Found matching .xyz: 'aryne_20_rdkit_conf_1.xyz'
# Copying 'aryne_20_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_20_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_21_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_21_rdkit.sdf'
# 	Found matching .xyz: 'aryne_21_rdkit_conf_1.xyz'
# Copying 'aryne_21_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_21_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_22_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_22_rdkit.sdf'
# 	Found matching .xyz: 'aryne_22_rdkit_conf_1.xyz'
# Copying 'aryne_22_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_22_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_23_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_23_rdkit.sdf'
# 	Found matching .xyz: 'aryne_23_rdkit_conf_1.xyz'
# Copying 'aryne_23_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_23_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_24_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_24_rdkit.sdf'
# 	Found matching .xyz: 'aryne_24_rdkit_conf_1.xyz'
# Copying 'aryne_24_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_24_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_25_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_25_rdkit.sdf'
# 	Found matching .xyz: 'aryne_25_rdkit_conf_1.xyz'
# Copying 'aryne_25_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_25_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_26_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_26_rdkit.sdf'
# 	Found matching .xyz: 'aryne_26_rdkit_conf_1.xyz'
# Copying 'aryne_26_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_26_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_27_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_27_rdkit.sdf'
# 	Found matching .xyz: 'aryne_27_rdkit_conf_1.xyz'
# Copying 'aryne_27_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_27_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_29_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_29_rdkit.sdf'
# 	Found matching .xyz: 'aryne_29_rdkit_conf_1.xyz'
# Copying 'aryne_29_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_29_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_30_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_30_rdkit.sdf'
# 	Found matching .xyz: 'aryne_30_rdkit_conf_1.xyz'
# Copying 'aryne_30_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_30_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_32_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_32_rdkit.sdf'
# 	Found matching .xyz: 'aryne_32_rdkit_conf_1.xyz'
# Copying 'aryne_32_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_32_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_33_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_33_rdkit.sdf'
# 	Found matching .xyz: 'aryne_33_rdkit_conf_1.xyz'
# Copying 'aryne_33_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_33_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_36_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_36_rdkit.sdf'
# 	Found matching .xyz: 'aryne_36_rdkit_conf_1.xyz'
# Copying 'aryne_36_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_36_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_37_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_37_rdkit.sdf'
# 	Found matching .xyz: 'aryne_37_rdkit_conf_1.xyz'
# Copying 'aryne_37_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_37_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_39_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_39_rdkit.sdf'
# 	Found matching .xyz: 'aryne_39_rdkit_conf_1.xyz'
# Copying 'aryne_39_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_39_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_41_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_41_rdkit.sdf'
# 	Found matching .xyz: 'aryne_41_rdkit_conf_1.xyz'
# Copying 'aryne_41_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_41_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_42_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_42_rdkit.sdf'
# 	Found matching .xyz: 'aryne_42_rdkit_conf_1.xyz'
# Copying 'aryne_42_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_42_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_43_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_43_rdkit.sdf'
# 	Found matching .xyz: 'aryne_43_rdkit_conf_1.xyz'
# Copying 'aryne_43_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_43_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_45_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_45_rdkit.sdf'
# 	Found matching .xyz: 'aryne_45_rdkit_conf_1.xyz'
# Copying 'aryne_45_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_45_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_46_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_46_rdkit.sdf'
# 	Found matching .xyz: 'aryne_46_rdkit_conf_1.xyz'
# Copying 'aryne_46_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_46_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_47_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_47_rdkit.sdf'
# 	Found matching .xyz: 'aryne_47_rdkit_conf_1.xyz'
# Copying 'aryne_47_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_47_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_48_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_48_rdkit.sdf'
# 	Found matching .xyz: 'aryne_48_rdkit_conf_1.xyz'
# Copying 'aryne_48_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_48_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_49_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_49_rdkit.sdf'
# 	Found matching .xyz: 'aryne_49_rdkit_conf_1.xyz'
# Copying 'aryne_49_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_49_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_50_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_50_rdkit.sdf'
# 	Found matching .xyz: 'aryne_50_rdkit_conf_1.xyz'
# Copying 'aryne_50_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_50_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_51_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_51_rdkit.sdf'
# 	Found matching .xyz: 'aryne_51_rdkit_conf_1.xyz'
# Copying 'aryne_51_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_51_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_52_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_52_rdkit.sdf'
# 	Found matching .xyz: 'aryne_52_rdkit_conf_1.xyz'
# Copying 'aryne_52_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_52_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_53_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_53_rdkit.sdf'
# 	Found matching .xyz: 'aryne_53_rdkit_conf_1.xyz'
# Copying 'aryne_53_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_53_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_54_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_54_rdkit.sdf'
# 	Found matching .xyz: 'aryne_54_rdkit_conf_1.xyz'
# Copying 'aryne_54_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_54_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_55_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_55_rdkit.sdf'
# 	Found matching .xyz: 'aryne_55_rdkit_conf_1.xyz'
# Copying 'aryne_55_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_55_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_56_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_56_rdkit.sdf'
# 	Found matching .xyz: 'aryne_56_rdkit_conf_1.xyz'
# Copying 'aryne_56_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_56_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_58_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_58_rdkit.sdf'
# 	Found matching .xyz: 'aryne_58_rdkit_conf_1.xyz'
# Copying 'aryne_58_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_58_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_59_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_59_rdkit.sdf'
# 	Found matching .xyz: 'aryne_59_rdkit_conf_1.xyz'
# Copying 'aryne_59_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_59_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_60_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_60_rdkit.sdf'
# 	Found matching .xyz: 'aryne_60_rdkit_conf_1.xyz'
# Copying 'aryne_60_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_60_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_61_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_61_rdkit.sdf'
# 	Found matching .xyz: 'aryne_61_rdkit_conf_1.xyz'
# Copying 'aryne_61_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_61_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_62_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_62_rdkit.sdf'
# 	Found matching .xyz: 'aryne_62_rdkit_conf_1.xyz'
# Copying 'aryne_62_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_62_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_63_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_63_rdkit.sdf'
# 	Found matching .xyz: 'aryne_63_rdkit_conf_1.xyz'
# Copying 'aryne_63_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_63_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_64_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_64_rdkit.sdf'
# 	Found matching .xyz: 'aryne_64_rdkit_conf_1.xyz'
# Copying 'aryne_64_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_64_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_65_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_65_rdkit.sdf'
# 	Found matching .xyz: 'aryne_65_rdkit_conf_1.xyz'
# Copying 'aryne_65_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_65_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_67_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_67_rdkit.sdf'
# 	Found matching .xyz: 'aryne_67_rdkit_conf_1.xyz'
# Copying 'aryne_67_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_67_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_68_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_68_rdkit.sdf'
# 	Found matching .xyz: 'aryne_68_rdkit_conf_1.xyz'
# Copying 'aryne_68_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_68_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_69_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_69_rdkit.sdf'
# 	Found matching .xyz: 'aryne_69_rdkit_conf_1.xyz'
# Copying 'aryne_69_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_69_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_70_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_70_rdkit.sdf'
# 	Found matching .xyz: 'aryne_70_rdkit_conf_1.xyz'
# Copying 'aryne_70_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_70_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_71_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_71_rdkit.sdf'
# 	Found matching .xyz: 'aryne_71_rdkit_conf_1.xyz'
# Copying 'aryne_71_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_71_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_72_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_72_rdkit.sdf'
# 	Found matching .xyz: 'aryne_72_rdkit_conf_1.xyz'
# Copying 'aryne_72_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_72_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_73_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_73_rdkit.sdf'
# 	Found matching .xyz: 'aryne_73_rdkit_conf_1.xyz'
# Copying 'aryne_73_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_73_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_75_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_75_rdkit.sdf'
# 	Found matching .xyz: 'aryne_75_rdkit_conf_1.xyz'
# Copying 'aryne_75_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_75_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_76_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_76_rdkit.sdf'
# 	Found matching .xyz: 'aryne_76_rdkit_conf_1.xyz'
# Copying 'aryne_76_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_76_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_77_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_77_rdkit.sdf'
# 	Found matching .xyz: 'aryne_77_rdkit_conf_1.xyz'
# Copying 'aryne_77_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_77_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_78_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_78_rdkit.sdf'
# 	Found matching .xyz: 'aryne_78_rdkit_conf_1.xyz'
# Copying 'aryne_78_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_78_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_79_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_79_rdkit.sdf'
# 	Found matching .xyz: 'aryne_79_rdkit_conf_1.xyz'
# Copying 'aryne_79_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_79_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_80_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_80_rdkit.sdf'
# 	Found matching .xyz: 'aryne_80_rdkit_conf_1.xyz'
# Copying 'aryne_80_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_80_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_81_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_81_rdkit.sdf'
# 	Found matching .xyz: 'aryne_81_rdkit_conf_1.xyz'
# Copying 'aryne_81_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_81_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_82_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_82_rdkit.sdf'
# 	Found matching .xyz: 'aryne_82_rdkit_conf_1.xyz'
# Copying 'aryne_82_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_82_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_83_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_83_rdkit.sdf'
# 	Found matching .xyz: 'aryne_83_rdkit_conf_1.xyz'
# Copying 'aryne_83_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_83_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_84_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_84_rdkit.sdf'
# 	Found matching .xyz: 'aryne_84_rdkit_conf_1.xyz'
# Copying 'aryne_84_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_84_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_85_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_85_rdkit.sdf'
# 	Found matching .xyz: 'aryne_85_rdkit_conf_1.xyz'
# Copying 'aryne_85_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_85_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_86_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_86_rdkit.sdf'
# 	Found matching .xyz: 'aryne_86_rdkit_conf_1.xyz'
# Copying 'aryne_86_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_86_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_87_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_87_rdkit.sdf'
# 	Found matching .xyz: 'aryne_87_rdkit_conf_1.xyz'
# Copying 'aryne_87_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_87_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_88_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_88_rdkit.sdf'
# 	Found matching .xyz: 'aryne_88_rdkit_conf_1.xyz'
# Copying 'aryne_88_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_88_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_89_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_89_rdkit.sdf'
# 	Found matching .xyz: 'aryne_89_rdkit_conf_1.xyz'
# Copying 'aryne_89_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_89_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_90_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_90_rdkit.sdf'
# 	Found matching .xyz: 'aryne_90_rdkit_conf_1.xyz'
# Copying 'aryne_90_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_90_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_92_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_92_rdkit.sdf'
# 	Found matching .xyz: 'aryne_92_rdkit_conf_1.xyz'
# Copying 'aryne_92_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_92_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_93_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_93_rdkit.sdf'
# 	Found matching .xyz: 'aryne_93_rdkit_conf_1.xyz'
# Copying 'aryne_93_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_93_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_94_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_94_rdkit.sdf'
# 	Found matching .xyz: 'aryne_94_rdkit_conf_1.xyz'
# Copying 'aryne_94_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_94_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_95_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_95_rdkit.sdf'
# 	Found matching .xyz: 'aryne_95_rdkit_conf_1.xyz'
# Copying 'aryne_95_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_95_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_96_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_96_rdkit.sdf'
# 	Found matching .xyz: 'aryne_96_rdkit_conf_1.xyz'
# Copying 'aryne_96_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_96_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_97_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_97_rdkit.sdf'
# 	Found matching .xyz: 'aryne_97_rdkit_conf_1.xyz'
# Copying 'aryne_97_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_97_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_98_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_98_rdkit.sdf'
# 	Found matching .xyz: 'aryne_98_rdkit_conf_1.xyz'
# Copying 'aryne_98_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_98_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_99_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_99_rdkit.sdf'
# 	Found matching .xyz: 'aryne_99_rdkit_conf_1.xyz'
# Copying 'aryne_99_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_99_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_100_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_100_rdkit.sdf'
# 	Found matching .xyz: 'aryne_100_rdkit_conf_1.xyz'
# Copying 'aryne_100_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_100_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_101_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_101_rdkit.sdf'
# 	Found matching .xyz: 'aryne_101_rdkit_conf_1.xyz'
# Copying 'aryne_101_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_101_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_102_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_102_rdkit.sdf'
# 	Found matching .xyz: 'aryne_102_rdkit_conf_1.xyz'
# Copying 'aryne_102_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_102_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_103_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_103_rdkit.sdf'
# 	Found matching .xyz: 'aryne_103_rdkit_conf_1.xyz'
# Copying 'aryne_103_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_103_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_104_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_104_rdkit.sdf'
# 	Found matching .xyz: 'aryne_104_rdkit_conf_1.xyz'
# Copying 'aryne_104_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_104_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_105_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_105_rdkit.sdf'
# 	Found matching .xyz: 'aryne_105_rdkit_conf_1.xyz'
# Copying 'aryne_105_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_105_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_107_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_107_rdkit.sdf'
# 	Found matching .xyz: 'aryne_107_rdkit_conf_1.xyz'
# Copying 'aryne_107_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_107_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_108_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_108_rdkit.sdf'
# 	Found matching .xyz: 'aryne_108_rdkit_conf_1.xyz'
# Copying 'aryne_108_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_108_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_109_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_109_rdkit.sdf'
# 	Found matching .xyz: 'aryne_109_rdkit_conf_1.xyz'
# Copying 'aryne_109_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_109_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_111_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_111_rdkit.sdf'
# 	Found matching .xyz: 'aryne_111_rdkit_conf_1.xyz'
# Copying 'aryne_111_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_111_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_112_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_112_rdkit.sdf'
# 	Found matching .xyz: 'aryne_112_rdkit_conf_1.xyz'
# Copying 'aryne_112_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_112_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_113_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_113_rdkit.sdf'
# 	Found matching .xyz: 'aryne_113_rdkit_conf_1.xyz'
# Copying 'aryne_113_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_113_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_114_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_114_rdkit.sdf'
# 	Found matching .xyz: 'aryne_114_rdkit_conf_1.xyz'
# Copying 'aryne_114_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_114_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_115_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_115_rdkit.sdf'
# 	Found matching .xyz: 'aryne_115_rdkit_conf_1.xyz'
# Copying 'aryne_115_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_115_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_116_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_116_rdkit.sdf'
# 	Found matching .xyz: 'aryne_116_rdkit_conf_1.xyz'
# Copying 'aryne_116_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_116_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_117_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_117_rdkit.sdf'
# 	Found matching .xyz: 'aryne_117_rdkit_conf_1.xyz'
# Copying 'aryne_117_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_117_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_118_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_118_rdkit.sdf'
# 	Found matching .xyz: 'aryne_118_rdkit_conf_1.xyz'
# Copying 'aryne_118_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_118_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_119_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_119_rdkit.sdf'
# 	Found matching .xyz: 'aryne_119_rdkit_conf_1.xyz'
# Copying 'aryne_119_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_119_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_120_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_120_rdkit.sdf'
# 	Found matching .xyz: 'aryne_120_rdkit_conf_1.xyz'
# Copying 'aryne_120_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_120_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_121_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_121_rdkit.sdf'
# 	Found matching .xyz: 'aryne_121_rdkit_conf_1.xyz'
# Copying 'aryne_121_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_121_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_122_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_122_rdkit.sdf'
# 	Found matching .xyz: 'aryne_122_rdkit_conf_1.xyz'
# Copying 'aryne_122_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_122_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_123_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_123_rdkit.sdf'
# 	Found matching .xyz: 'aryne_123_rdkit_conf_1.xyz'
# Copying 'aryne_123_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_123_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_124_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_124_rdkit.sdf'
# 	Found matching .xyz: 'aryne_124_rdkit_conf_1.xyz'
# Copying 'aryne_124_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_124_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_125_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_125_rdkit.sdf'
# 	Found matching .xyz: 'aryne_125_rdkit_conf_1.xyz'
# Copying 'aryne_125_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_125_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_126_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_126_rdkit.sdf'
# 	Found matching .xyz: 'aryne_126_rdkit_conf_1.xyz'
# Copying 'aryne_126_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_126_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_127_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_127_rdkit.sdf'
# 	Found matching .xyz: 'aryne_127_rdkit_conf_1.xyz'
# Copying 'aryne_127_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_127_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_128_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_128_rdkit.sdf'
# 	Found matching .xyz: 'aryne_128_rdkit_conf_1.xyz'
# Copying 'aryne_128_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_128_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_129_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_129_rdkit.sdf'
# 	Found matching .xyz: 'aryne_129_rdkit_conf_1.xyz'
# Copying 'aryne_129_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_129_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_130_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_130_rdkit.sdf'
# 	Found matching .xyz: 'aryne_130_rdkit_conf_1.xyz'
# Copying 'aryne_130_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_130_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_131_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_131_rdkit.sdf'
# 	Found matching .xyz: 'aryne_131_rdkit_conf_1.xyz'
# Copying 'aryne_131_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_131_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_133_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_133_rdkit.sdf'
# 	Found matching .xyz: 'aryne_133_rdkit_conf_1.xyz'
# Copying 'aryne_133_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_133_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_134_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_134_rdkit.sdf'
# 	Found matching .xyz: 'aryne_134_rdkit_conf_1.xyz'
# Copying 'aryne_134_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_134_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_135_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_135_rdkit.sdf'
# 	Found matching .xyz: 'aryne_135_rdkit_conf_1.xyz'
# Copying 'aryne_135_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_135_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_136_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_136_rdkit.sdf'
# 	Found matching .xyz: 'aryne_136_rdkit_conf_1.xyz'
# Copying 'aryne_136_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_136_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_137_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_137_rdkit.sdf'
# 	Found matching .xyz: 'aryne_137_rdkit_conf_1.xyz'
# Copying 'aryne_137_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_137_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_138_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_138_rdkit.sdf'
# 	Found matching .xyz: 'aryne_138_rdkit_conf_1.xyz'
# Copying 'aryne_138_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_138_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_139_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_139_rdkit.sdf'
# 	Found matching .xyz: 'aryne_139_rdkit_conf_1.xyz'
# Copying 'aryne_139_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_139_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_141_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_141_rdkit.sdf'
# 	Found matching .xyz: 'aryne_141_rdkit_conf_1.xyz'
# Copying 'aryne_141_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_141_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_142_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_142_rdkit.sdf'
# 	Found matching .xyz: 'aryne_142_rdkit_conf_1.xyz'
# Copying 'aryne_142_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_142_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_143_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_143_rdkit.sdf'
# 	Found matching .xyz: 'aryne_143_rdkit_conf_1.xyz'
# Copying 'aryne_143_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_143_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_144_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_144_rdkit.sdf'
# 	Found matching .xyz: 'aryne_144_rdkit_conf_1.xyz'
# Copying 'aryne_144_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_144_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_145_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_145_rdkit.sdf'
# 	Found matching .xyz: 'aryne_145_rdkit_conf_1.xyz'
# Copying 'aryne_145_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_145_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_146_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_146_rdkit.sdf'
# 	Found matching .xyz: 'aryne_146_rdkit_conf_1.xyz'
# Copying 'aryne_146_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_146_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_147_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_147_rdkit.sdf'
# 	Found matching .xyz: 'aryne_147_rdkit_conf_1.xyz'
# Copying 'aryne_147_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_147_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_150_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_150_rdkit.sdf'
# 	Found matching .xyz: 'aryne_150_rdkit_conf_1.xyz'
# Copying 'aryne_150_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_150_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_151_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_151_rdkit.sdf'
# 	Found matching .xyz: 'aryne_151_rdkit_conf_1.xyz'
# Copying 'aryne_151_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_151_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_152_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_152_rdkit.sdf'
# 	Found matching .xyz: 'aryne_152_rdkit_conf_1.xyz'
# Copying 'aryne_152_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_152_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_153_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_153_rdkit.sdf'
# 	Found matching .xyz: 'aryne_153_rdkit_conf_1.xyz'
# Copying 'aryne_153_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_153_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_154_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_154_rdkit.sdf'
# 	Found matching .xyz: 'aryne_154_rdkit_conf_1.xyz'
# Copying 'aryne_154_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_154_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_155_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_155_rdkit.sdf'
# 	Found matching .xyz: 'aryne_155_rdkit_conf_1.xyz'
# Copying 'aryne_155_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_155_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_156_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_156_rdkit.sdf'
# 	Found matching .xyz: 'aryne_156_rdkit_conf_1.xyz'
# Copying 'aryne_156_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_156_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_158_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_158_rdkit.sdf'
# 	Found matching .xyz: 'aryne_158_rdkit_conf_1.xyz'
# Copying 'aryne_158_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_158_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_159_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_159_rdkit.sdf'
# 	Found matching .xyz: 'aryne_159_rdkit_conf_1.xyz'
# Copying 'aryne_159_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_159_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_160_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_160_rdkit.sdf'
# 	Found matching .xyz: 'aryne_160_rdkit_conf_1.xyz'
# Copying 'aryne_160_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_160_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_161_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_161_rdkit.sdf'
# 	Found matching .xyz: 'aryne_161_rdkit_conf_1.xyz'
# Copying 'aryne_161_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_161_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_162_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_162_rdkit.sdf'
# 	Found matching .xyz: 'aryne_162_rdkit_conf_1.xyz'
# Copying 'aryne_162_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_162_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_163_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_163_rdkit.sdf'
# 	Found matching .xyz: 'aryne_163_rdkit_conf_1.xyz'
# Copying 'aryne_163_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_163_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_164_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_164_rdkit.sdf'
# 	Found matching .xyz: 'aryne_164_rdkit_conf_1.xyz'
# Copying 'aryne_164_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_164_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_165_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_165_rdkit.sdf'
# 	Found matching .xyz: 'aryne_165_rdkit_conf_1.xyz'
# Copying 'aryne_165_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_165_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_166_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_166_rdkit.sdf'
# 	Found matching .xyz: 'aryne_166_rdkit_conf_1.xyz'
# Copying 'aryne_166_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_166_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_167_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_167_rdkit.sdf'
# 	Found matching .xyz: 'aryne_167_rdkit_conf_1.xyz'
# Copying 'aryne_167_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_167_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_168_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_168_rdkit.sdf'
# 	Found matching .xyz: 'aryne_168_rdkit_conf_1.xyz'
# Copying 'aryne_168_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_168_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_169_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_169_rdkit.sdf'
# 	Found matching .xyz: 'aryne_169_rdkit_conf_1.xyz'
# Copying 'aryne_169_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_169_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_170_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_170_rdkit.sdf'
# 	Found matching .xyz: 'aryne_170_rdkit_conf_1.xyz'
# Copying 'aryne_170_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_170_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_171_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_171_rdkit.sdf'
# 	Found matching .xyz: 'aryne_171_rdkit_conf_1.xyz'
# Copying 'aryne_171_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_171_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_172_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_172_rdkit.sdf'
# 	Found matching .xyz: 'aryne_172_rdkit_conf_1.xyz'
# Copying 'aryne_172_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_172_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_173_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_173_rdkit.sdf'
# 	Found matching .xyz: 'aryne_173_rdkit_conf_1.xyz'
# Copying 'aryne_173_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_173_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_174_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_174_rdkit.sdf'
# 	Found matching .xyz: 'aryne_174_rdkit_conf_1.xyz'
# Copying 'aryne_174_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_174_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_175_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_175_rdkit.sdf'
# 	Found matching .xyz: 'aryne_175_rdkit_conf_1.xyz'
# Copying 'aryne_175_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_175_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_176_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_176_rdkit.sdf'
# 	Found matching .xyz: 'aryne_176_rdkit_conf_1.xyz'
# Copying 'aryne_176_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_176_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_177_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_177_rdkit.sdf'
# 	Found matching .xyz: 'aryne_177_rdkit_conf_1.xyz'
# Copying 'aryne_177_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_177_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_178_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_178_rdkit.sdf'
# 	Found matching .xyz: 'aryne_178_rdkit_conf_1.xyz'
# Copying 'aryne_178_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_178_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_179_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_179_rdkit.sdf'
# 	Found matching .xyz: 'aryne_179_rdkit_conf_1.xyz'
# Copying 'aryne_179_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_179_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_180_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_180_rdkit.sdf'
# 	Found matching .xyz: 'aryne_180_rdkit_conf_1.xyz'
# Copying 'aryne_180_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_180_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_181_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_181_rdkit.sdf'
# 	Found matching .xyz: 'aryne_181_rdkit_conf_1.xyz'
# Copying 'aryne_181_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_181_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_182_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_182_rdkit.sdf'
# 	Found matching .xyz: 'aryne_182_rdkit_conf_1.xyz'
# Copying 'aryne_182_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_182_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_183_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_183_rdkit.sdf'
# 	Found matching .xyz: 'aryne_183_rdkit_conf_1.xyz'
# Copying 'aryne_183_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_183_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_184_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_184_rdkit.sdf'
# 	Found matching .xyz: 'aryne_184_rdkit_conf_1.xyz'
# Copying 'aryne_184_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_184_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_186_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_186_rdkit.sdf'
# 	Found matching .xyz: 'aryne_186_rdkit_conf_1.xyz'
# Copying 'aryne_186_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_186_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_188_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_188_rdkit.sdf'
# 	Found matching .xyz: 'aryne_188_rdkit_conf_1.xyz'
# Copying 'aryne_188_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_188_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_189_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_189_rdkit.sdf'
# 	Found matching .xyz: 'aryne_189_rdkit_conf_1.xyz'
# Copying 'aryne_189_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_189_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_191_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_191_rdkit.sdf'
# 	Found matching .xyz: 'aryne_191_rdkit_conf_1.xyz'
# Copying 'aryne_191_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_191_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_192_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_192_rdkit.sdf'
# 	Found matching .xyz: 'aryne_192_rdkit_conf_1.xyz'
# Copying 'aryne_192_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_192_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_193_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_193_rdkit.sdf'
# 	Found matching .xyz: 'aryne_193_rdkit_conf_1.xyz'
# Copying 'aryne_193_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne_193_rdkit.sdf' already exists in '/Aryne_Post_Opt_sdfs/'. Copy skipped.
#
# Working file: 'aryne_194_rdkit_conf_1.out'
# 	Found matching .sdf: 'aryne_194_rdkit.sdf'
# 	Found matching .xyz: 'aryne_194_rdkit_conf_1.xyz'
# Copying 'aryne_194_rdkit.sdf' to '/Aryne_Post_Opt_sdfs/'
# 	'aryne
    dEs and the dehydration energy before being written to an output .csv. 
    
"""

### Read in the generated arene/aryne.csv dataset from TLD ### 
#Use this as a naming reference against the files in our output dirs
hetaryne_df = pd.read_csv('arenes_and_generated_arynes.csv')
hetaryne_df.head()
# Out:
#   arene_ID          arene_smiles aryne_ID           aryne_smiles
# 0  arene_1       O=c1nc2ccsc2cs1  aryne_1       O=c1nc2c#csc2cs1
# 1  arene_2    c1csn2nn[nH]cc-2o1  aryne_2    c1oc2c[nH]nnn-2sc#1
# 2  arene_3   O=c1cnc2occsc=2c1=O  aryne_3   O=c1cnc2oc#csc=2c1=O
# 3  arene_4  O=c1cnc2sc(=O)ccc2s1  aryne_4  O=c1c#cc2sc(=O)cnc2s1
# 4  arene_5   O=c1ccn2sccsn2[nH]1  aryne_5   O=c1c#cn2sccsn2[nH]1

# %%
"""### Extract SCF Energies from DFT-Optimized ARENES ###

This cell will extract the final single point SCF Energy (dE) from validated Orca Arene.outs
in the /arene_dft_outs dir. The ID-paired energies are appended to a new column in a Pandas DF.
'NaN' is appendend if/when an .out is undreadable/the SCF energy can't be found. 
"""

if "arene_energy" in hetaryne_df.columns:
    print(f"Found extant 'arene_energy' data in current dataframe.")
    
else:
    #Extract energies from processed/valid ARENE Orca .out files
    print("Processing Arene Energies...")
    hetaryne_df['arene_energy'] = extract_dE_to_dataframe(hetaryne_df['arene_ID'], arene_dft_output_path)

#print the first 5 rows of the DF 
hetaryne_df.head()
# Out:
# Processing Arene Energies...
# arene_9_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_64_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_96_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_96_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_127_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_177_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_186_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_215_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_219_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_239_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_247_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_322_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_335_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_378_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_495_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_509_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_544_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_556_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_574_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_589_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_602_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_638_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_679_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_705_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_713_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_713_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_732_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_734_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_735_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_738_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_743_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_775_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_795_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_812_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_851_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_851_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_898_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_900_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_919_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_939_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_942_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_962_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_986_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_994_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1017_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1055_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1066_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1070_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1134_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1139_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1162_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1193_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1216_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1216_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1226_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1283_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1292_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1412_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1453_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1481_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1481_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1481_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1481_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1481_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1494_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1499_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1569_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1595_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1606_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1606_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1608_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1612_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1637_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1641_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1660_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1679_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1679_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1679_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1710_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1720_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1725_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1730_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1734_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1737_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1749_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1767_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1780_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1891_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1929_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_1988_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2026_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2056_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2061_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2146_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2146_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2171_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2177_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2231_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2231_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2237_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2251_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2274_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2274_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2298_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2334_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2403_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2408_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2427_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2433_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2451_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2451_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2467_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2467_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2469_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2469_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2488_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2492_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2499_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2524_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2560_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2608_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2639_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2665_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2713_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2715_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2752_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2752_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2754_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2768_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2800_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2917_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2927_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2951_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2963_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2973_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2973_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2974_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2979_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_2991_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3087_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3109_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3132_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3134_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3174_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3174_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3179_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3203_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3205_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3235_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3249_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3281_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3309_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3309_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3326_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3337_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3342_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3346_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3358_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3358_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3366_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3381_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3381_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3436_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3450_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3452_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3486_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3497_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3501_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3504_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3506_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3521_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3558_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3560_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3560_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3610_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3684_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3729_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3759_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3761_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3810_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3825_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3858_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3892_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3920_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3925_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3956_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3978_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_3991_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4013_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4026_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4042_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4050_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4054_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_4080_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Arene_Data\Arene_Orca_DFT_Outputs/'
# arene_
rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_4048_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# ...
# aryne_8536_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8537_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8539_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8545_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8563_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8570_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8573_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8592_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8598_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8604_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8624_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8642_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8655_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8657_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8658_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8667_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8697_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8702_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8705_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8707_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8711_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8730_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8749_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8751_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8755_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8772_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8775_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8776_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8782_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8789_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8814_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8824_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8826_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8832_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8833_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8838_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8839_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8843_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8848_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8855_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8857_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8870_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8872_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8879_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8882_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8885_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8893_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8900_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8906_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8909_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8914_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8926_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8930_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8935_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8951_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8955_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8960_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8961_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8966_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_8993_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9000_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9001_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9003_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9005_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9011_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9021_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9036_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9040_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9047_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9048_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9061_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9069_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9071_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9072_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9075_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9080_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9085_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9116_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9122_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9124_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9125_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9128_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9129_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9140_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9145_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9148_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9151_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9154_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9156_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9177_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9180_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9182_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9183_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9186_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9187_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9196_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9210_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9211_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9227_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9235_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9244_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9266_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9271_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9273_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9293_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9326_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9329_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9335_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9345_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9380_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9402_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9408_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9422_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9428_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9429_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9436_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9447_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
# aryne_9457_rdkit_conf_1 not found in '/C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local\DFT_Aryne_Data\Aryne_Orca_DFT_Outputs/'
#   arene_ID          arene_smiles aryne_ID           aryne_smiles  \
# 0  arene_1       O=c1nc2ccsc2cs1  aryne_1       O=c1nc2c#csc2cs1
# 1  arene_2    c1csn2nn[nH]cc-2o1  aryne_2    c1oc2c[nH]nnn-2sc#1
# 2  arene_3   O=c1cnc2occsc=2c1=O  aryne_3   O=c1cnc2oc#csc=2c1=O
# 3  arene_4  O=c1cnc2sc(=O)ccc2s1  aryne_4  O=c1c#cc2sc(=O)cnc2s1
# 4  arene_5   O=c1ccn2sccsn2[nH]1  aryne_5   O=c1c#cn2sccsn2[nH]1
#
#    arene_energy  aryne_energy
# 0    -1156.0883    -1154.7269
# 1     -846.4294     -845.1003
# 2     -946.3140     -944.9744
# 3    -1269.2819    -1267.9693
# 4    -1228.5052    -1227.1702

# %%
""" ### Compute dE(Dehydration) Using Arene ==> Aryne + H2 ###

This cell is used to calculate the DFT-derived dehydration energies for the hypothetical reaction 
    "Arene ==> Aryne + H2." The value is calculated from the values within Pandas DF "hetaryne_df".
    The SCF energy (dE) of H2 was calculated at the same LOT and manually entered, below. Values 
    are calculated in Hartree and then converted to Kcal/mol using the appl. conversion factor.
"""

#Compute the dehydrogenation energy given energies present in both arene/aryne columns
## the energy of H2 (same level of theory is -1.16498994) - this comes from the H2 orca calc in top-level dir

#conversion factor between Hartrees and kcal/mol
Hartree_to_kcal = 627.509

#calculate the dehydration energy using Arene ==> Aryne + H2; Round to 4dps; units are kcal/mol
if "dehydrogenation_energy" in hetaryne_df.columns:
    print(f"Found extant 'dehydrogenation_energy' data in current dataframe.\n")
else:
    print(f"Calculating dE(dehydrogenation)...")
    hetaryne_df['dehydrogenation_energy'] = round(((hetaryne_df['arene_energy'] - (hetaryne_df['aryne_energy'] + -1.16372587)) * -1 * Hartree_to_kcal), 4)

hetaryne_df.head()
# Out:
# Calculating dE(dehydrogenation)...
#   arene_ID          arene_smiles aryne_ID           aryne_smiles  \
# 0  arene_1       O=c1nc2ccsc2cs1  aryne_1       O=c1nc2c#csc2cs1
# 1  arene_2    c1csn2nn[nH]cc-2o1  aryne_2    c1oc2c[nH]nnn-2sc#1
# 2  arene_3   O=c1cnc2occsc=2c1=O  aryne_3   O=c1cnc2oc#csc=2c1=O
# 3  arene_4  O=c1cnc2sc(=O)ccc2s1  aryne_4  O=c1c#cc2sc(=O)cnc2s1
# 4  arene_5   O=c1ccn2sccsn2[nH]1  aryne_5   O=c1c#cn2sccsn2[nH]1
#
#    arene_energy  aryne_energy  dehydrogenation_energy
# 0    -1156.0883    -1154.7269                124.0423
# 1     -846.4294     -845.1003                103.7738
# 2     -946.3140     -944.9744                110.3626
# 3    -1269.2819    -1267.9693                 93.4199
# 4    -1228.5052    -1227.1702                107.4761

# %%
""" ### Format and Write data to .csv - Output 'Calculated_Dehydrogenation_Energies.csv' to /ProjectDir ###

This cell reformats the current dehydrogenation dataframe to a preferred column order and sorts ascending
    based on the "aryne_id" column (can also change that, here). Writes a .csv file to the /projectdir 
    called 'Calculated_Dehydrogenation_Energies.csv' containing DFT-calculated dE(dehyd.). 
"""

### Format Output.csv; Remove unitilized arenes/arynes; Output the final dehydrogenation_energies.csv  ###
new_col_order = ['arene_ID', 'arene_smiles', 'arene_energy',
                 'aryne_ID', 'aryne_smiles', 'aryne_energy',
                 'dehydrogenation_energy']

#copy df to change the column ordering
hydrog_df = hetaryne_df[new_col_order]

#Sort the df rows based on the aryne_id# (ascending)
hydrog_sorted = hydrog_df.sort_values(by='aryne_ID', key=lambda col: col.apply(lambda x: int(re.search(r'\d+', x).group())))

#Drop rows that contain a 'NaN' dehydrogenation energy (these don't have all the DFT calcs needed to calc dE)
dehydrogenation_energies_df = hydrog_sorted.dropna(how='any',axis=0)

#output the current DF as a .csv to TLD (project dir)
csv_name = 'Calculated_Dehydrogenation_Energies'
dehydrogenation_energies_df.to_csv(f'{csv_name}.csv', index=False)
print(f'\033[1m{csv_name}.csv containing {len(dehydrogenation_energies_df)} DFT-calculated dehydrogenation energies written to {project_dir}.\033[0m')

#for debug
dehydrogenation_energies_df.head()
# Out:
# Calculated_Dehydrogenation_Energies.csv containing 8124 DFT-calculated dehydrogenation energies written to C:\Chem_Work\CompChem_Working\CCAS_Hetarynes_Local.
#   arene_ID          arene_smiles  arene_energy aryne_ID  \
# 0  arene_1       O=c1nc2ccsc2cs1    -1156.0883  aryne_1
# 1  arene_2    c1csn2nn[nH]cc-2o1     -846.4294  aryne_2
# 2  arene_3   O=c1cnc2occsc=2c1=O     -946.3140  aryne_3
# 3  arene_4  O=c1cnc2sc(=O)ccc2s1    -1269.2819  aryne_4
# 4  arene_5   O=c1ccn2sccsn2[nH]1    -1228.5052  aryne_5
#
#             aryne_smiles  aryne_energy  dehydrogenation_energy
# 0       O=c1nc2c#csc2cs1    -1154.7269                124.0423
# 1    c1oc2c[nH]nnn-2sc#1     -845.1003                103.7738
# 2   O=c1cnc2oc#csc=2c1=O     -944.9744                110.3626
# 3  O=c1c#cc2sc(=O)cnc2s1    -1267.9693                 93.4199
# 4   O=c1c#cn2sccsn2[nH]1    -1227.1702                107.4761

# %%
"""### Final ARENE File Cleanup / Dir management before Parameter Extraction ###

This cell uses the generated "Calculated_Dehydrogenation_Energies.csv" to determine which .outs in 
/Arene_Orca_DFT_Outputs are paired with a "parent" arene. Unpaired arene.outs (those lacking a parent arene)
are moved to a "Valid but unused dir". Given some unused .outs, isolate the corresponding .sdfs and .xyzs 
for unpaired arenes. This ensures a 1:1 match in the number of validated files across all project subdirs.
"""

#Make dirs to hold unpaired files - these are either an arene/aryne missing its partner
#Dir for unpaired Arene.outs
unpaired_arene_outs = arene_dft_output_path/"Valid_but_Unpaired_arenes"
unpaired_arene_outs.mkdir(parents=True, exist_ok=True)

#Dir for unpaired arene_post_opt.sdfs
unpaired_arene_sdfs = arene_post_opt_sdf_path/"Unpaired_Arene_sdfs"
unpaired_arene_sdfs.mkdir(parents=True, exist_ok=True)

#Dir for unpaired arene.xyzs
unpaired_arene_xyzs = arene_post_opt_xyz_path/"Unpaired_Arene_xyzs"
unpaired_arene_xyzs.mkdir(parents=True, exist_ok=True)

#Pull in the dehydrogenation DF as a naming/ID/energy reference
#arenes in this DF are confirmed to be paired; can process anything knowing it is paired
dehyd_df = pd.read_csv('Calculated_Dehydrogenation_Energies.csv')
dehyd_df.head()

#pull IDs of paired 'arene_ids' from dehydrog DF
utilized_arene_ids = dehyd_df['arene_ID'].tolist()

#Need a list of filepaths that ARE used - not all .outs are actually used - need to be paired
#loop through the arene_IDs and generate filepaths to search for
utilized_arene_paths = [] #list to store utilized filepaths
for utilized_arene_id in utilized_arene_ids:
    #Construct the name out the expected .out 
    name_of_out = f"{utilized_arene_id}_rdkit_conf_1.out"
    #dir that the source file should be in
    source_out_path = arene_dft_output_path / name_of_out
    #append the filepath to a list of filepaths
    utilized_arene_paths.append(source_out_path)

#Now, compare the list of utilized arenes against the list of .outs currently in the .outs dir
#Get a list of existing arene filepaths for .out files currently in /arene_dft_output_path
current_arene_outs = get_filepaths_in_target_dir(arene_dft_output_path, ".out")

#Next calculate the set of .outs currently in /arene_dft_output_path that are not utilized
non_utilized_arenes = set(current_arene_outs) - set(utilized_arene_paths)

#Using the list of unutilized IDs, move the unused .outs, .xyzs, and .sdfs to respective /unused dirs
for unutilized_out in non_utilized_arenes:
    #specify the source/destination paths for unutilized .outs
    source_out = unutilized_out
    unutilized_out_name = unutilized_out.name
    destination_out = unpaired_arene_outs / unutilized_out_name

    #attempt to move the .out 
    if source_out.is_file():
        try:
            source_out.rename(destination_out)
            #print(f"Moved '{source_out.name}' to '/{unpaired_arene_outs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{source_out}': {e}")
            
    else:
        print(f"File '{source_out.name}' not found in '/{source_out.parent}/'")

    #separate the associated unused arene.xyz file
    raw_name = unutilized_out.stem
    xyz_name = f"{raw_name}.xyz"
    xyz_source = arene_post_opt_xyz_path / xyz_name
    xyz_dest = unpaired_arene_xyzs / xyz_name

    #attempt to move the .xyz
    if xyz_source.is_file():
        try:
            xyz_source.rename(xyz_dest)
            #print(f"Moved '{xyz_source.name}' to '/{unpaired_arene_xyzs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{xyz_source}': {e}")
            
    else:
        print(f"File '{xyz_source.name}' not found in '/{xyz_source.parent}/'")
    
    #separate the associated unused arene.sd-file
    raw_split = raw_name.split("_")
    mol_id = f"{raw_split[0]}_{raw_split[1]}"
    post_sdf_name = f"{mol_id}_rdkit_conf_1_post_opt.sdf"
    sdf_source = arene_post_opt_sdf_path / post_sdf_name
    sdf_dest = unpaired_arene_sdfs / post_sdf_name

    #attempt to move the .sdf
    if sdf_source.is_file():
        try:
            sdf_source.rename(sdf_dest)
            #print(f"Moved '{sdf_source.name}' to '/{unpaired_arene_sdfs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{sdf_source}': {e}")
            
    else:
        print(f"File '{sdf_source.name}' not found in '{sdf_source.parent}'")
# Out:
# Found 7880 .out files in '/Arene_Orca_DFT_Outputs/'

# %%
"""### Final ARYNE File Cleanup / Dir management before Parameter Extraction ###

This cell uses the generated "Calculated_Dehydrogenation_Energies.csv" to determine which .outs in 
/Aryne_Orca_DFT_Outputs are paired with a "parent" arene. Unpaired aryne.outs (those lacking a parent arene)
are moved to a "Valid but unused dir". Given some unused .outs, isolate the corresponding .sdfs and .xyzs 
for unpaired arynes. This ensures a 1:1 match in the number of validated files across all project subdirs.
"""

#Make dirs to hold unpaired files - these are either an arene/aryne missing its partner
#Dir for unpaired Aryne.outs
unpaired_aryne_outs = aryne_dft_output_path/"Valid_but_Unpaired_Arynes"
unpaired_aryne_outs.mkdir(parents=True, exist_ok=True)

#Dir for unpaired Aryne_post_opt.sdfs
unpaired_aryne_sdfs = aryne_post_opt_sdf_path/"Unpaired_Aryne_sdfs"
unpaired_aryne_sdfs.mkdir(parents=True, exist_ok=True)

#Dir for unpaired Aryne.xyzs
unpaired_aryne_xyzs = aryne_post_opt_xyz_path/"Unpaired_Aryne_xyzs"
unpaired_aryne_xyzs.mkdir(parents=True, exist_ok=True)

#Pull in the dehydrogenation DF as a naming/ID/energy reference
#Arynes in this DF are confirmed to be paired; can process anything knowing it is paired
dehyd_df = pd.read_csv('Calculated_Dehydrogenation_Energies.csv')
dehyd_df.head()

#pull IDs of paired 'aryne_ids' from dehydrog DF
utilized_aryne_ids = dehyd_df['aryne_ID'].tolist()

#Need a list of filepaths that ARE used - not all .outs are actually used - need to be paired
#loop through the aryne_IDs and generate filepaths to search for
utilized_aryne_paths = [] #list to store utilized filepaths
for utilized_aryne_id in utilized_aryne_ids:
    #Construct the name out the expected .out 
    name_of_out = f"{utilized_aryne_id}_rdkit_conf_1.out"
    #dir that the source file should be in
    source_out_path = aryne_dft_output_path / name_of_out
    #append the filepath to a list of filepaths
    utilized_aryne_paths.append(source_out_path)

#Now, compare the list of utilized arynes against the list of .outs currently in the .outs dir
#Get a list of existing Aryne filepaths for .out files currently in /aryne_dft_output_path
current_aryne_outs = get_filepaths_in_target_dir(aryne_dft_output_path, ".out")

#Next calculate the set of .outs currently in /aryne_dft_output_path that are not utilized
non_utilized_arynes = set(current_aryne_outs) - set(utilized_aryne_paths)

#Using the list of unutilized IDs, move the unused .outs, .xyzs, and .sdfs to respective /unused dirs
for unutilized_out in non_utilized_arynes:
    #specify the source/destination paths for unutilized .outs
    source_out = unutilized_out
    unutilized_out_name = unutilized_out.name
    destination_out = unpaired_aryne_outs / unutilized_out_name

    #attempt to move the .out 
    if source_out.is_file():
        try:
            source_out.rename(destination_out)
            #print(f"Moved '{source_out.name}' to '/{unpaired_aryne_outs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{source_out}': {e}")
            
    else:
        print(f"File '{source_out.name}' not found in '/{source_out.parent}/'")

    #separate the associated unused aryne.xyz file
    raw_name = unutilized_out.stem
    xyz_name = f"{raw_name}.xyz"
    xyz_source = aryne_post_opt_xyz_path / xyz_name
    xyz_dest = unpaired_aryne_xyzs / xyz_name

    #attempt to move the .xyz
    if xyz_source.is_file():
        try:
            xyz_source.rename(xyz_dest)
            #print(f"Moved '{xyz_source.name}' to '/{unpaired_aryne_xyzs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{xyz_source}': {e}")
            
    else:
        print(f"File '{xyz_source.name}' not found in '/{xyz_source.parent}/'")
    
    #separate the associated unused aryne.sd-file
    raw_split = raw_name.split("_")
    mol_id = f"{raw_split[0]}_{raw_split[1]}"
    post_sdf_name = f"{mol_id}_rdkit_conf_1_post_opt.sdf"
    sdf_source = aryne_post_opt_sdf_path / post_sdf_name
    sdf_dest = unpaired_aryne_sdfs / post_sdf_name

    #attempt to move the .sdf
    if sdf_source.is_file():
        try:
            sdf_source.rename(sdf_dest)
            #print(f"Moved '{sdf_source.name}' to '/{unpaired_aryne_sdfs.name}/'") 
            
        except OSError as e:
            print(f"Error moving '{sdf_source}': {e}")
            
    else:
        print(f"File '{sdf_source.name}' not found in '{sdf_source.parent}'")    

# #For arynes, also delete the dir "Aryne_temp_sdfs"
# aryne_dir_to_delete = arynes_bad_connectivity_sdfs

# # Use shutil.rmtree() to delete the directory and all its contents
# if aryne_dir_to_delete.is_dir():
#     try:
#         shutil.rmtree(aryne_dir_to_delete)
#         print(f"Directory '/{aryne_dir_to_delete.parent}/' and all its contents have been deleted.")
#     except FileNotFoundError:
#         print(f"Error: Directory '/{aryne_directory_to_delete}/' not found.")
#     except Exception as e:
#         print(f"An error occurred: {e}")
# Out:
# Found 8420 .out files in '/Aryne_Orca_DFT_Outputs/'

# %%
"""### Diagnostics on Each Directory ###
"""
final_arene_outs = get_filepaths_in_target_dir(arene_dft_output_path, ".out", printing=False)
print(f"Number of validated/paired Arene.outs in dataset: {len(final_arene_outs)}")

final_aryne_outs = get_filepaths_in_target_dir(aryne_dft_output_path, ".out", printing=False)
print(f"Number of validated/paired Aryne.outs in dataset: {len(final_aryne_outs)}")

print(f"\nNumber of DFT-calculated dE(dehydration) values in dataset: {len(dehyd_df)}")
# Out:
# Number of validated/paired Arene.outs in dataset: 7147
# Number of validated/paired Aryne.outs in dataset: 8124
#
# Number of DFT-calculated dE(dehydration) values in dataset: 8124
